# %% [markdown]
# <a href="https://colab.research.google.com/github/gagan3012/wav2vec2-large-xlsr-punjabi/blob/master/Fine_Tune_XLSR_Wav2Vec2_on_Nepali_ASR_with_%F0%9F%A4%97_Transformers_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Fine-tuning XLSR-Wav2Vec2 for Multi-Lingual ASR with 🤗 Transformers**

# %% [markdown]
# Wav2Vec2 is a pretrained model for Automatic Speech Recognition (ASR) and was released in [September 2020](https://ai.facebook.com/blog/wav2vec-20-learning-the-structure-of-speech-from-raw-audio/) by Alexei Baevski, Michael Auli, and Alex Conneau.  Soon after the superior performance of Wav2Vec2 was demonstrated on the English ASR dataset LibriSpeech, *Facebook AI* presented XLSR-Wav2Vec2 (click [here](https://arxiv.org/abs/2006.13979)). XLSR stands for *cross-lingual  speech representations* and refers to XLSR-Wav2Vec2`s ability to learn speech representations that are useful across multiple languages.
#
# Similar to Wav2Vec2, XLSR-Wav2Vec2 learns powerful speech representations from hundreds of thousands of hours of speech in more than 50 languages of unlabeled speech. Similar, to [BERT's masked language modeling](http://jalammar.github.io/illustrated-bert/), the model learns contextualized speech representations by randomly masking feature vectors before passing them to a transformer network.
#
# ![wav2vec2_structure](https://raw.githubusercontent.com/patrickvonplaten/scientific_images/master/xlsr_wav2vec2.png)
#
# The authors show for the first time that massively pretraining an ASR model on cross-lingual unlabeled speech data, followed by language-specific fine-tuning on very little labeled data achieves state-of-the-art results. See Table 1-5 of the official [paper](https://arxiv.org/pdf/2006.13979.pdf).

# %% [markdown]
# In this notebook, we will give an in-detail explanation of how XLSR-Wav2Vec2's pretrained checkpoint can be fine-tuned on a low-resource ASR dataset of any language. Note that in this notebook, we will fine-tune XLSR-Wav2Vec2 without making use of a language model. It is much simpler and more efficient to use XLSR-Wav2Vec2 without a language model, but better results can be achieved by including a language model.
#
# For demonstration purposes, we fine-tune the [wav2vec2-large-xlsr-53](https://huggingface.co/facebook/wav2vec2-large-xlsr-53) on the low resource Turkish ASR dataset of [Common Voice](https://huggingface.co/datasets/common_voice) that contains just ~6h of validated training data.

# %% [markdown]
# XLSR-Wav2Vec2 is fine-tuned using Connectionist Temporal Classification (CTC), which is an algorithm that is used to train neural networks for sequence-to-sequence problems and mainly in Automatic Speech Recognition and handwriting recognition.
#
# I highly recommend reading the blog post [Sequence Modeling with CTC (2017)](https://distill.pub/2017/ctc/) very well-written blog post by Awni Hannun.

# %% [markdown]
# Before we start, let's install both `datasets` and `transformers` from master. Also, we need the `torchaudio` and `librosa` package to load audio files and the `jiwer` to evaluate our fine-tuned model using the [word error rate (WER)](https://huggingface.co/metrics/wer) metric ${}^1$.

# %%
# %%capture
# !pip install datasets==1.4.1
# !pip install transformers==4.4.0
# !pip install torchaudio
# !pip install librosa
# !pip install jiwer

# %% [markdown]
# ---
#
# ${}^1$ In the [paper](https://arxiv.org/pdf/2006.13979.pdf), the model was evaluated using the phoneme error rate (PER), but by far the most common metric in ASR is the word error rate (WER). To keep this notebook as general as possible we decided to evaluate the model using WER.

# %% [markdown]
# ## Prepare Data, Tokenizer, Feature Extractor

# %% [markdown]
# ASR models transcribe speech to text, which means that we both need a feature extractor that processes the speech signal to the model's input format, *e.g.* a feature vector, and a tokenizer that processes the model's output format to text.
#
# In 🤗 Transformers, the XLSR-Wav2Vec2 model is thus accompanied by both a tokenizer, called [Wav2Vec2CTCTokenizer](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#wav2vec2ctctokenizer), and a feature extractor, called [Wav2Vec2FeatureExtractor](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#wav2vec2featureextractor).
#
# Let's start by creating the tokenizer responsible for decoding the model's predictions.

# %% [markdown]
# ### Create Wav2Vec2CTCTokenizer

# %% [markdown]
# The [pretrained Wav2Vec2 checkpoint]( ) maps the speech signal to a sequence of context representations as illustrated in the figure above. A fine-tuned XLSR-Wav2Vec2 checkpoint needs to map this sequence of context representations to its corresponding transcription so that a linear layer has to be added on top of the transformer block (shown in yellow). This linear layer is used to classifies each context representation to a token class analogous how, *e.g.*, after pretraining a linear layer is added on top of BERT's embeddings for further classification - *cf.* with *"BERT"* section of this [blog post](https://huggingface.co/blog/warm-starting-encoder-decoder).
#
# The output size of this layer corresponds to the number of tokens in the vocabulary, which does **not** depend on XLSR-Wav2Vec2's pretraining task, but only on the labeled dataset used for fine-tuning. So in the first step, we will take a look at Common Voice and define a vocabulary based on the dataset's transcriptions.

# %% [markdown]
# First, let's go to [Common Voice](https://commonvoice.mozilla.org/en/datasets) and pick a language to fine-tune XLSR-Wav2Vec2 on. For this notebook, we will use Turkish.
#
# For each language-specific dataset, you can find a language code corresponding to your chosen language. On [Common Voice](https://commonvoice.mozilla.org/en/datasets), look for the field "Version". The language code then corresponds to the prefix before the underscore. For Turkish, *e.g.* the language code is `"tr"`.
#
# Great, now we can use 🤗 Datasets' simple API to download the data. The dataset name will be `"common_voice"`, the config name corresponds to the language code - `"tr"` in our case.

# %% [markdown]
# Common Voice has many different splits including `invalidated`, which refers to data that was not rated as "clean enough" to be considered useful. In this notebook, we will only make use of the splits `"train"`, `"validation"` and `"test"`.
#
# Because the Turkish dataset is so small, we will merge both the validation and training data into a training dataset and simply use the test data for validation.

# %%
# !wget https://www.openslr.org/resources/43/ne_np_female.zip
# !unzip ne_np_female.zip
# !ls ne_np_female
# Out:
# --2021-03-23 17:12:13--  https://www.openslr.org/resources/43/ne_np_female.zip
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 800375645 (763M) [application/zip]
# Saving to: ‘ne_np_female.zip’
#
# ne_np_female.zip    100%[===================>] 763.30M  20.0MB/s    in 40s
#
# 2021-03-23 17:12:54 (18.9 MB/s) - ‘ne_np_female.zip’ saved [800375645/800375645]
#
# Archive:  ne_np_female.zip
#    creating: ne_np_female/
#   inflating: ne_np_female/line_index.tsv
#    creating: ne_np_female/wavs/
#   inflating: ne_np_female/wavs/nep_0258_0119737288.wav
#   inflating: ne_np_female/wavs/nep_0258_0461984530.wav
#   inflating: ne_np_female/wavs/nep_0258_0576399736.wav
#   inflating: ne_np_female/wavs/nep_0258_0707220145.wav
#   inflating: ne_np_female/wavs/nep_0258_0838627393.wav
#   inflating: ne_np_female/wavs/nep_0258_1082186644.wav
#   inflating: ne_np_female/wavs/nep_0258_1139532706.wav
#   inflating: ne_np_female/wavs/nep_0258_2044831682.wav
#   inflating: ne_np_female/wavs/nep_0258_2658340102.wav
#   inflating: ne_np_female/wavs/nep_0258_2670176669.wav
#   inflating: ne_np_female/wavs/nep_0258_2764563824.wav
#   inflating: ne_np_female/wavs/nep_0258_2784581247.wav
#   inflating: ne_np_female/wavs/nep_0258_2857262530.wav
#   inflating: ne_np_female/wavs/nep_0258_2907711643.wav
#   inflating: ne_np_female/wavs/nep_0258_3000024878.wav
#   inflating: ne_np_female/wavs/nep_0258_3178538388.wav
#   inflating: ne_np_female/wavs/nep_0258_3696950667.wav
#   inflating: ne_np_female/wavs/nep_0258_3756247064.wav
#   inflating: ne_np_female/wavs/nep_0258_3863885031.wav
#   inflating: ne_np_female/wavs/nep_0258_4633570599.wav
#   inflating: ne_np_female/wavs/nep_0258_5936619539.wav
#   inflating: ne_np_female/wavs/nep_0258_5963754000.wav
#   inflating: ne_np_female/wavs/nep_0258_6050104400.wav
#   inflating: ne_np_female/wavs/nep_0258_6075003542.wav
#   inflating: ne_np_female/wavs/nep_0258_6318800215.wav
#   inflating: ne_np_female/wavs/nep_0258_6957160770.wav
#   inflating: ne_np_female/wavs/nep_0258_7059288409.wav
#   inflating: ne_np_female/wavs/nep_0258_7074678628.wav
#   inflating: ne_np_female/wavs/nep_0258_7121600053.wav
#   inflating: ne_np_female/wavs/nep_0258_7147057872.wav
#   inflating: ne_np_female/wavs/nep_0258_7211607717.wav
#   inflating: ne_np_female/wavs/nep_0258_7263933785.wav
#   inflating: ne_np_female/wavs/nep_0258_7375603014.wav
#   inflating: ne_np_female/wavs/nep_0258_7605572831.wav
#   inflating: ne_np_female/wavs/nep_0258_7843539751.wav
#   inflating: ne_np_female/wavs/nep_0258_7944550785.wav
#   inflating: ne_np_female/wavs/nep_0258_8169062440.wav
#   inflating: ne_np_female/wavs/nep_0258_8444696734.wav
#   inflating: ne_np_female/wavs/nep_0258_9071871190.wav
#   inflating: ne_np_female/wavs/nep_0258_9113827113.wav
#   inflating: ne_np_female/wavs/nep_0258_9132039389.wav
#   inflating: ne_np_female/wavs/nep_0258_9284332098.wav
#   inflating: ne_np_female/wavs/nep_0258_9660145870.wav
#   inflating: ne_np_female/wavs/nep_0258_9678022366.wav
#   inflating: ne_np_female/wavs/nep_0258_9856286890.wav
#   inflating: ne_np_female/wavs/nep_0258_9867218411.wav
#   inflating: ne_np_female/wavs/nep_0258_9885710280.wav
#   inflating: ne_np_female/wavs/nep_0258_9939583579.wav
#   inflating: ne_np_female/wavs/nep_0258_9950286014.wav
#   inflating: ne_np_female/wavs/nep_0283_0766374282.wav
#   inflating: ne_np_female/wavs/nep_0283_0816115484.wav
#   inflating: ne_np_female/wavs/nep_0283_0964661420.wav
#   inflating: ne_np_female/wavs/nep_0283_0976640363.wav
#   inflating: ne_np_female/wavs/nep_0283_1353776465.wav
#   inflating: ne_np_female/wavs/nep_0283_1731098563.wav
#   inflating: ne_np_female/wavs/nep_0283_2244138368.wav
#   inflating: ne_np_female/wavs/nep_0283_3326495973.wav
#   inflating: ne_np_female/wavs/nep_0283_3759375127.wav
#   inflating: ne_np_female/wavs/nep_0283_4038945255.wav
#   inflating: ne_np_female/wavs/nep_0283_4559349270.wav
#   inflating: ne_np_female/wavs/nep_0283_4618089463.wav
#   inflating: ne_np_female/wavs/nep_0283_4751807651.wav
#   inflating: ne_np_female/wavs/nep_0283_4905013597.wav
#   inflating: ne_np_female/wavs/nep_0283_5158477137.wav
#   inflating: ne_np_female/wavs/nep_0283_5326639197.wav
#   inflating: ne_np_female/wavs/nep_0283_5380400568.wav
#   inflating: ne_np_female/wavs/nep_0283_5584542821.wav
#   inflating: ne_np_female/wavs/nep_0283_6656084051.wav
#   inflating: ne_np_female/wavs/nep_0283_6773461444.wav
#   inflating: ne_np_female/wavs/nep_0283_7088220977.wav
#   inflating: ne_np_female/wavs/nep_0283_7151562621.wav
#   inflating: ne_np_female/wavs/nep_0283_7189052277.wav
#   inflating: ne_np_female/wavs/nep_0283_7794093052.wav
#   inflating: ne_np_female/wavs/nep_0283_8183720007.wav
#   inflating: ne_np_female/wavs/nep_0283_8303673924.wav
#   inflating: ne_np_female/wavs/nep_0283_8671851523.wav
#   inflating: ne_np_female/wavs/nep_0283_8694410705.wav
#   inflating: ne_np_female/wavs/nep_0283_8753376916.wav
#   inflating: ne_np_female/wavs/nep_0283_9497646917.wav
#   inflating: ne_np_female/wavs/nep_0283_9642724626.wav
#   inflating: ne_np_female/wavs/nep_0283_9885544741.wav
#   inflating: ne_np_female/wavs/nep_0546_0029201705.wav
#   inflating: ne_np_female/wavs/nep_0546_0054660966.wav
#   inflating: ne_np_female/wavs/nep_0546_0077678862.wav
#   inflating: ne_np_female/wavs/nep_0546_0081522120.wav
#   inflating: ne_np_female/wavs/nep_0546_0087760275.wav
#   inflating: ne_np_female/wavs/nep_0546_0106808568.wav
#   inflating: ne_np_female/wavs/nep_0546_0111162501.wav
#   inflating: ne_np_female/wavs/nep_0546_0111676622.wav
#   inflating: ne_np_female/wavs/nep_0546_0152397263.wav
#   inflating: ne_np_female/wavs/nep_0546_0203684983.wav
#   inflating: ne_np_female/wavs/nep_0546_0212162804.wav
#   inflating: ne_np_female/wavs/nep_0546_0247234914.wav
#   inflating: ne_np_female/wavs/nep_0546_0247685392.wav
#   inflating: ne_np_female/wavs/nep_0546_0280639280.wav
#   inflating: ne_np_female/wavs/nep_0546_0314559048.wav
#   inflating: ne_np_female/wavs/nep_0546_0324069539.wav
#   inflating: ne_np_female/wavs/nep_0546_0328643693.wav
#   inflating: ne_np_female/wavs/nep_0546_0356947146.wav
#   inflating: ne_np_female/wavs/nep_0546_0360261388.wav
#   inflating: ne_np_female/wavs/nep_0546_0371825078.wav
#   inflating: ne_np_female/wavs/nep_0546_0388611826.wav
#   inflating: ne_np_female/wavs/nep_0546_0417178507.wav
#   inflating: ne_np_female/wavs/nep_0546_0420145571.wav
#   inflating: ne_np_female/wavs/nep_0546_0432877132.wav
#   inflating: ne_np_female/wavs/nep_0546_0490617198.wav
#   inflating: ne_np_female/wavs/nep_0546_0504646534.wav
#   inflating: ne_np_female/wavs/nep_0546_0657727170.wav
#   inflating: ne_np_female/wavs/nep_0546_0659548622.wav
#   inflating: ne_np_female/wavs/nep_0546_0664459816.wav
#   inflating: ne_np_female/wavs/nep_0546_0677472615.wav
#   inflating: ne_np_female/wavs/nep_0546_0685084826.wav
#   inflating: ne_np_female/wavs/nep_0546_0712459277.wav
#   inflating: ne_np_female/wavs/nep_0546_0738896302.wav
#   inflating: ne_np_female/wavs/nep_0546_0743764877.wav
#   inflating: ne_np_female/wavs/nep_0546_0744543522.wav
#   inflating: ne_np_female/wavs/nep_0546_0760148551.wav
#   inflating: ne_np_female/wavs/nep_0546_0806003703.wav
#   inflating: ne_np_female/wavs/nep_0546_0876609377.wav
#   inflating: ne_np_female/wavs/nep_0546_0894887834.wav
#   inflating: ne_np_female/wavs/nep_0546_0973996646.wav
#   inflating: ne_np_female/wavs/nep_0546_0987384824.wav
#   inflating: ne_np_female/wavs/nep_0546_0988245523.wav
#   inflating: ne_np_female/wavs/nep_0546_1009807268.wav
#   inflating: ne_np_female/wavs/nep_0546_1036808728.wav
#   inflating: ne_np_female/wavs/nep_0546_1046020727.wav
#   inflating: ne_np_female/wavs/nep_0546_1050863540.wav
#   inflating: ne_np_female/wavs/nep_0546_1075589513.wav
#   inflating: ne_np_female/wavs/nep_0546_1091421919.wav
#   inflating: ne_np_female/wavs/nep_0546_1095090924.wav
#   inflating: ne_np_female/wavs/nep_0546_1101290916.wav
#   inflating: ne_np_female/wavs/nep_0546_1153028889.wav
#   inflating: ne_np_female/wavs/nep_0546_1216756049.wav
#   inflating: ne_np_female/wavs/nep_0546_1266766076.wav
#   inflating: ne_np_female/wavs/nep_0546_1284228568.wav
#   inflating: ne_np_female/wavs/nep_0546_1329853697.wav
#   inflating: ne_np_female/wavs/nep_0546_1364936863.wav
#   inflating: ne_np_female/wavs/nep_0546_1370941050.wav
#   inflating: ne_np_female/wavs/nep_0546_1373549461.wav
#   inflating: ne_np_female/wavs/nep_0546_1409208559.wav
#   inflating: ne_np_female/wavs/nep_0546_1411086812.wav
#   inflating: ne_np_female/wavs/nep_0546_1488676727.wav
#   inflating: ne_np_female/wavs/nep_0546_1506025460.wav
#   inflating: ne_np_female/wavs/nep_0546_1535070415.wav
#   inflating: ne_np_female/wavs/nep_0546_1548994302.wav
#   inflating: ne_np_female/wavs/nep_0546_1555952548.wav
#   inflating: ne_np_female/wavs/nep_0546_1567992918.wav
#   inflating: ne_np_female/wavs/nep_0546_1570010746.wav
#   inflating: ne_np_female/wavs/nep_0546_1581951551.wav
#   inflating: ne_np_female/wavs/nep_0546_1623165518.wav
#   inflating: ne_np_female/wavs/nep_0546_1623725320.wav
#   inflating: ne_np_female/wavs/nep_0546_1627945346.wav
#   inflating: ne_np_female/wavs/nep_0546_1636939995.wav
#   inflating: ne_np_female/wavs/nep_0546_1648288763.wav
#   inflating: ne_np_female/wavs/nep_0546_1657730053.wav
#   inflating: ne_np_female/wavs/nep_0546_1704280925.wav
#   inflating: ne_np_female/wavs/nep_0546_1709529716.wav
#   inflating: ne_np_female/wavs/nep_0546_1751539393.wav
#   inflating: ne_np_female/wavs/nep_0546_1757689247.wav
#   inflating: ne_np_female/wavs/nep_0546_1820151981.wav
#   inflating: ne_np_female/wavs/nep_0546_1828967194.wav
#   inflating: ne_np_female/wavs/nep_0546_1839688913.wav
#   inflating: ne_np_female/wavs/nep_0546_1839946667.wav
#   inflating: ne_np_female/wavs/nep_0546_1841446999.wav
#   inflating: ne_np_female/wavs/nep_0546_1847819546.wav
#   inflating: ne_np_female/wavs/nep_0546_1874346314.wav
#   inflating: ne_np_female/wavs/nep_0546_1875717509.wav
#   inflating: ne_np_female/wavs/nep_0546_1888328246.wav
#   inflating: ne_np_female/wavs/nep_0546_1913589364.wav
#   inflating: ne_np_female/wavs/nep_0546_1917017692.wav
#   inflating: ne_np_female/wavs/nep_0546_1932438217.wav
#   inflating: ne_np_female/wavs/nep_0546_1950992198.wav
#   inflating: ne_np_female/wavs/nep_0546_1969789211.wav
#   inflating: ne_np_female/wavs/nep_0546_1990809193.wav
#   inflating: ne_np_female/wavs/nep_0546_1999862359.wav
#   inflating: ne_np_female/wavs/nep_0546_2028204747.wav
#   inflating: ne_np_female/wavs/nep_0546_2031120995.wav
#   inflating: ne_np_female/wavs/nep_0546_2082351340.wav
#   inflating: ne_np_female/wavs/nep_0546_2106804279.wav
#   inflating: ne_np_female/wavs/nep_0546_2150970344.wav
#   inflating: ne_np_female/wavs/nep_0546_2190381285.wav
#   inflating: ne_np_female/wavs/nep_0546_2228311637.wav
#   inflating: ne_np_female/wavs/nep_0546_2254855120.wav
#   inflating: ne_np_female/wavs/nep_0546_2261491734.wav
#   inflating: ne_np_female/wavs/nep_0546_2264069418.wav
#   inflating: ne_np_female/wavs/nep_0546_2282619132.wav
#   inflating: ne_np_female/wavs/nep_0546_2289266069.wav
#   inflating: ne_np_female/wavs/nep_0546_2300280975.wav
#   inflating: ne_np_female/wavs/nep_0546_2306998866.wav
#   inflating: ne_np_female/wavs/nep_0546_2327279343.wav
#   inflating: ne_np_female/wavs/nep_0546_2423665507.wav
#   inflating: ne_np_female/wavs/nep_0546_2444457349.wav
#   inflating: ne_np_female/wavs/nep_0546_2500635318.wav
#   inflating: ne_np_female/wavs/nep_0546_2555171110.wav
#   inflating: ne_np_female/wavs/nep_0546_2566323184.wav
#   inflating: ne_np_female/wavs/nep_0546_2569424979.wav
#   inflating: ne_np_female/wavs/nep_0546_2580741211.wav
#   inflating: ne_np_female/wavs/nep_0546_2586374559.wav
#   inflating: ne_np_female/wavs/nep_0546_2592619420.wav
#   inflating: ne_np_female/wavs/nep_0546_2598767507.wav
#   inflating: ne_np_female/wavs/nep_0546_2627445287.wav
#   inflating: ne_np_female/wavs/nep_0546_2641669367.wav
#   inflating: ne_np_female/wavs/nep_0546_2648001614.wav
#   inflating: ne_np_female/wavs/nep_0546_2648125610.wav
#   inflating: ne_np_female/wavs/nep_0546_2669050485.wav
#   inflating: ne_np_female/wavs/nep_0546_2708621810.wav
#   inflating: ne_np_female/wavs/nep_0546_2730850248.wav
#   inflating: ne_np_female/wavs/nep_0546_2743516060.wav
#   inflating: ne_np_female/wavs/nep_0546_2756840944.wav
#   inflating: ne_np_female/wavs/nep_0546_2770740893.wav
#   inflating: ne_np_female/wavs/nep_0546_2783338810.wav
#   inflating: ne_np_female/wavs/nep_0546_2785060463.wav
#   inflating: ne_np_female/wavs/nep_0546_2800364285.wav
#   inflating: ne_np_female/wavs/nep_0546_2801412251.wav
#   inflating: ne_np_female/wavs/nep_0546_2843404972.wav
#   inflating: ne_np_female/wavs/nep_0546_2854954282.wav
#   inflating: ne_np_female/wavs/nep_0546_2868510042.wav
#   inflating: ne_np_female/wavs/nep_0546_2878948778.wav
#   inflating: ne_np_female/wavs/nep_0546_2880447148.wav
#   inflating: ne_np_female/wavs/nep_0546_2890130880.wav
#   inflating: ne_np_female/wavs/nep_0546_2901086638.wav
#   inflating: ne_np_female/wavs/nep_0546_2917381710.wav
#   inflating: ne_np_female/wavs/nep_0546_2918033281.wav
#   inflating: ne_np_female/wavs/nep_0546_2923886327.wav
#   inflating: ne_np_female/wavs/nep_0546_2929266220.wav
#   inflating: ne_np_female/wavs/nep_0546_2953992562.wav
#   inflating: ne_np_female/wavs/nep_0546_2958873141.wav
#   inflating: ne_np_female/wavs/nep_0546_3003054814.wav
#   inflating: ne_np_female/wavs/nep_0546_3007836143.wav
#   inflating: ne_np_female/wavs/nep_0546_3020378588.wav
#   inflating: ne_np_female/wavs/nep_0546_3042205946.wav
#   inflating: ne_np_female/wavs/nep_0546_3076577201.wav
#   inflating: ne_np_female/wavs/nep_0546_3134436030.wav
#   inflating: ne_np_female/wavs/nep_0546_3193418396.wav
#   inflating: ne_np_female/wavs/nep_0546_3201480617.wav
#   inflating: ne_np_female/wavs/nep_0546_3212922328.wav
#   inflating: ne_np_female/wavs/nep_0546_3220286793.wav
#   inflating: ne_np_female/wavs/nep_0546_3232354843.wav
#   inflating: ne_np_female/wavs/nep_0546_3267854744.wav
#   inflating: ne_np_female/wavs/nep_0546_3318714782.wav
#   inflating: ne_np_female/wavs/nep_0546_3339057687.wav
#   inflating: ne_np_female/wavs/nep_0546_3349081644.wav
#   inflating: ne_np_female/wavs/nep_0546_3357727111.wav
#   inflating: ne_np_female/wavs/nep_0546_3360525235.wav
#   inflating: ne_np_female/wavs/nep_0546_3379641776.wav
#   inflating: ne_np_female/wavs/nep_0546_3397318151.wav
#   inflating: ne_np_female/wavs/nep_0546_3415443618.wav
#   inflating: ne_np_female/wavs/nep_0546_3432370397.wav
#   inflating: ne_np_female/wavs/nep_0546_3433661851.wav
#   inflating: ne_np_female/wavs/nep_0546_3442005520.wav
#   inflating: ne_np_female/wavs/nep_0546_3468463359.wav
#   inflating: ne_np_female/wavs/nep_0546_3493862458.wav
#   inflating: ne_np_female/wavs/nep_0546_3498602749.wav
#   inflating: ne_np_female/wavs/nep_0546_3502546382.wav
#   inflating: ne_np_female/wavs/nep_0546_3543318757.wav
#   inflating: ne_np_female/wavs/nep_0546_3543759936.wav
#   inflating: ne_np_female/wavs/nep_0546_3594640296.wav
#   inflating: ne_np_female/wavs/nep_0546_3606699939.wav
#   inflating: ne_np_female/wavs/nep_0546_3625614428.wav
#   inflating: ne_np_female/wavs/nep_0546_3655731348.wav
#   inflating: ne_np_female/wavs/nep_0546_3659519943.wav
#   inflating: ne_np_female/wavs/nep_0546_3665916054.wav
#   inflating: ne_np_female/wavs/nep_0546_3669566875.wav
#   inflating: ne_np_female/wavs/nep_0546_3686219859.wav
#   inflating: ne_np_female/wavs/nep_0546_3693406213.wav
#   inflating: ne_np_female/wavs/nep_0546_3719657199.wav
#   inflating: ne_np_female/wavs/nep_0546_3735008673.wav
#   inflating: ne_np_female/wavs/nep_0546_3737710455.wav
#   inflating: ne_np_female/wavs/nep_0546_3743234271.wav
#   inflating: ne_np_female/wavs/nep_0546_3751777393.wav
#   inflating: ne_np_female/wavs/nep_0546_3782097543.wav
#   inflating: ne_np_female/wavs/nep_0546_3785618587.wav
#   inflating: ne_np_female/wavs/nep_0546_3803170301.wav
#   inflating: ne_np_female/wavs/nep_0546_3805346971.wav
#   inflating: ne_np_female/wavs/nep_0546_3844213957.wav
#   inflating: ne_np_female/wavs/nep_0546_3857176321.wav
#   inflating: ne_np_female/wavs/nep_0546_3869979792.wav
#   inflating: ne_np_female/wavs/nep_0546_3899362644.wav
#   inflating: ne_np_female/wavs/nep_0546_3903777350.wav
#   inflating: ne_np_female/wavs/nep_0546_3911026041.wav
#   inflating: ne_np_female/wavs/nep_0546_3979164145.wav
#   inflating: ne_np_female/wavs/nep_0546_3988642046.wav
#   inflating: ne_np_female/wavs/nep_0546_3995718916.wav
#   inflating: ne_np_female/wavs/nep_0546_4013351462.wav
#   inflating: ne_np_female/wavs/nep_0546_4035246296.wav
#   inflating: ne_np_female/wavs/nep_0546_4061797802.wav
#   inflating: ne_np_female/wavs/nep_0546_4074187558.wav
#   inflating: ne_np_female/wavs/nep_0546_4100790116.wav
#   inflating: ne_np_female/wavs/nep_0546_4143561318.wav
#   inflating: ne_np_female/wavs/nep_0546_4192847763.wav
#   inflating: ne_np_female/wavs/nep_0546_4208078228.wav
#   inflating: ne_np_female/wavs/nep_0546_4234687737.wav
#   inflating: ne_np_female/wavs/nep_0546_4235434290.wav
#   inflating: ne_np_female/wavs/nep_0546_4272781089.wav
#   inflating: ne_np_female/wavs/nep_0546_4324932527.wav
#   inflating: ne_np_female/wavs/nep_0546_4403604647.wav
#   inflating: ne_np_female/wavs/nep_0546_4405770244.wav
#   inflating: ne_np_female/wavs/nep_0546_4411250717.wav
#   inflating: ne_np_female/wavs/nep_0546_4418224893.wav
#   inflating: ne_np_female/wavs/nep_0546_4429317177.wav
#   inflating: ne_np_female/wavs/nep_0546_4451907228.wav
#   inflating: ne_np_female/wavs/nep_0546_4462375379.wav
#   inflating: ne_np_female/wavs/nep_0546_4503712516.wav
#   inflating: ne_np_female/wavs/nep_0546_4571121178.wav
#   inflating: ne_np_female/wavs/nep_0546_4580530501.wav
#   inflating: ne_np_female/wavs/nep_0546_4626254053.wav
#   inflating: ne_np_female/wavs/nep_0546_4654161400.wav
#   inflating: ne_np_female/wavs/nep_0546_4668652322.wav
#   inflating: ne_np_female/wavs/nep_0546_4673329605.wav
#   inflating: ne_np_female/wavs/nep_0546_4708367699.wav
#   inflating: ne_np_female/wavs/nep_0546_4710635421.wav
#   inflating: ne_np_female/wavs/nep_0546_4733772203.wav
#   inflating: ne_np_female/wavs/nep_0546_4734354598.wav
#   inflating: ne_np_female/wavs/nep_0546_4759164239.wav
#   inflating: ne_np_female/wavs/nep_0546_4767150400.wav
#   inflating: ne_np_female/wavs/nep_0546_4767440530.wav
#   inflating: ne_np_female/wavs/nep_0546_4792017606.wav
#   inflating: ne_np_female/wavs/nep_0546_4792342171.wav
#   inflating: ne_np_female/wavs/nep_0546_4797569736.wav
#   inflating: ne_np_female/wavs/nep_0546_4819044101.wav
#   inflating: ne_np_female/wavs/nep_0546_4853610763.wav
#   inflating: ne_np_female/wavs/nep_0546_4868265038.wav
#   inflating: ne_np_female/wavs/nep_0546_4874583637.wav
#   inflating: ne_np_female/wavs/nep_0546_4896619679.wav
#   inflating: ne_np_female/wavs/nep_0546_4928555822.wav
#   inflating: ne_np_female/wavs/nep_0546_4940527952.wav
#   inflating: ne_np_female/wavs/nep_0546_4941885441.wav
#   inflating: ne_np_female/wavs/nep_0546_4969979086.wav
#   inflating: ne_np_female/wavs/nep_0546_4979711920.wav
#   inflating: ne_np_female/wavs/nep_0546_5023753880.wav
#   inflating: ne_np_female/wavs/nep_0546_5059471688.wav
#   inflating: ne_np_female/wavs/nep_0546_5082066987.wav
#   inflating: ne_np_female/wavs/nep_0546_5082936888.wav
#   inflating: ne_np_female/wavs/nep_0546_5108450978.wav
#   inflating: ne_np_female/wavs/nep_0546_5121682352.wav
#   inflating: ne_np_female/wavs/nep_0546_5145517817.wav
#   inflating: ne_np_female/wavs/nep_0546_5150629786.wav
#   inflating: ne_np_female/wavs/nep_0546_5154065910.wav
#   inflating: ne_np_female/wavs/nep_0546_5155722329.wav
#   inflating: ne_np_female/wavs/nep_0546_5176171202.wav
#   inflating: ne_np_female/wavs/nep_0546_5184310421.wav
#   inflating: ne_np_female/wavs/nep_0546_5225771126.wav
#   inflating: ne_np_female/wavs/nep_0546_5230584092.wav
#   inflating: ne_np_female/wavs/nep_0546_5273088105.wav
#   inflating: ne_np_female/wavs/nep_0546_5287880117.wav
#   inflating: ne_np_female/wavs/nep_0546_5292495263.wav
#   inflating: ne_np_female/wavs/nep_0546_5294903398.wav
#   inflating: ne_np_female/wavs/nep_0546_5309728526.wav
#   inflating: ne_np_female/wavs/nep_0546_5320106695.wav
#   inflating: ne_np_female/wavs/nep_0546_5345340396.wav
#   inflating: ne_np_female/wavs/nep_0546_5362686516.wav
#   inflating: ne_np_female/wavs/nep_0546_5439122478.wav
#   inflating: ne_np_female/wavs/nep_0546_5451941367.wav
#   inflating: ne_np_female/wavs/nep_0546_5493767844.wav
#   inflating: ne_np_female/wavs/nep_0546_5517187052.wav
#   inflating: ne_np_female/wavs/nep_0546_5521883428.wav
#   inflating: ne_np_female/wavs/nep_0546_5523246251.wav
#   inflating: ne_np_female/wavs/nep_0546_5528622774.wav
#   inflating: ne_np_female/wavs/nep_0546_5530396269.wav
#   inflating: ne_np_female/wavs/nep_0546_5540265879.wav
#   inflating: ne_np_female/wavs/nep_0546_5551244103.wav
#   inflating: ne_np_female/wavs/nep_0546_5559563135.wav
#   inflating: ne_np_female/wavs/nep_0546_5563904117.wav
#   inflating: ne_np_female/wavs/nep_0546_5564857879.wav
#   inflating: ne_np_female/wavs/nep_0546_5591338514.wav
#   inflating: ne_np_female/wavs/nep_0546_5596997258.wav
#   inflating: ne_np_female/wavs/nep_0546_5623578564.wav
#   inflating: ne_np_female/wavs/nep_0546_5625463325.wav
#   inflating: ne_np_female/wavs/nep_0546_5637749186.wav
#   inflating: ne_np_female/wavs/nep_0546_5640068622.wav
#   inflating: ne_np_female/wavs/nep_0546_5641364661.wav
#   inflating: ne_np_female/wavs/nep_0546_5649057553.wav
#   inflating: ne_np_female/wavs/nep_0546_5685379320.wav
#   inflating: ne_np_female/wavs/nep_0546_5693635406.wav
#   inflating: ne_np_female/wavs/nep_0546_5697832733.wav
#   inflating: ne_np_female/wavs/nep_0546_5712694328.wav
#   inflating: ne_np_female/wavs/nep_0546_5748448669.wav
#   inflating: ne_np_female/wavs/nep_0546_5773020952.wav
#   inflating: ne_np_female/wavs/nep_0546_5775264068.wav
#   inflating: ne_np_female/wavs/nep_0546_5792891596.wav
#   inflating: ne_np_female/wavs/nep_0546_5800210345.wav
#   inflating: ne_np_female/wavs/nep_0546_5881846858.wav
#   inflating: ne_np_female/wavs/nep_0546_5887506398.wav
#   inflating: ne_np_female/wavs/nep_0546_5967412214.wav
#   inflating: ne_np_female/wavs/nep_0546_6024469911.wav
#   inflating: ne_np_female/wavs/nep_0546_6024498400.wav
#   inflating: ne_np_female/wavs/nep_0546_6099121597.wav
#   inflating: ne_np_female/wavs/nep_0546_6117297526.wav
#   inflating: ne_np_female/wavs/nep_0546_6133740081.wav
#   inflating: ne_np_female/wavs/nep_0546_6160964956.wav
#   inflating: ne_np_female/wavs/nep_0546_6178756476.wav
#   inflating: ne_np_female/wavs/nep_0546_6181977750.wav
#   inflating: ne_np_female/wavs/nep_0546_6224843014.wav
#   inflating: ne_np_female/wavs/nep_0546_6242395806.wav
#   inflating: ne_np_female/wavs/nep_0546_6261649465.wav
#   inflating: ne_np_female/wavs/nep_0546_6268679559.wav
#   inflating: ne_np_female/wavs/nep_0546_6278470870.wav
#   inflating: ne_np_female/wavs/nep_0546_6280377443.wav
#   inflating: ne_np_female/wavs/nep_0546_6297249192.wav
#   inflating: ne_np_female/wavs/nep_0546_6303294475.wav
#   inflating: ne_np_female/wavs/nep_0546_6322353836.wav
#   inflating: ne_np_female/wavs/nep_0546_6375493076.wav
#   inflating: ne_np_female/wavs/nep_0546_6379008467.wav
#   inflating: ne_np_female/wavs/nep_0546_6477856191.wav
#   inflating: ne_np_female/wavs/nep_0546_6487604424.wav
#   inflating: ne_np_female/wavs/nep_0546_6561926136.wav
#   inflating: ne_np_female/wavs/nep_0546_6565054275.wav
#   inflating: ne_np_female/wavs/nep_0546_6567686476.wav
#   inflating: ne_np_female/wavs/nep_0546_6587298618.wav
#   inflating: ne_np_female/wavs/nep_0546_6608602305.wav
#   inflating: ne_np_female/wavs/nep_0546_6634248093.wav
#   inflating: ne_np_female/wavs/nep_0546_6699931770.wav
#   inflating: ne_np_female/wavs/nep_0546_6701968493.wav
#   inflating: ne_np_female/wavs/nep_0546_6714476998.wav
#   inflating: ne_np_female/wavs/nep_0546_6724371003.wav
#   inflating: ne_np_female/wavs/nep_0546_6730177303.wav
#   inflating: ne_np_female/wavs/nep_0546_6748563935.wav
#   inflating: ne_np_female/wavs/nep_0546_6753563278.wav
#   inflating: ne_np_female/wavs/nep_0546_6790520596.wav
#   inflating: ne_np_female/wavs/nep_0546_6822246701.wav
#   inflating: ne_np_female/wavs/nep_0546_6827653923.wav
#   inflating: ne_np_female/wavs/nep_0546_6835729336.wav
#   inflating: ne_np_female/wavs/nep_0546_6852778943.wav
#   inflating: ne_np_female/wavs/nep_0546_6853079866.wav
#   inflating: ne_np_female/wavs/nep_0546_6886348878.wav
#   inflating: ne_np_female/wavs/nep_0546_6895873651.wav
#   inflating: ne_np_female/wavs/nep_0546_6902458143.wav
#   inflating: ne_np_female/wavs/nep_0546_6924932351.wav
#   inflating: ne_np_female/wavs/nep_0546_6941764775.wav
#   inflating: ne_np_female/wavs/nep_0546_6945085419.wav
#   inflating: ne_np_female/wavs/nep_0546_6959931606.wav
#   inflating: ne_np_female/wavs/nep_0546_6998432618.wav
#   inflating: ne_np_female/wavs/nep_0546_7014054383.wav
#   inflating: ne_np_female/wavs/nep_0546_7016402255.wav
#   inflating: ne_np_female/wavs/nep_0546_7054581764.wav
#   inflating: ne_np_female/wavs/nep_0546_7059399731.wav
#   inflating: ne_np_female/wavs/nep_0546_7066975831.wav
#   inflating: ne_np_female/wavs/nep_0546_7082599536.wav
#   inflating: ne_np_female/wavs/nep_0546_7092737345.wav
#   inflating: ne_np_female/wavs/nep_0546_7094533040.wav
#   inflating: ne_np_female/wavs/nep_0546_7133800018.wav
#   inflating: ne_np_female/wavs/nep_0546_7146910945.wav
#   inflating: ne_np_female/wavs/nep_0546_7150982977.wav
#   inflating: ne_np_female/wavs/nep_0546_7195186643.wav
#   inflating: ne_np_female/wavs/nep_0546_7198399203.wav
#   inflating: ne_np_female/wavs/nep_0546_7212931328.wav
#   inflating: ne_np_female/wavs/nep_0546_7238336677.wav
#   inflating: ne_np_female/wavs/nep_0546_7241261186.wav
#   inflating: ne_np_female/wavs/nep_0546_7289298941.wav
#   inflating: ne_np_female/wavs/nep_0546_7302174967.wav
#   inflating: ne_np_female/wavs/nep_0546_7314848881.wav
#   inflating: ne_np_female/wavs/nep_0546_7327433114.wav
#   inflating: ne_np_female/wavs/nep_0546_7353852861.wav
#   inflating: ne_np_female/wavs/nep_0546_7370160468.wav
#   inflating: ne_np_female/wavs/nep_0546_7420214959.wav
#   inflating: ne_np_female/wavs/nep_0546_7421635821.wav
#   inflating: ne_np_female/wavs/nep_0546_7422515817.wav
#   inflating: ne_np_female/wavs/nep_0546_7454541011.wav
#   inflating: ne_np_female/wavs/nep_0546_7455127638.wav
#   inflating: ne_np_female/wavs/nep_0546_7455362678.wav
#   inflating: ne_np_female/wavs/nep_0546_7493351074.wav
#   inflating: ne_np_female/wavs/nep_0546_7502845342.wav
#   inflating: ne_np_female/wavs/nep_0546_7511966218.wav
#   inflating: ne_np_female/wavs/nep_0546_7516045693.wav
#   inflating: ne_np_female/wavs/nep_0546_7521852173.wav
#   inflating: ne_np_female/wavs/nep_0546_7528731180.wav
#   inflating: ne_np_female/wavs/nep_0546_7563454464.wav
#   inflating: ne_np_female/wavs/nep_0546_7570897621.wav
#   inflating: ne_np_female/wavs/nep_0546_7578870544.wav
#   inflating: ne_np_female/wavs/nep_0546_7629032009.wav
#   inflating: ne_np_female/wavs/nep_0546_7676046381.wav
#   inflating: ne_np_female/wavs/nep_0546_7689862348.wav
#   inflating: ne_np_female/wavs/nep_0546_7696662134.wav
#   inflating: ne_np_female/wavs/nep_0546_7733176302.wav
#   inflating: ne_np_female/wavs/nep_0546_7753581863.wav
#   inflating: ne_np_female/wavs/nep_0546_7774375667.wav
#   inflating: ne_np_female/wavs/nep_0546_7806448108.wav
#   inflating: ne_np_female/wavs/nep_0546_7817976489.wav
#   inflating: ne_np_female/wavs/nep_0546_7830341512.wav
#   inflating: ne_np_female/wavs/nep_0546_7837584211.wav
#   inflating: ne_np_female/wavs/nep_0546_7857067919.wav
#   inflating: ne_np_female/wavs/nep_0546_7857473824.wav
#   inflating: ne_np_female/wavs/nep_0546_7865243262.wav
#   inflating: ne_np_female/wavs/nep_0546_7872130285.wav
#   inflating: ne_np_female/wavs/nep_0546_7916985660.wav
#   inflating: ne_np_female/wavs/nep_0546_7951389195.wav
#   inflating: ne_np_female/wavs/nep_0546_7965126677.wav
#   inflating: ne_np_female/wavs/nep_0546_7970327760.wav
#   inflating: ne_np_female/wavs/nep_0546_8029002129.wav
#   inflating: ne_np_female/wavs/nep_0546_8049723356.wav
#   inflating: ne_np_female/wavs/nep_0546_8072356175.wav
#   inflating: ne_np_female/wavs/nep_0546_8102470649.wav
#   inflating: ne_np_female/wavs/nep_0546_8122250189.wav
#   inflating: ne_np_female/wavs/nep_0546_8137014687.wav
#   inflating: ne_np_female/wavs/nep_0546_8153093399.wav
#   inflating: ne_np_female/wavs/nep_0546_8174329507.wav
#   inflating: ne_np_female/wavs/nep_0546_8209964856.wav
#   inflating: ne_np_female/wavs/nep_0546_8216444997.wav
#   inflating: ne_np_female/wavs/nep_0546_8225278732.wav
#   inflating: ne_np_female/wavs/nep_0546_8230952984.wav
#   inflating: ne_np_female/wavs/nep_0546_8252565869.wav
#   inflating: ne_np_female/wavs/nep_0546_8263716617.wav
#   inflating: ne_np_female/wavs/nep_0546_8269284289.wav
#   inflating: ne_np_female/wavs/nep_0546_8279731068.wav
#   inflating: ne_np_female/wavs/nep_0546_8288093433.wav
#   inflating: ne_np_female/wavs/nep_0546_8308270552.wav
#   inflating: ne_np_female/wavs/nep_0546_8314979469.wav
#   inflating: ne_np_female/wavs/nep_0546_8337996134.wav
#   inflating: ne_np_female/wavs/nep_0546_8384971968.wav
#   inflating: ne_np_female/wavs/nep_0546_8411565863.wav
#   inflating: ne_np_female/wavs/nep_0546_8423611413.wav
#   inflating: ne_np_female/wavs/nep_0546_8455289154.wav
#   inflating: ne_np_female/wavs/nep_0546_8457748492.wav
#   inflating: ne_np_female/wavs/nep_0546_8472528244.wav
#   inflating: ne_np_female/wavs/nep_0546_8473061866.wav
#   inflating: ne_np_female/wavs/nep_0546_8473471222.wav
#   inflating: ne_np_female/wavs/nep_0546_8481103245.wav
#   inflating: ne_np_female/wavs/nep_0546_8482838687.wav
#   inflating: ne_np_female/wavs/nep_0546_8512196296.wav
#   inflating: ne_np_female/wavs/nep_0546_8514789003.wav
#   inflating: ne_np_female/wavs/nep_0546_8524342476.wav
#   inflating: ne_np_female/wavs/nep_0546_8526588911.wav
#   inflating: ne_np_female/wavs/nep_0546_8540565259.wav
#   inflating: ne_np_female/wavs/nep_0546_8564533324.wav
#   inflating: ne_np_female/wavs/nep_0546_8664466780.wav
#   inflating: ne_np_female/wavs/nep_0546_8677425651.wav
#   inflating: ne_np_female/wavs/nep_0546_8679094848.wav
#   inflating: ne_np_female/wavs/nep_0546_8708178608.wav
#   inflating: ne_np_female/wavs/nep_0546_8722667846.wav
#   inflating: ne_np_female/wavs/nep_0546_8729437951.wav
#   inflating: ne_np_female/wavs/nep_0546_8745630097.wav
#   inflating: ne_np_female/wavs/nep_0546_8764132304.wav
#   inflating: ne_np_female/wavs/nep_0546_8764721307.wav
#   inflating: ne_np_female/wavs/nep_0546_8768125323.wav
#   inflating: ne_np_female/wavs/nep_0546_8776000401.wav
#   inflating: ne_np_female/wavs/nep_0546_8791936845.wav
#   inflating: ne_np_female/wavs/nep_0546_8843084784.wav
#   inflating: ne_np_female/wavs/nep_0546_8846826662.wav
#   inflating: ne_np_female/wavs/nep_0546_8860380762.wav
#   inflating: ne_np_female/wavs/nep_0546_8872553757.wav
#   inflating: ne_np_female/wavs/nep_0546_8882222908.wav
#   inflating: ne_np_female/wavs/nep_0546_8896555810.wav
#   inflating: ne_np_female/wavs/nep_0546_8930487507.wav
#   inflating: ne_np_female/wavs/nep_0546_8937731751.wav
#   inflating: ne_np_female/wavs/nep_0546_8955529673.wav
#   inflating: ne_np_female/wavs/nep_0546_8999349284.wav
#   inflating: ne_np_female/wavs/nep_0546_9009740875.wav
#   inflating: ne_np_female/wavs/nep_0546_9023350983.wav
#   inflating: ne_np_female/wavs/nep_0546_9046666695.wav
#   inflating: ne_np_female/wavs/nep_0546_9054535100.wav
#   inflating: ne_np_female/wavs/nep_0546_9062136918.wav
#   inflating: ne_np_female/wavs/nep_0546_9093963485.wav
#   inflating: ne_np_female/wavs/nep_0546_9131901321.wav
#   inflating: ne_np_female/wavs/nep_0546_9158934174.wav
#   inflating: ne_np_female/wavs/nep_0546_9183385297.wav
#   inflating: ne_np_female/wavs/nep_0546_9188640765.wav
#   inflating: ne_np_female/wavs/nep_0546_9233285234.wav
#   inflating: ne_np_female/wavs/nep_0546_9272279274.wav
#   inflating: ne_np_female/wavs/nep_0546_9334740893.wav
#   inflating: ne_np_female/wavs/nep_0546_9339309717.wav
#   inflating: ne_np_female/wavs/nep_0546_9392107080.wav
#   inflating: ne_np_female/wavs/nep_0546_9426840016.wav
#   inflating: ne_np_female/wavs/nep_0546_9447623973.wav
#   inflating: ne_np_female/wavs/nep_0546_9450977405.wav
#   inflating: ne_np_female/wavs/nep_0546_9500168444.wav
#   inflating: ne_np_female/wavs/nep_0546_9521503901.wav
#   inflating: ne_np_female/wavs/nep_0546_9568328624.wav
#   inflating: ne_np_female/wavs/nep_0546_9587230848.wav
#   inflating: ne_np_female/wavs/nep_0546_9588696681.wav
#   inflating: ne_np_female/wavs/nep_0546_9595432537.wav
#   inflating: ne_np_female/wavs/nep_0546_9624031563.wav
#   inflating: ne_np_female/wavs/nep_0546_9655636527.wav
#   inflating: ne_np_female/wavs/nep_0546_9673141857.wav
#   inflating: ne_np_female/wavs/nep_0546_9675837067.wav
#   inflating: ne_np_female/wavs/nep_0546_9709728566.wav
#   inflating: ne_np_female/wavs/nep_0546_9730362107.wav
#   inflating: ne_np_female/wavs/nep_0546_9732483157.wav
#   inflating: ne_np_female/wavs/nep_0546_9798842871.wav
#   inflating: ne_np_female/wavs/nep_0546_9855387476.wav
#   inflating: ne_np_female/wavs/nep_0546_9860405955.wav
#   inflating: ne_np_female/wavs/nep_0546_9879937579.wav
#   inflating: ne_np_female/wavs/nep_0546_9882317584.wav
#   inflating: ne_np_female/wavs/nep_0546_9890598208.wav
#   inflating: ne_np_female/wavs/nep_0546_9929277968.wav
#   inflating: ne_np_female/wavs/nep_0546_9954418010.wav
#   inflating: ne_np_female/wavs/nep_0546_9970131737.wav
#   inflating: ne_np_female/wavs/nep_0649_1055199537.wav
#   inflating: ne_np_female/wavs/nep_0649_1179487906.wav
#   inflating: ne_np_female/wavs/nep_0649_1734113982.wav
#   inflating: ne_np_female/wavs/nep_0649_3100264581.wav
#   inflating: ne_np_female/wavs/nep_0649_8842855723.wav
#   inflating: ne_np_female/wavs/nep_0883_0152052664.wav
#   inflating: ne_np_female/wavs/nep_0883_0523982617.wav
#   inflating: ne_np_female/wavs/nep_0883_0681743016.wav
#   inflating: ne_np_female/wavs/nep_0883_0743584260.wav
#   inflating: ne_np_female/wavs/nep_0883_1901876438.wav
#   inflating: ne_np_female/wavs/nep_0883_2369430056.wav
#   inflating: ne_np_female/wavs/nep_0883_3134182114.wav
#   inflating: ne_np_female/wavs/nep_0883_3153528178.wav
#   inflating: ne_np_female/wavs/nep_0883_3323148122.wav
#   inflating: ne_np_female/wavs/nep_0883_3724821053.wav
#   inflating: ne_np_female/wavs/nep_0883_4623121104.wav
#   inflating: ne_np_female/wavs/nep_0883_4875482575.wav
#   inflating: ne_np_female/wavs/nep_0883_5151957471.wav
#   inflating: ne_np_female/wavs/nep_0883_5250370686.wav
#   inflating: ne_np_female/wavs/nep_0883_6130774235.wav
#   inflating: ne_np_female/wavs/nep_0883_6440912992.wav
#   inflating: ne_np_female/wavs/nep_0883_6567311100.wav
#   inflating: ne_np_female/wavs/nep_0883_6745833485.wav
#   inflating: ne_np_female/wavs/nep_0883_8357619055.wav
#   inflating: ne_np_female/wavs/nep_0883_8460335842.wav
#   inflating: ne_np_female/wavs/nep_0883_8469107559.wav
#   inflating: ne_np_female/wavs/nep_0883_8723568174.wav
#   inflating: ne_np_female/wavs/nep_0883_9164164279.wav
#   inflating: ne_np_female/wavs/nep_0883_9678478624.wav
#   inflating: ne_np_female/wavs/nep_2027_0207928793.wav
#   inflating: ne_np_female/wavs/nep_2027_1887654545.wav
#   inflating: ne_np_female/wavs/nep_2027_1968598216.wav
#   inflating: ne_np_female/wavs/nep_2027_2135210073.wav
#   inflating: ne_np_female/wavs/nep_2027_4177543423.wav
#   inflating: ne_np_female/wavs/nep_2027_4199215152.wav
#   inflating: ne_np_female/wavs/nep_2027_4667640580.wav
#   inflating: ne_np_female/wavs/nep_2027_4724560602.wav
#   inflating: ne_np_female/wavs/nep_2027_4847233647.wav
#   inflating: ne_np_female/wavs/nep_2027_5576535754.wav
#   inflating: ne_np_female/wavs/nep_2027_5665575707.wav
#   inflating: ne_np_female/wavs/nep_2027_5969290132.wav
#   inflating: ne_np_female/wavs/nep_2027_6058780194.wav
#   inflating: ne_np_female/wavs/nep_2027_6330960353.wav
#   inflating: ne_np_female/wavs/nep_2027_7061155296.wav
#   inflating: ne_np_female/wavs/nep_2027_7274060085.wav
#   inflating: ne_np_female/wavs/nep_2027_8609281430.wav
#   inflating: ne_np_female/wavs/nep_2027_8813767402.wav
#   inflating: ne_np_female/wavs/nep_2027_8976817293.wav
#   inflating: ne_np_female/wavs/nep_2027_9839171653.wav
#   inflating: ne_np_female/wavs/nep_2099_0065310479.wav
#   inflating: ne_np_female/wavs/nep_2099_0119467480.wav
#   inflating: ne_np_female/wavs/nep_2099_0135911099.wav
#   inflating: ne_np_female/wavs/nep_2099_0145260888.wav
#   inflating: ne_np_female/wavs/nep_2099_0150100916.wav
#   inflating: ne_np_female/wavs/nep_2099_0153703750.wav
#   inflating: ne_np_female/wavs/nep_2099_0225459997.wav
#   inflating: ne_np_female/wavs/nep_2099_0233938126.wav
#   inflating: ne_np_female/wavs/nep_2099_0249069684.wav
#   inflating: ne_np_female/wavs/nep_2099_0376291458.wav
#   inflating: ne_np_female/wavs/nep_2099_0456476554.wav
#   inflating: ne_np_female/wavs/nep_2099_0489803071.wav
#   inflating: ne_np_female/wavs/nep_2099_0516669352.wav
#   inflating: ne_np_female/wavs/nep_2099_0558451960.wav
#   inflating: ne_np_female/wavs/nep_2099_0631115901.wav
#   inflating: ne_np_female/wavs/nep_2099_0650526524.wav
#   inflating: ne_np_female/wavs/nep_2099_0661714172.wav
#   inflating: ne_np_female/wavs/nep_2099_0784724381.wav
#   inflating: ne_np_female/wavs/nep_2099_0932150072.wav
#   inflating: ne_np_female/wavs/nep_2099_0972783303.wav
#   inflating: ne_np_female/wavs/nep_2099_0974456682.wav
#   inflating: ne_np_female/wavs/nep_2099_1045072190.wav
#   inflating: ne_np_female/wavs/nep_2099_1049912857.wav
#   inflating: ne_np_female/wavs/nep_2099_1113953471.wav
#   inflating: ne_np_female/wavs/nep_2099_1118947558.wav
#   inflating: ne_np_female/wavs/nep_2099_1127258591.wav
#   inflating: ne_np_female/wavs/nep_2099_1166564592.wav
#   inflating: ne_np_female/wavs/nep_2099_1168672510.wav
#   inflating: ne_np_female/wavs/nep_2099_1210926555.wav
#   inflating: ne_np_female/wavs/nep_2099_1239490722.wav
#   inflating: ne_np_female/wavs/nep_2099_1252103550.wav
#   inflating: ne_np_female/wavs/nep_2099_1308110078.wav
#   inflating: ne_np_female/wavs/nep_2099_1325400187.wav
#   inflating: ne_np_female/wavs/nep_2099_1493577464.wav
#   inflating: ne_np_female/wavs/nep_2099_1595751409.wav
#   inflating: ne_np_female/wavs/nep_2099_1620891327.wav
#   inflating: ne_np_female/wavs/nep_2099_1647836016.wav
#   inflating: ne_np_female/wavs/nep_2099_1652297885.wav
#   inflating: ne_np_female/wavs/nep_2099_1781886317.wav
#   inflating: ne_np_female/wavs/nep_2099_1866707562.wav
#   inflating: ne_np_female/wavs/nep_2099_1930580490.wav
#   inflating: ne_np_female/wavs/nep_2099_2087198048.wav
#   inflating: ne_np_female/wavs/nep_2099_2092695301.wav
#   inflating: ne_np_female/wavs/nep_2099_2117262310.wav
#   inflating: ne_np_female/wavs/nep_2099_2148816873.wav
#   inflating: ne_np_female/wavs/nep_2099_2156203541.wav
#   inflating: ne_np_female/wavs/nep_2099_2177646820.wav
#   inflating: ne_np_female/wavs/nep_2099_2236639076.wav
#   inflating: ne_np_female/wavs/nep_2099_2246042046.wav
#   inflating: ne_np_female/wavs/nep_2099_2261012064.wav
#   inflating: ne_np_female/wavs/nep_2099_2272015924.wav
#   inflating: ne_np_female/wavs/nep_2099_2296423149.wav
#   inflating: ne_np_female/wavs/nep_2099_2308716689.wav
#   inflating: ne_np_female/wavs/nep_2099_2312183443.wav
#   inflating: ne_np_female/wavs/nep_2099_2372342860.wav
#   inflating: ne_np_female/wavs/nep_2099_2380888505.wav
#   inflating: ne_np_female/wavs/nep_2099_2396757575.wav
#   inflating: ne_np_female/wavs/nep_2099_2444485210.wav
#   inflating: ne_np_female/wavs/nep_2099_2480341314.wav
#   inflating: ne_np_female/wavs/nep_2099_2545982989.wav
#   inflating: ne_np_female/wavs/nep_2099_2575893683.wav
#   inflating: ne_np_female/wavs/nep_2099_2583853926.wav
#   inflating: ne_np_female/wavs/nep_2099_2602572693.wav
#   inflating: ne_np_female/wavs/nep_2099_2636020806.wav
#   inflating: ne_np_female/wavs/nep_2099_2639367134.wav
#   inflating: ne_np_female/wavs/nep_2099_2651306388.wav
#   inflating: ne_np_female/wavs/nep_2099_2664037030.wav
#   inflating: ne_np_female/wavs/nep_2099_2672412961.wav
#   inflating: ne_np_female/wavs/nep_2099_2761512626.wav
#   inflating: ne_np_female/wavs/nep_2099_2765447007.wav
#   inflating: ne_np_female/wavs/nep_2099_2788612143.wav
#   inflating: ne_np_female/wavs/nep_2099_2836882307.wav
#   inflating: ne_np_female/wavs/nep_2099_2848092180.wav
#   inflating: ne_np_female/wavs/nep_2099_2898115278.wav
#   inflating: ne_np_female/wavs/nep_2099_2910899168.wav
#   inflating: ne_np_female/wavs/nep_2099_2951995413.wav
#   inflating: ne_np_female/wavs/nep_2099_2983462393.wav
#   inflating: ne_np_female/wavs/nep_2099_3210893690.wav
#   inflating: ne_np_female/wavs/nep_2099_3232335200.wav
#   inflating: ne_np_female/wavs/nep_2099_3236525110.wav
#   inflating: ne_np_female/wavs/nep_2099_3265813239.wav
#   inflating: ne_np_female/wavs/nep_2099_3287257157.wav
#   inflating: ne_np_female/wavs/nep_2099_3360592058.wav
#   inflating: ne_np_female/wavs/nep_2099_3384352377.wav
#   inflating: ne_np_female/wavs/nep_2099_3400996335.wav
#   inflating: ne_np_female/wavs/nep_2099_3420424836.wav
#   inflating: ne_np_female/wavs/nep_2099_3504794324.wav
#   inflating: ne_np_female/wavs/nep_2099_3508801376.wav
#   inflating: ne_np_female/wavs/nep_2099_3520404984.wav
#   inflating: ne_np_female/wavs/nep_2099_3532073204.wav
#   inflating: ne_np_female/wavs/nep_2099_3636838174.wav
#   inflating: ne_np_female/wavs/nep_2099_3660091245.wav
#   inflating: ne_np_female/wavs/nep_2099_3674649929.wav
#   inflating: ne_np_female/wavs/nep_2099_3683393070.wav
#   inflating: ne_np_female/wavs/nep_2099_3691524514.wav
#   inflating: ne_np_female/wavs/nep_2099_3837561282.wav
#   inflating: ne_np_female/wavs/nep_2099_3840539384.wav
#   inflating: ne_np_female/wavs/nep_2099_3862635526.wav
#   inflating: ne_np_female/wavs/nep_2099_3928220943.wav
#   inflating: ne_np_female/wavs/nep_2099_3979939574.wav
#   inflating: ne_np_female/wavs/nep_2099_4033610943.wav
#   inflating: ne_np_female/wavs/nep_2099_4050693112.wav
#   inflating: ne_np_female/wavs/nep_2099_4067442303.wav
#   inflating: ne_np_female/wavs/nep_2099_4100396715.wav
#   inflating: ne_np_female/wavs/nep_2099_4169695290.wav
#   inflating: ne_np_female/wavs/nep_2099_4176068194.wav
#   inflating: ne_np_female/wavs/nep_2099_4208594844.wav
#   inflating: ne_np_female/wavs/nep_2099_4273865064.wav
#   inflating: ne_np_female/wavs/nep_2099_4281336848.wav
#   inflating: ne_np_female/wavs/nep_2099_4379273998.wav
#   inflating: ne_np_female/wavs/nep_2099_4436163003.wav
#   inflating: ne_np_female/wavs/nep_2099_4449358732.wav
#   inflating: ne_np_female/wavs/nep_2099_4459809718.wav
#   inflating: ne_np_female/wavs/nep_2099_4461704085.wav
#   inflating: ne_np_female/wavs/nep_2099_4492131142.wav
#   inflating: ne_np_female/wavs/nep_2099_4501444493.wav
#   inflating: ne_np_female/wavs/nep_2099_4518604406.wav
#   inflating: ne_np_female/wavs/nep_2099_4519299999.wav
#   inflating: ne_np_female/wavs/nep_2099_4550495055.wav
#   inflating: ne_np_female/wavs/nep_2099_4554960550.wav
#   inflating: ne_np_female/wavs/nep_2099_4604098970.wav
#   inflating: ne_np_female/wavs/nep_2099_4631152487.wav
#   inflating: ne_np_female/wavs/nep_2099_4707771331.wav
#   inflating: ne_np_female/wavs/nep_2099_4744680160.wav
#   inflating: ne_np_female/wavs/nep_2099_4770237520.wav
#   inflating: ne_np_female/wavs/nep_2099_4770680947.wav
#   inflating: ne_np_female/wavs/nep_2099_4815781687.wav
#   inflating: ne_np_female/wavs/nep_2099_4853806205.wav
#   inflating: ne_np_female/wavs/nep_2099_4909848859.wav
#   inflating: ne_np_female/wavs/nep_2099_4913924179.wav
#   inflating: ne_np_female/wavs/nep_2099_4941967874.wav
#   inflating: ne_np_female/wavs/nep_2099_4979236297.wav
#   inflating: ne_np_female/wavs/nep_2099_5032830850.wav
#   inflating: ne_np_female/wavs/nep_2099_5048690176.wav
#   inflating: ne_np_female/wavs/nep_2099_5054938752.wav
#   inflating: ne_np_female/wavs/nep_2099_5118226450.wav
#   inflating: ne_np_female/wavs/nep_2099_5218658859.wav
#   inflating: ne_np_female/wavs/nep_2099_5234496621.wav
#   inflating: ne_np_female/wavs/nep_2099_5252626197.wav
#   inflating: ne_np_female/wavs/nep_2099_5267195265.wav
#   inflating: ne_np_female/wavs/nep_2099_5304715258.wav
#   inflating: ne_np_female/wavs/nep_2099_5307317292.wav
#   inflating: ne_np_female/wavs/nep_2099_5327754802.wav
#   inflating: ne_np_female/wavs/nep_2099_5350016637.wav
#   inflating: ne_np_female/wavs/nep_2099_5401272194.wav
#   inflating: ne_np_female/wavs/nep_2099_5502275720.wav
#   inflating: ne_np_female/wavs/nep_2099_5521500706.wav
#   inflating: ne_np_female/wavs/nep_2099_5556441385.wav
#   inflating: ne_np_female/wavs/nep_2099_5576821657.wav
#   inflating: ne_np_female/wavs/nep_2099_5618542901.wav
#   inflating: ne_np_female/wavs/nep_2099_5641131819.wav
#   inflating: ne_np_female/wavs/nep_2099_5645653931.wav
#   inflating: ne_np_female/wavs/nep_2099_5648258185.wav
#   inflating: ne_np_female/wavs/nep_2099_5660771258.wav
#   inflating: ne_np_female/wavs/nep_2099_5687427261.wav
#   inflating: ne_np_female/wavs/nep_2099_5741033366.wav
#   inflating: ne_np_female/wavs/nep_2099_5756420394.wav
#   inflating: ne_np_female/wavs/nep_2099_5760175818.wav
#   inflating: ne_np_female/wavs/nep_2099_5812748784.wav
#   inflating: ne_np_female/wavs/nep_2099_5823542172.wav
#   inflating: ne_np_female/wavs/nep_2099_5839248117.wav
#   inflating: ne_np_female/wavs/nep_2099_5868366489.wav
#   inflating: ne_np_female/wavs/nep_2099_5919356064.wav
#   inflating: ne_np_female/wavs/nep_2099_5922025842.wav
#   inflating: ne_np_female/wavs/nep_2099_5925264926.wav
#   inflating: ne_np_female/wavs/nep_2099_6039823279.wav
#   inflating: ne_np_female/wavs/nep_2099_6048396103.wav
#   inflating: ne_np_female/wavs/nep_2099_6055635685.wav
#   inflating: ne_np_female/wavs/nep_2099_6069536092.wav
#   inflating: ne_np_female/wavs/nep_2099_6109436534.wav
#   inflating: ne_np_female/wavs/nep_2099_6177486482.wav
#   inflating: ne_np_female/wavs/nep_2099_6182182497.wav
#   inflating: ne_np_female/wavs/nep_2099_6220214087.wav
#   inflating: ne_np_female/wavs/nep_2099_6283825030.wav
#   inflating: ne_np_female/wavs/nep_2099_6300428933.wav
#   inflating: ne_np_female/wavs/nep_2099_6364360672.wav
#   inflating: ne_np_female/wavs/nep_2099_6377479275.wav
#   inflating: ne_np_female/wavs/nep_2099_6379965939.wav
#   inflating: ne_np_female/wavs/nep_2099_6441499351.wav
#   inflating: ne_np_female/wavs/nep_2099_6496884013.wav
#   inflating: ne_np_female/wavs/nep_2099_6539885256.wav
#   inflating: ne_np_female/wavs/nep_2099_6573413045.wav
#   inflating: ne_np_female/wavs/nep_2099_6592070542.wav
#   inflating: ne_np_female/wavs/nep_2099_6684522365.wav
#   inflating: ne_np_female/wavs/nep_2099_6718283522.wav
#   inflating: ne_np_female/wavs/nep_2099_6752211697.wav
#   inflating: ne_np_female/wavs/nep_2099_6783914335.wav
#   inflating: ne_np_female/wavs/nep_2099_6804594335.wav
#   inflating: ne_np_female/wavs/nep_2099_6828893048.wav
#   inflating: ne_np_female/wavs/nep_2099_6880385108.wav
#   inflating: ne_np_female/wavs/nep_2099_6925166966.wav
#   inflating: ne_np_female/wavs/nep_2099_6985724525.wav
#   inflating: ne_np_female/wavs/nep_2099_6989474730.wav
#   inflating: ne_np_female/wavs/nep_2099_7067930712.wav
#   inflating: ne_np_female/wavs/nep_2099_7146853781.wav
# ...
#   inflating: ne_np_female/wavs/nep_6834_4927536600.wav
#   inflating: ne_np_female/wavs/nep_6834_4963803865.wav
#   inflating: ne_np_female/wavs/nep_6834_4981767777.wav
#   inflating: ne_np_female/wavs/nep_6834_4986165748.wav
#   inflating: ne_np_female/wavs/nep_6834_5007479984.wav
#   inflating: ne_np_female/wavs/nep_6834_5070348763.wav
#   inflating: ne_np_female/wavs/nep_6834_5122650091.wav
#   inflating: ne_np_female/wavs/nep_6834_5173085348.wav
#   inflating: ne_np_female/wavs/nep_6834_5257840596.wav
#   inflating: ne_np_female/wavs/nep_6834_5260978904.wav
#   inflating: ne_np_female/wavs/nep_6834_5295537087.wav
#   inflating: ne_np_female/wavs/nep_6834_5400599628.wav
#   inflating: ne_np_female/wavs/nep_6834_5431604112.wav
#   inflating: ne_np_female/wavs/nep_6834_5460988013.wav
#   inflating: ne_np_female/wavs/nep_6834_5592477130.wav
#   inflating: ne_np_female/wavs/nep_6834_5746530753.wav
#   inflating: ne_np_female/wavs/nep_6834_5798576935.wav
#   inflating: ne_np_female/wavs/nep_6834_5802345009.wav
#   inflating: ne_np_female/wavs/nep_6834_5877473759.wav
#   inflating: ne_np_female/wavs/nep_6834_5916619272.wav
#   inflating: ne_np_female/wavs/nep_6834_5966581481.wav
#   inflating: ne_np_female/wavs/nep_6834_5997059918.wav
#   inflating: ne_np_female/wavs/nep_6834_6045810218.wav
#   inflating: ne_np_female/wavs/nep_6834_6151409964.wav
#   inflating: ne_np_female/wavs/nep_6834_6191873103.wav
#   inflating: ne_np_female/wavs/nep_6834_6227221696.wav
#   inflating: ne_np_female/wavs/nep_6834_6231233885.wav
#   inflating: ne_np_female/wavs/nep_6834_6280964849.wav
#   inflating: ne_np_female/wavs/nep_6834_6318313501.wav
#   inflating: ne_np_female/wavs/nep_6834_6362179385.wav
#   inflating: ne_np_female/wavs/nep_6834_6392881485.wav
#   inflating: ne_np_female/wavs/nep_6834_6449523850.wav
#   inflating: ne_np_female/wavs/nep_6834_6500238641.wav
#   inflating: ne_np_female/wavs/nep_6834_6500910053.wav
#   inflating: ne_np_female/wavs/nep_6834_6501222973.wav
#   inflating: ne_np_female/wavs/nep_6834_6530919193.wav
#   inflating: ne_np_female/wavs/nep_6834_6727338945.wav
#   inflating: ne_np_female/wavs/nep_6834_6748541699.wav
#   inflating: ne_np_female/wavs/nep_6834_6786807069.wav
#   inflating: ne_np_female/wavs/nep_6834_6910353378.wav
#   inflating: ne_np_female/wavs/nep_6834_6997773130.wav
#   inflating: ne_np_female/wavs/nep_6834_7006102475.wav
#   inflating: ne_np_female/wavs/nep_6834_7022722399.wav
#   inflating: ne_np_female/wavs/nep_6834_7045652727.wav
#   inflating: ne_np_female/wavs/nep_6834_7219780083.wav
#   inflating: ne_np_female/wavs/nep_6834_7235986256.wav
#   inflating: ne_np_female/wavs/nep_6834_7318170766.wav
#   inflating: ne_np_female/wavs/nep_6834_7338170386.wav
#   inflating: ne_np_female/wavs/nep_6834_7347847874.wav
#   inflating: ne_np_female/wavs/nep_6834_7367961655.wav
#   inflating: ne_np_female/wavs/nep_6834_7400338955.wav
#   inflating: ne_np_female/wavs/nep_6834_7496761736.wav
#   inflating: ne_np_female/wavs/nep_6834_7534114675.wav
#   inflating: ne_np_female/wavs/nep_6834_7575295537.wav
#   inflating: ne_np_female/wavs/nep_6834_7581185692.wav
#   inflating: ne_np_female/wavs/nep_6834_7597189861.wav
#   inflating: ne_np_female/wavs/nep_6834_7621423521.wav
#   inflating: ne_np_female/wavs/nep_6834_7680945837.wav
#   inflating: ne_np_female/wavs/nep_6834_7738562180.wav
#   inflating: ne_np_female/wavs/nep_6834_7766238939.wav
#   inflating: ne_np_female/wavs/nep_6834_7810371653.wav
#   inflating: ne_np_female/wavs/nep_6834_7819509842.wav
#   inflating: ne_np_female/wavs/nep_6834_7828553259.wav
#   inflating: ne_np_female/wavs/nep_6834_7829580309.wav
#   inflating: ne_np_female/wavs/nep_6834_7865588733.wav
#   inflating: ne_np_female/wavs/nep_6834_7871266412.wav
#   inflating: ne_np_female/wavs/nep_6834_7899693955.wav
#   inflating: ne_np_female/wavs/nep_6834_7946628431.wav
#   inflating: ne_np_female/wavs/nep_6834_7999704556.wav
#   inflating: ne_np_female/wavs/nep_6834_8024274937.wav
#   inflating: ne_np_female/wavs/nep_6834_8130311336.wav
#   inflating: ne_np_female/wavs/nep_6834_8134424465.wav
#   inflating: ne_np_female/wavs/nep_6834_8174154863.wav
#   inflating: ne_np_female/wavs/nep_6834_8192975347.wav
#   inflating: ne_np_female/wavs/nep_6834_8304577409.wav
#   inflating: ne_np_female/wavs/nep_6834_8313324263.wav
#   inflating: ne_np_female/wavs/nep_6834_8455496039.wav
#   inflating: ne_np_female/wavs/nep_6834_8623317500.wav
#   inflating: ne_np_female/wavs/nep_6834_8628853591.wav
#   inflating: ne_np_female/wavs/nep_6834_8677691953.wav
#   inflating: ne_np_female/wavs/nep_6834_8728617166.wav
#   inflating: ne_np_female/wavs/nep_6834_8782018734.wav
#   inflating: ne_np_female/wavs/nep_6834_8836482229.wav
#   inflating: ne_np_female/wavs/nep_6834_8941342606.wav
#   inflating: ne_np_female/wavs/nep_6834_8962137317.wav
#   inflating: ne_np_female/wavs/nep_6834_9008342916.wav
#   inflating: ne_np_female/wavs/nep_6834_9092559990.wav
#   inflating: ne_np_female/wavs/nep_6834_9113225488.wav
#   inflating: ne_np_female/wavs/nep_6834_9155833217.wav
#   inflating: ne_np_female/wavs/nep_6834_9198746343.wav
#   inflating: ne_np_female/wavs/nep_6834_9278979144.wav
#   inflating: ne_np_female/wavs/nep_6834_9312649856.wav
#   inflating: ne_np_female/wavs/nep_6834_9351558392.wav
#   inflating: ne_np_female/wavs/nep_6834_9372773397.wav
#   inflating: ne_np_female/wavs/nep_6834_9385085142.wav
#   inflating: ne_np_female/wavs/nep_6834_9555445187.wav
#   inflating: ne_np_female/wavs/nep_6834_9558302314.wav
#   inflating: ne_np_female/wavs/nep_6834_9683958153.wav
#   inflating: ne_np_female/wavs/nep_6834_9709151348.wav
#   inflating: ne_np_female/wavs/nep_6834_9740563659.wav
#   inflating: ne_np_female/wavs/nep_6834_9820060770.wav
#   inflating: ne_np_female/wavs/nep_6834_9867321262.wav
#   inflating: ne_np_female/wavs/nep_7957_0009783902.wav
#   inflating: ne_np_female/wavs/nep_7957_0079907626.wav
#   inflating: ne_np_female/wavs/nep_7957_0082530407.wav
#   inflating: ne_np_female/wavs/nep_7957_0087734441.wav
#   inflating: ne_np_female/wavs/nep_7957_0140388673.wav
#   inflating: ne_np_female/wavs/nep_7957_0150211614.wav
#   inflating: ne_np_female/wavs/nep_7957_0177954418.wav
#   inflating: ne_np_female/wavs/nep_7957_0250324643.wav
#   inflating: ne_np_female/wavs/nep_7957_0328143850.wav
#   inflating: ne_np_female/wavs/nep_7957_0385367299.wav
#   inflating: ne_np_female/wavs/nep_7957_0459069016.wav
#   inflating: ne_np_female/wavs/nep_7957_0465528479.wav
#   inflating: ne_np_female/wavs/nep_7957_0539427969.wav
#   inflating: ne_np_female/wavs/nep_7957_0701885846.wav
#   inflating: ne_np_female/wavs/nep_7957_0754329079.wav
#   inflating: ne_np_female/wavs/nep_7957_0767454215.wav
#   inflating: ne_np_female/wavs/nep_7957_0918744926.wav
#   inflating: ne_np_female/wavs/nep_7957_1107857989.wav
#   inflating: ne_np_female/wavs/nep_7957_1264932788.wav
#   inflating: ne_np_female/wavs/nep_7957_1305772940.wav
#   inflating: ne_np_female/wavs/nep_7957_1388418121.wav
#   inflating: ne_np_female/wavs/nep_7957_1561164877.wav
#   inflating: ne_np_female/wavs/nep_7957_1562490176.wav
#   inflating: ne_np_female/wavs/nep_7957_1605678105.wav
#   inflating: ne_np_female/wavs/nep_7957_1717899039.wav
#   inflating: ne_np_female/wavs/nep_7957_1817204134.wav
#   inflating: ne_np_female/wavs/nep_7957_1879972607.wav
#   inflating: ne_np_female/wavs/nep_7957_1988178635.wav
#   inflating: ne_np_female/wavs/nep_7957_2004204104.wav
#   inflating: ne_np_female/wavs/nep_7957_2162495145.wav
#   inflating: ne_np_female/wavs/nep_7957_2261972825.wav
#   inflating: ne_np_female/wavs/nep_7957_2306441679.wav
#   inflating: ne_np_female/wavs/nep_7957_2420759252.wav
#   inflating: ne_np_female/wavs/nep_7957_2619070331.wav
#   inflating: ne_np_female/wavs/nep_7957_2831159128.wav
#   inflating: ne_np_female/wavs/nep_7957_2912354038.wav
#   inflating: ne_np_female/wavs/nep_7957_2945185218.wav
#   inflating: ne_np_female/wavs/nep_7957_2946235127.wav
#   inflating: ne_np_female/wavs/nep_7957_3053783668.wav
#   inflating: ne_np_female/wavs/nep_7957_3056873419.wav
#   inflating: ne_np_female/wavs/nep_7957_3122821499.wav
#   inflating: ne_np_female/wavs/nep_7957_3383714049.wav
#   inflating: ne_np_female/wavs/nep_7957_3423244460.wav
#   inflating: ne_np_female/wavs/nep_7957_3647141889.wav
#   inflating: ne_np_female/wavs/nep_7957_3764105076.wav
#   inflating: ne_np_female/wavs/nep_7957_4073378842.wav
#   inflating: ne_np_female/wavs/nep_7957_4119953298.wav
#   inflating: ne_np_female/wavs/nep_7957_4183289036.wav
#   inflating: ne_np_female/wavs/nep_7957_4268626399.wav
#   inflating: ne_np_female/wavs/nep_7957_4271932038.wav
#   inflating: ne_np_female/wavs/nep_7957_4341937167.wav
#   inflating: ne_np_female/wavs/nep_7957_4586775162.wav
#   inflating: ne_np_female/wavs/nep_7957_4596578175.wav
#   inflating: ne_np_female/wavs/nep_7957_4717090689.wav
#   inflating: ne_np_female/wavs/nep_7957_4735995613.wav
#   inflating: ne_np_female/wavs/nep_7957_4810765538.wav
#   inflating: ne_np_female/wavs/nep_7957_4817046571.wav
#   inflating: ne_np_female/wavs/nep_7957_4936747249.wav
#   inflating: ne_np_female/wavs/nep_7957_5084430899.wav
#   inflating: ne_np_female/wavs/nep_7957_5396441684.wav
#   inflating: ne_np_female/wavs/nep_7957_5435738711.wav
#   inflating: ne_np_female/wavs/nep_7957_5536664294.wav
#   inflating: ne_np_female/wavs/nep_7957_5610002623.wav
#   inflating: ne_np_female/wavs/nep_7957_5636337706.wav
#   inflating: ne_np_female/wavs/nep_7957_5683536819.wav
#   inflating: ne_np_female/wavs/nep_7957_5688499953.wav
#   inflating: ne_np_female/wavs/nep_7957_5692054824.wav
#   inflating: ne_np_female/wavs/nep_7957_5716140709.wav
#   inflating: ne_np_female/wavs/nep_7957_5786715186.wav
#   inflating: ne_np_female/wavs/nep_7957_6155198316.wav
#   inflating: ne_np_female/wavs/nep_7957_6298591264.wav
#   inflating: ne_np_female/wavs/nep_7957_6330432420.wav
#   inflating: ne_np_female/wavs/nep_7957_6689854482.wav
#   inflating: ne_np_female/wavs/nep_7957_6706814045.wav
#   inflating: ne_np_female/wavs/nep_7957_6834505402.wav
#   inflating: ne_np_female/wavs/nep_7957_7043499849.wav
#   inflating: ne_np_female/wavs/nep_7957_7061781956.wav
#   inflating: ne_np_female/wavs/nep_7957_7150839031.wav
#   inflating: ne_np_female/wavs/nep_7957_7174466874.wav
#   inflating: ne_np_female/wavs/nep_7957_7179302770.wav
#   inflating: ne_np_female/wavs/nep_7957_7218719384.wav
#   inflating: ne_np_female/wavs/nep_7957_7277032953.wav
#   inflating: ne_np_female/wavs/nep_7957_7390775219.wav
#   inflating: ne_np_female/wavs/nep_7957_7498485870.wav
#   inflating: ne_np_female/wavs/nep_7957_7595935465.wav
#   inflating: ne_np_female/wavs/nep_7957_7650570354.wav
#   inflating: ne_np_female/wavs/nep_7957_8068460898.wav
#   inflating: ne_np_female/wavs/nep_7957_8176877225.wav
#   inflating: ne_np_female/wavs/nep_7957_8208452579.wav
#   inflating: ne_np_female/wavs/nep_7957_8568488459.wav
#   inflating: ne_np_female/wavs/nep_7957_8610550659.wav
#   inflating: ne_np_female/wavs/nep_7957_8622545561.wav
#   inflating: ne_np_female/wavs/nep_7957_8648955519.wav
#   inflating: ne_np_female/wavs/nep_7957_8690887370.wav
#   inflating: ne_np_female/wavs/nep_7957_8821387069.wav
#   inflating: ne_np_female/wavs/nep_7957_8852910206.wav
#   inflating: ne_np_female/wavs/nep_7957_8962516805.wav
#   inflating: ne_np_female/wavs/nep_7957_8964412285.wav
#   inflating: ne_np_female/wavs/nep_7957_8968461916.wav
#   inflating: ne_np_female/wavs/nep_7957_9047604439.wav
#   inflating: ne_np_female/wavs/nep_7957_9062454092.wav
#   inflating: ne_np_female/wavs/nep_7957_9078420842.wav
#   inflating: ne_np_female/wavs/nep_7957_9170956763.wav
#   inflating: ne_np_female/wavs/nep_7957_9402794157.wav
#   inflating: ne_np_female/wavs/nep_7957_9501826337.wav
#   inflating: ne_np_female/wavs/nep_7957_9519606809.wav
#   inflating: ne_np_female/wavs/nep_7957_9553525282.wav
#   inflating: ne_np_female/wavs/nep_7957_9590537696.wav
#   inflating: ne_np_female/wavs/nep_7957_9607614486.wav
#   inflating: ne_np_female/wavs/nep_7957_9680379589.wav
#   inflating: ne_np_female/wavs/nep_7957_9826018123.wav
#   inflating: ne_np_female/wavs/nep_7957_9879087796.wav
#   inflating: ne_np_female/wavs/nep_7957_9918407216.wav
#   inflating: ne_np_female/wavs/nep_7957_9978009630.wav
#   inflating: ne_np_female/wavs/nep_9407_0158792615.wav
#   inflating: ne_np_female/wavs/nep_9407_0193589415.wav
#   inflating: ne_np_female/wavs/nep_9407_0400722495.wav
#   inflating: ne_np_female/wavs/nep_9407_0496486930.wav
#   inflating: ne_np_female/wavs/nep_9407_0613415585.wav
#   inflating: ne_np_female/wavs/nep_9407_0799871024.wav
#   inflating: ne_np_female/wavs/nep_9407_0996409696.wav
#   inflating: ne_np_female/wavs/nep_9407_1014345868.wav
#   inflating: ne_np_female/wavs/nep_9407_1025784594.wav
#   inflating: ne_np_female/wavs/nep_9407_1174772886.wav
#   inflating: ne_np_female/wavs/nep_9407_1190775953.wav
#   inflating: ne_np_female/wavs/nep_9407_1238310521.wav
#   inflating: ne_np_female/wavs/nep_9407_1315910654.wav
#   inflating: ne_np_female/wavs/nep_9407_1364591454.wav
#   inflating: ne_np_female/wavs/nep_9407_1387465127.wav
#   inflating: ne_np_female/wavs/nep_9407_1645226568.wav
#   inflating: ne_np_female/wavs/nep_9407_2141121852.wav
#   inflating: ne_np_female/wavs/nep_9407_2263580908.wav
#   inflating: ne_np_female/wavs/nep_9407_2333970111.wav
#   inflating: ne_np_female/wavs/nep_9407_2488033066.wav
#   inflating: ne_np_female/wavs/nep_9407_2812946804.wav
#   inflating: ne_np_female/wavs/nep_9407_3266682112.wav
#   inflating: ne_np_female/wavs/nep_9407_3483517941.wav
#   inflating: ne_np_female/wavs/nep_9407_3627853892.wav
#   inflating: ne_np_female/wavs/nep_9407_3709787182.wav
#   inflating: ne_np_female/wavs/nep_9407_3741270281.wav
#   inflating: ne_np_female/wavs/nep_9407_3822201289.wav
#   inflating: ne_np_female/wavs/nep_9407_3978206055.wav
#   inflating: ne_np_female/wavs/nep_9407_4315096359.wav
#   inflating: ne_np_female/wavs/nep_9407_4456725875.wav
#   inflating: ne_np_female/wavs/nep_9407_4546759808.wav
#   inflating: ne_np_female/wavs/nep_9407_4708385865.wav
#   inflating: ne_np_female/wavs/nep_9407_5120596605.wav
#   inflating: ne_np_female/wavs/nep_9407_5122519134.wav
#   inflating: ne_np_female/wavs/nep_9407_5725574039.wav
#   inflating: ne_np_female/wavs/nep_9407_5753543973.wav
#   inflating: ne_np_female/wavs/nep_9407_5753765750.wav
#   inflating: ne_np_female/wavs/nep_9407_5754189878.wav
#   inflating: ne_np_female/wavs/nep_9407_6166370797.wav
#   inflating: ne_np_female/wavs/nep_9407_6191215837.wav
#   inflating: ne_np_female/wavs/nep_9407_6193607404.wav
#   inflating: ne_np_female/wavs/nep_9407_6540916448.wav
#   inflating: ne_np_female/wavs/nep_9407_6625520421.wav
#   inflating: ne_np_female/wavs/nep_9407_6761600954.wav
#   inflating: ne_np_female/wavs/nep_9407_6860838920.wav
#   inflating: ne_np_female/wavs/nep_9407_7175482211.wav
#   inflating: ne_np_female/wavs/nep_9407_7452562092.wav
#   inflating: ne_np_female/wavs/nep_9407_7594762595.wav
#   inflating: ne_np_female/wavs/nep_9407_7758195523.wav
#   inflating: ne_np_female/wavs/nep_9407_7860795301.wav
#   inflating: ne_np_female/wavs/nep_9407_7958778449.wav
#   inflating: ne_np_female/wavs/nep_9407_7973941193.wav
#   inflating: ne_np_female/wavs/nep_9407_8029469037.wav
#   inflating: ne_np_female/wavs/nep_9407_8609403285.wav
#   inflating: ne_np_female/wavs/nep_9407_8654587697.wav
#   inflating: ne_np_female/wavs/nep_9407_8703001189.wav
#   inflating: ne_np_female/wavs/nep_9407_9206137835.wav
#   inflating: ne_np_female/wavs/nep_9407_9290636989.wav
#   inflating: ne_np_female/wavs/nep_9407_9295760097.wav
#   inflating: ne_np_female/wavs/nep_9407_9451979543.wav
#   inflating: ne_np_female/wavs/nep_9407_9558473002.wav
#   inflating: ne_np_female/wavs/nep_9407_9632964143.wav
#   inflating: ne_np_female/wavs/nep_9407_9646005575.wav
#   inflating: ne_np_female/wavs/nep_9407_9974252924.wav
# line_index.tsv	wavs

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from datasets import load_dataset

colnames=['path','text'] 
df  = pd.read_csv('/content/ne_np_female/line_index.tsv',sep='\t',header=None,names = colnames)
df['path'] = '/content/ne_np_female/wavs/'+df['path'] +'.wav'

train, test = train_test_split(df, test_size=0.1)

train.to_csv('/content/ne_np_female/line_index_train.csv')
test.to_csv('/content/ne_np_female/line_index_test.csv')
common_voice_train = load_dataset('csv', data_files='/content/ne_np_female/line_index_train.csv',split= 'train')
common_voice_test = load_dataset('csv', data_files='/content/ne_np_female/line_index_test.csv',split = 'train')
df.head()
# Out:
# Using custom data configuration default-2802c4f421cdca07
# Downloading and preparing dataset csv/default (download: Unknown size, generated: Unknown size, post-processed: Unknown size, total: Unknown size) to /root/.cache/huggingface/datasets/csv/default-2802c4f421cdca07/0.0.0/2a88c45fed596f9421a2e7f74ab1a3cd012ef75210a5dc1950e8d60ca8d9c66c...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-2802c4f421cdca07/0.0.0/2a88c45fed596f9421a2e7f74ab1a3cd012ef75210a5dc1950e8d60ca8d9c66c. Subsequent calls will reuse this data.
# Using custom data configuration default-e1d91a7987c9f482
# Downloading and preparing dataset csv/default (download: Unknown size, generated: Unknown size, post-processed: Unknown size, total: Unknown size) to /root/.cache/huggingface/datasets/csv/default-e1d91a7987c9f482/0.0.0/2a88c45fed596f9421a2e7f74ab1a3cd012ef75210a5dc1950e8d60ca8d9c66c...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-e1d91a7987c9f482/0.0.0/2a88c45fed596f9421a2e7f74ab1a3cd012ef75210a5dc1950e8d60ca8d9c66c. Subsequent calls will reuse this data.
#                                                 path                                               text
# 0  /content/ne_np_female/wavs/nep_0258_0119737288...  दीपा धामीको जन्म सुदूरपश्चिम नेपालको बझाङ जिल्...
# 1  /content/ne_np_female/wavs/nep_0258_0461984530...  डिग्रा देवीको जन्म सुदूरपश्चिम नेपालको बझाङ जि...
# 2  /content/ne_np_female/wavs/nep_0258_0576399736...  टेकबहादुर ऐरको जन्म सुदूरपश्चिम नेपालको डडेलधु...
# 3  /content/ne_np_female/wavs/nep_0258_0707220145...  सुमन शेखरमानन्धर नेपालको कृषि अर्थविद् तथा गाय...
# 4  /content/ne_np_female/wavs/nep_0258_0838627393...  आधिकारिक रूपमा पहिलो नेपाली चलचित्र नायक शिव श...

# %% [markdown]
# Many ASR datasets only provide the target text, `'sentence'` for each audio file `'path'`. Common Voice actually provides much more information about each audio file, such as the `'accent'`, etc. However, we want to keep the notebook as general as possible, so that we will only consider the transcribed text for fine-tuning.

# %%
common_voice_train = common_voice_train.remove_columns(["Unnamed: 0"])
common_voice_test = common_voice_test.remove_columns(["Unnamed: 0"])

# %% [markdown]
# Let's write a short function to display some random samples of the dataset and run it a couple of times to get a feeling for the transcriptions.

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))


def show_rand(dataset,num_examples=10):
  df = dataset.sample(n = num_examples, random_state = 2) 
  display(HTML(df.to_html()))

# %%
common_voice_train
# Out:
# Dataset({
#     features: ['path', 'text'],
#     num_rows: 1857
# })

# %%
show_random_elements(common_voice_train.remove_columns(["path"]), num_examples=2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>चितवन राष्ट्रिय निकुञ्ज विश्वभरका पर्यटकहरूमाझ निकै प्रख्यात छ</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ताराको अर्धव्यास करिब दस हजार एक सय पटक सूर्यको ज्योति जति</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Alright! The transcriptions look fairly clean. Having translated the transcribed sentences (I'm sadly not a native speaker in Turkish), it seems that the language corresponds more to written text than noisy dialogue. This makes sense taking into account that [Common Voice](https://huggingface.co/datasets/common_voice) is a crowd-sourced read speech corpus.

# %% [markdown]
# We can see that the transcriptions contain some special characters, such as `,.?!;:`. Without a language model, it is much harder to classify speech chunks to such special characters because they don't really correspond to a characteristic sound unit. *E.g.*, the letter `"s"` has a more or less clear sound, whereas the special character `"."` does not.
# Also in order to understand the meaning of a speech signal, it is usually not necessary to include special characters in the transcription.
#
# In addition, we normalize the text to only have lower case letters and append a word separator token at the end.

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\“\%\‘\”\�]'

def remove_special_characters(batch):
    batch["text"] = re.sub(chars_to_ignore_regex, '', batch["text"]).lower() + " "
    return batch

# %%
common_voice_train = common_voice_train.map(remove_special_characters)
common_voice_test = common_voice_test.map(remove_special_characters)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1857.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=207.0), HTML(value='')))

# %%
show_random_elements(common_voice_train.remove_columns(["path"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>अर्को कृतकमा यो रोग निरोधक क्षमता हुँदैन संक्रमण पछि रोग लाग्छ मर्छ</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>अमेरिकी अभिनेता र आवाज अभिनेता</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>क्रोगरका धेरै उत्पदनहरू बजारमा आएका छन्</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>देवराज जोशी त्रिभुवन विश्वविद्यालयबाट शिक्षाशास्त्रमा स्नातक हुनुहुन्छ</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>बिमला पन्तको जन्म सुदूरपश्चिम नेपालको डडेलधुरा जिल्लामा भएको हो</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>आजा पनि टारकेरावारीको रातमाटे जङ्गलमा किराँतहरूको चिहान यद्दावधि पाइने दाबी स्थानीय श्रोतव्यक्ति दीर्धराज पौडेलको छ</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>इन्टरनेसनल बिजिनेस मेसिनले आफ्नो व्यवसाय विश्वभर फैलाएको छ</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>व्यावसायिक इटालियन फुटबल क्लब</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>टस्क्यानीमा रहेको इटालियन सहर</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>कालोटाउके बगेडी नेपालमा पाइने एक प्रकारको चराको नाम हो</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Good! This looks better. We have removed most special characters from transcriptions and normalized them to lower-case only.
#
# In CTC, it is common to classify speech chunks into letters, so we will do the same here.
# Let's extract all distinct letters of the training and test data and build our vocabulary from this set of letters.
#
# We write a mapping function that concatenates all transcriptions into one long transcription and then transforms the string into a set of chars.
# It is important to pass the argument `batched=True` to the `map(...)` function so that the mapping function has access to all transcriptions at once.

# %%
def extract_all_chars(batch):
  all_text = " ".join(batch["text"])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}

# %%
vocab_train = common_voice_train.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=common_voice_train.column_names)
vocab_test = common_voice_test.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=common_voice_test.column_names)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %% [markdown]
# Now, we create the union of all distinct letters in the training dataset and test dataset and convert the resulting list into an enumerated dictionary.

# %%
vocab_list = list(set(vocab_train["vocab"][0]) | set(vocab_test["vocab"][0]))

# %%
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
vocab_dict
# Out:
# {' ': 18,
#  'ँ': 34,
#  'ं': 36,
#  'ः': 56,
#  'अ': 46,
#  'आ': 41,
#  'इ': 27,
#  'ई': 47,
#  'उ': 6,
#  'ऊ': 2,
#  'ऋ': 16,
#  'ए': 33,
#  'ऐ': 11,
#  'ओ': 31,
#  'औ': 30,
#  'क': 61,
#  'ख': 38,
#  'ग': 44,
#  'घ': 13,
#  'ङ': 21,
#  'च': 14,
#  'छ': 55,
#  'ज': 17,
#  'झ': 19,
#  'ञ': 15,
#  'ट': 37,
#  'ठ': 5,
#  'ड': 39,
#  'ढ': 25,
#  'ण': 58,
#  'त': 4,
#  'थ': 29,
#  'द': 43,
#  'ध': 35,
#  'न': 28,
#  'प': 53,
#  'फ': 12,
#  'ब': 8,
#  'भ': 59,
#  'म': 22,
#  'य': 23,
#  'र': 3,
#  'ल': 1,
#  'व': 42,
#  'श': 20,
#  'ष': 45,
#  'स': 49,
#  'ह': 7,
#  'ा': 40,
#  'ि': 10,
#  'ी': 0,
#  'ु': 54,
#  'ू': 50,
#  'ृ': 9,
#  'े': 51,
#  'ै': 32,
#  'ो': 24,
#  'ौ': 57,
#  '्': 52,
#  'ॠ': 48,
#  '८': 62,
#  '\u200c': 26,
#  '\u200d': 60}

# %% [markdown]
# Cool, we see that all letters of the alphabet occur in the dataset (which is not really surprising) and we also extracted the special characters `" "` and `'`. Note that we did not exclude those special characters because:
#
# - The model has to learn to predict when a word is finished or else the model prediction would always be a sequence of chars which would make it impossible to separate words from each other.
# - From the transcriptions above it seems that words that include an apostrophe, such as `maktouf'un` do exist in Turkish, so I decided to keep the apostrophe in the dataset. This might be a wrong assumption though.
#
# One should always keep in mind that the data-preprocessing is a very important step before training your model. E.g., we don't want our model to differentiate between `a` and `A` just because we forgot to normalize the data. The difference between `a` and `A` does not depend on the "sound" of the letter at all, but more on grammatical rules - *e.g.* use a capitalized letter at the beginning of the sentence. So it is sensible to remove the difference between capitalized and non-capitalized letters so that the model has an easier time learning to transcribe speech.
#
# It is always advantageous to get help from a native speaker of the language you would like to transcribe to verify whether the assumptions you made are sensible, *e.g.* I should have made sure that keeping `'`, but removing other special characters is a sensible choice for Turkish.

# %% [markdown]
# To make it clearer that `" "` has its own token class, we give it a more visible character `|`. In addition, we also add an "unknown" token so that the model can later deal with characters not encountered in Common Voice's training set.
#
# Finally, we also add a padding token that corresponds to CTC's "*blank token*". The "blank token" is a core component of the CTC algorithm. For more information, please take a look at the "Alignment" section [here](https://distill.pub/2017/ctc/).

# %%
vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]

# %%
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
len(vocab_dict)
# Out:
# 65

# %% [markdown]
# Cool, now our vocabulary is complete and consists of 39 tokens, which means that the linear layer that we will add on top of the pretrained XLSR-Wav2Vec2 checkpoint will have an output dimension of 39.

# %% [markdown]
# Let's now save the vocabulary as a json file.

# %%
import json
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %% [markdown]
# In a final step, we use the json file to instantiate an object of the `Wav2Vec2CTCTokenizer` class.

# %%
from transformers import Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

# %% [markdown]
# Next, we will create the feature extractor.

# %% [markdown]
# ### Create XLSR-Wav2Vec2 Feature Extractor

# %% [markdown]
# Speech is a continuous signal and to be treated by computers, it first has to be discretized, which is usually called **sampling**. The sampling rate hereby plays an important role in that it defines how many data points of the speech signal are measured per second. Therefore, sampling with a higher sampling rate results in a better approximation of the *real* speech signal but also necessitates more values per second.
#
# A pretrained checkpoint expects its input data to have been sampled more or less from the same distribution as the data it was trained on. The same speech signals sampled at two different rates have a very different distribution, *e.g.*, doubling the sampling rate results in data points being twice as long. Thus,
# before fine-tuning a pretrained checkpoint of an ASR model, it is crucial to verify that the sampling rate of the data that was used to pretrain the model matches the sampling rate of the dataset used to fine-tune the model.
#
# XLSR-Wav2Vec2 was pretrained on the audio data of [Babel](https://huggingface.co/datasets/librispeech_asr),
# [Multilingual LibriSpeech (MLS)](https://ai.facebook.com/blog/a-new-open-data-set-for-multilingual-speech-research/), and [Common Voice](https://huggingface.co/datasets/common_voice). Most of those datasets were sampled at 16kHz, so that Common Voice, sampled at 48kHz, has to be downsampled to 16kHz for training. Therefore, we will have to downsample our fine-tuning data to 16kHz in the following.

# %% [markdown]
# A XLSR-Wav2Vec2 feature extractor object requires the following parameters to be instantiated:
#
# - `feature_size`: Speech models take a sequence of feature vectors as an input. While the length of this sequence obviously varies, the feature size should not. In the case of Wav2Vec2, the feature size is 1 because the model was trained on the raw speech signal ${}^2$.
# - `sampling_rate`: The sampling rate at which the model is trained on.
# - `padding_value`: For batched inference, shorter inputs need to be padded with a specific value
# - `do_normalize`: Whether the input should be *zero-mean-unit-variance* normalized or not. Usually, speech models perform better when normalizing the input
# - `return_attention_mask`: Whether the model should make use of an `attention_mask` for batched inference. In general, XLSR-Wav2Vec2 models should **always** make use of the `attention_mask`.

# %%
from transformers import Wav2Vec2FeatureExtractor

feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=True)

# %% [markdown]
# Great, XLSR-Wav2Vec2's feature extraction pipeline is thereby fully defined!
#
# To make the usage of XLSR-Wav2Vec2 as user-friendly as possible, the feature extractor and tokenizer are *wrapped* into a single `Wav2Vec2Processor` class so that one only needs a `model` and `processor` object.

# %%
from transformers import Wav2Vec2Processor

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %% [markdown]
# If one wants to re-use the just created processor and the fine-tuned model of this notebook, one can mount his/her google drive to the notebook and save all relevant files there. To do so, please uncomment the following lines.
#
# We will give the fine-tuned model the name `"wav2vec2-large-xlsr-turkish-demo"`.

# %%
# from google.colab import drive
# drive.mount('/content/gdrive/')

# %%
processor.save_pretrained("/content/wav2vec2-large-xlsr-nepali")

# %% [markdown]
# Next, we can prepare the dataset.

# %% [markdown]
# ### Preprocess Data
#
# So far, we have not looked at the actual values of the speech signal but just kept the path to its file in the dataset. `XLSR-Wav2Vec2` expects the audio file in the format of a 1-dimensional array, so in the first step, let's load all audio files into the dataset object.
#
# Let's first check the serialization format of the downloaded audio files by looking at the first training sample.

# %%
common_voice_train[0]
# Out:
# {'path': '/content/ne_np_female/wavs/nep_0546_5145517817.wav',
#  'text': 'दक्षिण अस्ट्रेलियाको राजधानी '}

# %% [markdown]
# Alright, the audio file is saved in the `.mp3` format. The `.mp3` format is usually not the easiest format to deal with. We found that the [`torchaudio`](https://pytorch.org/audio/stable/index.html) library works best for reading in `.mp3` data.
#
# An audio file usually stores both its values and the sampling rate with which the speech signal was digitalized. We want to store both in the dataset and write a `map(...)` function accordingly.

# %%
import torchaudio

def speech_file_to_array_fn(batch):
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    batch["speech"] = speech_array[0].numpy()
    batch["sampling_rate"] = sampling_rate
    batch["target_text"] = batch["text"]
    return batch

# %%
common_voice_train = common_voice_train.map(speech_file_to_array_fn, remove_columns=common_voice_train.column_names)
common_voice_test = common_voice_test.map(speech_file_to_array_fn, remove_columns=common_voice_test.column_names)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1857.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=207.0), HTML(value='')))

# %% [markdown]
# Great, now we've successfully read in all the audio files, but since we know that Common Voice is sampled at 48kHz, we need to resample the audio files to 16kHz.
#
# Let's make use of the [`librosa`](https://github.com/librosa/librosa) library to downsample the data.

# %%
import librosa
import numpy as np

def resample(batch):
    batch["speech"] = librosa.resample(np.asarray(batch["speech"]), 48_000, 16_000)
    batch["sampling_rate"] = 16_000
    return batch

# %%
common_voice_train = common_voice_train.map(resample, num_proc=4)
common_voice_test = common_voice_test.map(resample, num_proc=4)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='#2', max=464.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=464.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#1', max=464.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#0', max=465.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#0', max=52.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#1', max=52.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#2', max=52.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=51.0, style=ProgressStyle(description_width='ini…

# %% [markdown]
# This seemed to have worked! Let's listen to a couple of audio files to better understand the dataset and verify that the audio was correctly loaded.
#
# **Note**: *You can click the following cell a couple of times to listen to different speech samples.*

# %%
import IPython.display as ipd
import numpy as np
import random

rand_int = random.randint(0, len(common_voice_train)-1)

ipd.Audio(data=np.asarray(common_voice_train[rand_int]["speech"]), autoplay=True, rate=16000)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# It can be heard, that the speakers change along with their speaking rate, accent, and background environment, etc. Overall, the recordings sound acceptably clear though, which is to be expected from a crowd-sourced read speech corpus.
#
# Let's do a final check that the data is correctly prepared, by printing the shape of the speech input, its transcription, and the corresponding sampling rate.
#
# **Note**: *You can click the following cell a couple of times to verify multiple samples.*

# %%
rand_int = random.randint(0, len(common_voice_train)-1)

print("Target text:", common_voice_train[rand_int]["target_text"])
print("Input array shape:", np.asarray(common_voice_train[rand_int]["speech"]).shape)
print("Sampling rate:", common_voice_train[rand_int]["sampling_rate"])
# Out:
# Target text: फ्रान्सको राजनीतिक पार्टी
# Input array shape: (36059,)
# Sampling rate: 16000

# %% [markdown]
# Good! Everything looks fine - the data is a 1-dimensional array, the sampling rate always corresponds to 16kHz, and the target text is normalized.

# %% [markdown]
# Finally, we can process the dataset to the format expected by the model for training. We will again make use of the `map(...)` function.
#
# First, we check that the data samples have the same sampling rate of 16kHz.
# Second, we extract the `input_values` from the loaded audio file. In our case, this includes only normalization, but for other speech models, this step could correspond to extracting, *e.g.* [Log-Mel features](https://en.wikipedia.org/wiki/Mel-frequency_cepstrum).
# Third, we encode the transcriptions to label ids.
#
# **Note**: This mapping function is a good example of how the `Wav2Vec2Processor` class should be used. In "normal" context, calling `processor(...)` is redirected to `Wav2Vec2FeatureExtractor`'s call method. When wrapping the processor into the `as_target_processor` context, however, the same method is redirected to `Wav2Vec2CTCTokenizer`'s call method.
# For more information please check the [docs](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#transformers.Wav2Vec2Processor.__call__).

# %%
def prepare_dataset(batch):
    # check that all files have the correct sampling rate
    assert (
        len(set(batch["sampling_rate"])) == 1
    ), f"Make sure all inputs have the same sampling rate of {processor.feature_extractor.sampling_rate}."

    batch["input_values"] = processor(batch["speech"], sampling_rate=batch["sampling_rate"][0]).input_values
    
    with processor.as_target_processor():
        batch["labels"] = processor(batch["target_text"]).input_ids
    return batch

# %%
common_voice_train = common_voice_train.map(prepare_dataset, remove_columns=common_voice_train.column_names, batch_size=8, num_proc=4, batched=True)
common_voice_test = common_voice_test.map(prepare_dataset, remove_columns=common_voice_test.column_names, batch_size=8, num_proc=4, batched=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# HBox(children=(FloatProgress(value=0.0, description='#2', max=58.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#0', max=59.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=58.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#1', max=58.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#0', max=7.0, style=ProgressStyle(description_width='init…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=7.0, style=ProgressStyle(description_width='init…
# HBox(children=(FloatProgress(value=0.0, description='#1', max=7.0, style=ProgressStyle(description_width='init…
# HBox(children=(FloatProgress(value=0.0, description='#2', max=7.0, style=ProgressStyle(description_width='init…

# %% [markdown]
# ## Training
#
# The data is processed so that we are ready to start setting up the training pipeline. We will make use of 🤗's [Trainer](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer) for which we essentially need to do the following:
#
# - Define a data collator. In contrast to most NLP models, XLSR-Wav2Vec2 has a much larger input length than output length. *E.g.*, a sample of input length 50000 has an output length of no more than 100. Given the large input sizes, it is much more efficient to pad the training batches dynamically meaning that all training samples should only be padded to the longest sample in their batch and not the overall longest sample. Therefore, fine-tuning XLSR-Wav2Vec2 requires a special padding data collator, which we will define below
#
# - Evaluation metric. During training, the model should be evaluated on the word error rate. We should define a `compute_metrics` function accordingly
#
# - Load a pretrained checkpoint. We need to load a pretrained checkpoint and configure it correctly for training.
#
# - Define the training configuration.
#
# After having fine-tuned the model, we will correctly evaluate it on the test data and verify that it has indeed learned to correctly transcribe speech.

# %% [markdown]
# ### Set-up Trainer
#
# Let's start by defining the data collator. The code for the data collator was copied from [this example](https://github.com/huggingface/transformers/blob/9a06b6b11bdfc42eea08fa91d0c737d1863c99e3/examples/research_projects/wav2vec2/run_asr.py#L81).
#
# Without going into too many details, in contrast to the common data collators, this data collator treats the `input_values` and `labels` differently and thus applies to separate padding functions on them (again making use of XLSR-Wav2Vec2's context manager). This is necessary because in speech input and output are of different modalities meaning that they should not be treated by the same padding function.
# Analogous to the common data collators, the padding tokens in the labels with `-100` so that those tokens are **not** taken into account when computing the loss.

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# Next, the evaluation metric is defined. As mentioned earlier, the
# predominant metric in ASR is the word error rate (WER), hence we will use it in this notebook as well.

# %%
from datasets import load_metric

wer_metric = load_metric("wer")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1764.0, style=ProgressStyle(description…

# %% [markdown]
# The model will return a sequence of logit vectors:
# $\mathbf{y}_1, \ldots, \mathbf{y}_m$ with $\mathbf{y}_1 = f_{\theta}(x_1, \ldots, x_n)[0]$ and $n >> m$.
#
# A logit vector $\mathbf{y}_1$ contains the log-odds for each word in the vocabulary we defined earlier, thus $\text{len}(\mathbf{y}_i) =$ `config.vocab_size`. We are interested in the most likely prediction of the model and thus take the `argmax(...)` of the logits. Also, we transform the encoded labels back to the original string by replacing `-100` with the `pad_token_id` and decoding the ids while making sure that consecutive tokens are **not** grouped to the same token in CTC style ${}^1$.

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# Now, we can load the pretrained `XLSR-Wav2Vec2` checkpoint. The tokenizer's `pad_token_id` must be to define the model's `pad_token_id` or in the case of `Wav2Vec2ForCTC` also CTC's *blank token* ${}^2$. To save GPU memory, we enable PyTorch's [gradient checkpointing](https://pytorch.org/docs/stable/checkpoint.html) and also set the loss reduction to "*mean*".
#
# Because the dataset is quite small (~6h of training data) and because Common Voice is quite noisy, fine-tuning Facebook's [wav2vec2-large-xlsr-53 checkpoint](https://huggingface.co/facebook/wav2vec2-large-xlsr-53) seems to require some hyper-parameter tuning. Therefore, I had to play around a bit with different values for dropout, [SpecAugment](https://arxiv.org/abs/1904.08779)'s masking dropout rate, layer dropout, and the learning rate until training seemed to be stable enough.
#
# **Note**: When using this notebook to train XLSR-Wav2Vec2 on another language of Common Voice those hyper-parameter settings might not work very well. Feel free to adapt those depending on your use case.

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-large-xlsr-53", 
    attention_dropout=0.1,
    hidden_dropout=0.1,
    feat_proj_dropout=0.0,
    mask_time_prob=0.05,
    layerdrop=0.1,
    gradient_checkpointing=True, 
    ctc_loss_reduction="mean", 
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer)
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1451.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1261920069.0, style=ProgressStyle(descr…
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-xlsr-53 and are newly initialized: ['lm_head.bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# The first component of XLSR-Wav2Vec2 consists of a stack of CNN layers that are used to extract acoustically meaningful - but contextually independent - features from the raw speech signal. This part of the model has already been sufficiently trained during pretraining and as stated in the [paper](https://arxiv.org/pdf/2006.13979.pdf) does not need to be fine-tuned anymore.
# Thus, we can set the `requires_grad` to `False` for all parameters of the *feature extraction* part.

# %%
model.freeze_feature_extractor()

# %% [markdown]
# In a final step, we define all parameters related to training.
# To give more explanation on some of the parameters:
# - `group_by_length` makes training more efficient by grouping training samples of similar input length into one batch. This can significantly speed up training time by heavily reducing the overall number of useless padding tokens that are passed through the model
# - `learning_rate` and `weight_decay` were heuristically tuned until fine-tuning has become stable. Note that those parameters strongly depend on the Common Voice dataset and might be suboptimal for other speech datasets.
#
# For more explanations on other parameters, one can take a look at the [docs](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer#trainingarguments).
#
# **Note**: If one wants to save the trained models in his/her google drive the commented-out `output_dir` can be used instead.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir="/content/wav2vec2-large-xlsr-nepali",
  group_by_length=True,
  per_device_train_batch_size=16,
  gradient_accumulation_steps=2,
  evaluation_strategy="steps",
  num_train_epochs=50,
  fp16=True,
  save_steps=1000,
  eval_steps=1000,
  logging_steps=100,
  learning_rate=3e-4,
  warmup_steps=250,
  save_total_limit=2,
  load_best_model_at_end = True,  # This will ensure your best model will be uploaded to W&B
  metric_for_best_model='wer',    # Load best model based on "wer", not eval loss
  greater_is_better=False,
)

# %% [markdown]
# Now, all instances can be passed to Trainer and we are ready to start training!

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=common_voice_train,
    eval_dataset=common_voice_test,
    tokenizer=processor.feature_extractor,
)

# %% [markdown]
# ---
#
# ${}^1$ To allow models to become independent of the speaker rate, in CTC, consecutive tokens that are identical are simply grouped as a single token. However, the encoded labels should not be grouped when decoding since they don't correspond to the predicted tokens of the model, which is why the `group_tokens=False` parameter has to be passed. If we wouldn't pass this parameter a word like `"hello"` would incorrectly be encoded, and decoded as `"helo"`.
#
# ${}^2$ The blank token allows the model to predict a word, such as `"hello"` by forcing it to insert the blank token between the two l's. A CTC-conform prediction of `"hello"` of our model would be `[PAD] [PAD] "h" "e" "e" "l" "l" [PAD] "l" "o" "o" [PAD]`.

# %% [markdown]
# ### Training

# %% [markdown]
# Training will take between 180 and 240 minutes depending on the GPU allocated to this notebook. While the trained model yields somewhat satisfying results on *Common Voice*'s test data of Turkish, it is by no means an optimally fine-tuned model. The purpose of this notebook is to demonstrate how XLSR-Wav2Vec2's [checkpoint](https://huggingface.co/facebook/wav2vec2-large-xlsr-53) can be fine-tuned on a low-resource ASR dataset.
#
# In case you want to use this google colab to fine-tune your model, you should make sure that your training doesn't stop due to inactivity. A simple hack to prevent this is to paste the following code into the console of this tab (*right mouse click -> inspect -> Console tab and insert code*).

# %% [markdown]
# ```javascript
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton,60000);
# ```

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='2900' max='2900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2900/2900 4:44:43, Epoch 49/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.167500</td>
#       <td>0.357761</td>
#       <td>0.448697</td>
#       <td>28.218100</td>
#       <td>7.336000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.060300</td>
#       <td>0.398738</td>
#       <td>0.410982</td>
#       <td>27.730000</td>
#       <td>7.465000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2900, training_loss=0.7516725732540263, metrics={'train_runtime': 17097.5211, 'train_samples_per_second': 0.17, 'total_flos': 1.4315953434130276e+19, 'epoch': 49.99, 'init_mem_cpu_alloc_delta': 341978, 'init_mem_gpu_alloc_delta': 1262021632, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 2461251, 'train_mem_gpu_alloc_delta': 5042393600, 'train_mem_cpu_peaked_delta': 150633147, 'train_mem_gpu_peaked_delta': 3859083264})

# %%
import os 
os.chdir("/content")

# !sudo apt-get install git-lfs
# !transformers-cli login
# !transformers-cli repo create wav2vec2-xlsr-nepali
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.3.4-1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# 2021-03-23 22:10:50.294449: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
#
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#
# Username: gagan3012
# Password:
# Login successful
# Your token: EnMLiSkFfzebrIYozGXDtqpeYMHFgLXUwEnlZSoBONNRaxxfSRfprbMvUszDZLMmlZsykShsMzIcldUyCCJMyPZgdDoTXULUjxJnuqLJFgWdIckzWnknspjKCoZDJPjM
#
# Your token has been saved to /root/.huggingface/token
# 2021-03-23 22:11:04.130789: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# git version 2.17.1
# Error: unknown flag: --version
#
# Sorry, no usage text found for "git-lfs"
#
# You are about to create gagan3012/wav2vec2-xlsr-nepali
# Proceed? [Y/n] y
#
# Your repo now lives at:
#   https://huggingface.co/gagan3012/wav2vec2-xlsr-nepali
#
# You can clone it locally with the command below, and commit/push as usual.
#
#   git clone https://huggingface.co/gagan3012/wav2vec2-xlsr-nepali

# %%
# !git lfs install
# !git clone https://gagan3012:Mother456@huggingface.co/gagan3012/wav2vec2-xlsr-nepali

# !cp -r /content/wav2vec2-large-xlsr-nepali/checkpoint-2000/. /content/wav2vec2-xlsr-nepali/
# Out:
# Error: Failed to call git rev-parse --git-dir --show-toplevel: "fatal: not a git repository (or any of the parent directories): .git\n"
# Git LFS initialized.
# Cloning into 'wav2vec2-xlsr-nepali'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0)
# Unpacking objects: 100% (3/3), done.

# %%
# !git config --global user.email "gbhatia880@gmail.com"
# !git config --global user.name "Gagan Bhatia"

import os 
os.chdir("/content/wav2vec2-xlsr-nepali")

# !git add .
# !git commit -m "Initial commit"
# !git push
# Out:
# [main e75e473] Initial commit
#  3 files changed, 3 insertions(+)
#  create mode 100644 special_tokens_map.json
#  create mode 100644 tokenizer_config.json
#  create mode 100644 vocab.json
# Counting objects: 5, done.
# Delta compression using up to 4 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 803 bytes | 803.00 KiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0)
# To https://huggingface.co/gagan3012/wav2vec2-xlsr-nepali
#    6e2fe90..e75e473  main -> main

# %% [markdown]
# The training loss goes down and we can see that the WER on the test set also improves nicely. Because this notebook is just for demonstration purposes, we can stop here.
#
# The resulting model of this notebook has been saved to [`patrickvonplaten/wav2vec2-large-xlsr-turkish-demo`](https://huggingface.co/patrickvonplaten/wav2vec2-large-xlsr-turkish-demo)
#
# As a final check, let's load the model and verify that it indeed has learned to transcribe Turkish speech.
#
# Let's first load the pretrained checkpoint.

# %%
model = Wav2Vec2ForCTC.from_pretrained("gagan3012/wav2vec2-xlsr-nepali").to("cuda")
processor = Wav2Vec2Processor.from_pretrained("gagan3012/wav2vec2-xlsr-nepali")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=707.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=138.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=85.0, style=ProgressStyle(description_w…
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.

# %% [markdown]
# Now, we will just take the first example of the test set, run it through the model and take the `argmax(...)` of the logits to retrieve the predicted token ids.

# %%
input_dict = processor(common_voice_test["input_values"][0], return_tensors="pt", padding=True)

logits = model(input_dict.input_values.to("cuda")).logits

pred_ids = torch.argmax(logits, dim=-1)[0]
# Out:
# It is strongly recommended to pass the ``sampling_rate`` argument to this function.Failing to do so can result in silent errors that might be hard to debug.

# %%
common_voice_test_transcription
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'path', 'sentence'],
#     num_rows: 207
# })

# %% [markdown]
# We adapted `common_voice_test` quite a bit so that the dataset instance does not contain the original sentence label anymore. Thus, we re-use the original dataset to get the label of the first example.

# %%
common_voice_test_transcription = load_dataset('csv', data_files='/content/ne_np_female/line_index_test.csv',split = 'train')
# Out:
# Using custom data configuration default-33e60b51d29931aa
# Reusing dataset csv (/root/.cache/huggingface/datasets/csv/default-33e60b51d29931aa/0.0.0/2a88c45fed596f9421a2e7f74ab1a3cd012ef75210a5dc1950e8d60ca8d9c66c)

# %% [markdown]
# Finally, we can decode the example.

# %%
print("Prediction:")
print(processor.decode(pred_ids))

print("\nReference:")
print(common_voice_test_transcription["sentence"][0].lower())
# Out:
# Prediction:
# फिलिप मोरेस अन्तर्राष्ट्रिय इन्कले विभिन्न क्षेत्रमा कार्य गरिरहेको छ
#
# Reference:
# पारानाको ब्राजिली राज्यमा रहेको राजधानी

# %%
import os 
os.chdir("/content")

# !wget https://www.openslr.org/resources/43/ne_np_female.zip
# !unzip ne_np_female.zip
# !ls ne_np_female
# Out:
# --2021-03-23 22:35:57--  https://www.openslr.org/resources/43/ne_np_female.zip
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 800375645 (763M) [application/zip]
# Saving to: ‘ne_np_female.zip’
#
# ne_np_female.zip    100%[===================>] 763.30M  20.8MB/s    in 38s
#
# 2021-03-23 22:36:36 (19.9 MB/s) - ‘ne_np_female.zip’ saved [800375645/800375645]
#
# Archive:  ne_np_female.zip
#    creating: ne_np_female/
#   inflating: ne_np_female/line_index.tsv
#    creating: ne_np_female/wavs/
#   inflating: ne_np_female/wavs/nep_0258_0119737288.wav
#   inflating: ne_np_female/wavs/nep_0258_0461984530.wav
#   inflating: ne_np_female/wavs/nep_0258_0576399736.wav
#   inflating: ne_np_female/wavs/nep_0258_0707220145.wav
#   inflating: ne_np_female/wavs/nep_0258_0838627393.wav
#   inflating: ne_np_female/wavs/nep_0258_1082186644.wav
#   inflating: ne_np_female/wavs/nep_0258_1139532706.wav
#   inflating: ne_np_female/wavs/nep_0258_2044831682.wav
#   inflating: ne_np_female/wavs/nep_0258_2658340102.wav
#   inflating: ne_np_female/wavs/nep_0258_2670176669.wav
#   inflating: ne_np_female/wavs/nep_0258_2764563824.wav
#   inflating: ne_np_female/wavs/nep_0258_2784581247.wav
#   inflating: ne_np_female/wavs/nep_0258_2857262530.wav
#   inflating: ne_np_female/wavs/nep_0258_2907711643.wav
#   inflating: ne_np_female/wavs/nep_0258_3000024878.wav
#   inflating: ne_np_female/wavs/nep_0258_3178538388.wav
#   inflating: ne_np_female/wavs/nep_0258_3696950667.wav
#   inflating: ne_np_female/wavs/nep_0258_3756247064.wav
#   inflating: ne_np_female/wavs/nep_0258_3863885031.wav
#   inflating: ne_np_female/wavs/nep_0258_4633570599.wav
#   inflating: ne_np_female/wavs/nep_0258_5936619539.wav
#   inflating: ne_np_female/wavs/nep_0258_5963754000.wav
#   inflating: ne_np_female/wavs/nep_0258_6050104400.wav
#   inflating: ne_np_female/wavs/nep_0258_6075003542.wav
#   inflating: ne_np_female/wavs/nep_0258_6318800215.wav
#   inflating: ne_np_female/wavs/nep_0258_6957160770.wav
#   inflating: ne_np_female/wavs/nep_0258_7059288409.wav
#   inflating: ne_np_female/wavs/nep_0258_7074678628.wav
#   inflating: ne_np_female/wavs/nep_0258_7121600053.wav
#   inflating: ne_np_female/wavs/nep_0258_7147057872.wav
#   inflating: ne_np_female/wavs/nep_0258_7211607717.wav
#   inflating: ne_np_female/wavs/nep_0258_7263933785.wav
#   inflating: ne_np_female/wavs/nep_0258_7375603014.wav
#   inflating: ne_np_female/wavs/nep_0258_7605572831.wav
#   inflating: ne_np_female/wavs/nep_0258_7843539751.wav
#   inflating: ne_np_female/wavs/nep_0258_7944550785.wav
#   inflating: ne_np_female/wavs/nep_0258_8169062440.wav
#   inflating: ne_np_female/wavs/nep_0258_8444696734.wav
#   inflating: ne_np_female/wavs/nep_0258_9071871190.wav
#   inflating: ne_np_female/wavs/nep_0258_9113827113.wav
#   inflating: ne_np_female/wavs/nep_0258_9132039389.wav
#   inflating: ne_np_female/wavs/nep_0258_9284332098.wav
#   inflating: ne_np_female/wavs/nep_0258_9660145870.wav
#   inflating: ne_np_female/wavs/nep_0258_9678022366.wav
#   inflating: ne_np_female/wavs/nep_0258_9856286890.wav
#   inflating: ne_np_female/wavs/nep_0258_9867218411.wav
#   inflating: ne_np_female/wavs/nep_0258_9885710280.wav
#   inflating: ne_np_female/wavs/nep_0258_9939583579.wav
#   inflating: ne_np_female/wavs/nep_0258_9950286014.wav
#   inflating: ne_np_female/wavs/nep_0283_0766374282.wav
#   inflating: ne_np_female/wavs/nep_0283_0816115484.wav
#   inflating: ne_np_female/wavs/nep_0283_0964661420.wav
#   inflating: ne_np_female/wavs/nep_0283_0976640363.wav
#   inflating: ne_np_female/wavs/nep_0283_1353776465.wav
#   inflating: ne_np_female/wavs/nep_0283_1731098563.wav
#   inflating: ne_np_female/wavs/nep_0283_2244138368.wav
#   inflating: ne_np_female/wavs/nep_0283_3326495973.wav
#   inflating: ne_np_female/wavs/nep_0283_3759375127.wav
#   inflating: ne_np_female/wavs/nep_0283_4038945255.wav
#   inflating: ne_np_female/wavs/nep_0283_4559349270.wav
#   inflating: ne_np_female/wavs/nep_0283_4618089463.wav
#   inflating: ne_np_female/wavs/nep_0283_4751807651.wav
#   inflating: ne_np_female/wavs/nep_0283_4905013597.wav
#   inflating: ne_np_female/wavs/nep_0283_5158477137.wav
#   inflating: ne_np_female/wavs/nep_0283_5326639197.wav
#   inflating: ne_np_female/wavs/nep_0283_5380400568.wav
#   inflating: ne_np_female/wavs/nep_0283_5584542821.wav
#   inflating: ne_np_female/wavs/nep_0283_6656084051.wav
#   inflating: ne_np_female/wavs/nep_0283_6773461444.wav
#   inflating: ne_np_female/wavs/nep_0283_7088220977.wav
#   inflating: ne_np_female/wavs/nep_0283_7151562621.wav
#   inflating: ne_np_female/wavs/nep_0283_7189052277.wav
#   inflating: ne_np_female/wavs/nep_0283_7794093052.wav
#   inflating: ne_np_female/wavs/nep_0283_8183720007.wav
#   inflating: ne_np_female/wavs/nep_0283_8303673924.wav
#   inflating: ne_np_female/wavs/nep_0283_8671851523.wav
#   inflating: ne_np_female/wavs/nep_0283_8694410705.wav
#   inflating: ne_np_female/wavs/nep_0283_8753376916.wav
#   inflating: ne_np_female/wavs/nep_0283_9497646917.wav
#   inflating: ne_np_female/wavs/nep_0283_9642724626.wav
#   inflating: ne_np_female/wavs/nep_0283_9885544741.wav
#   inflating: ne_np_female/wavs/nep_0546_0029201705.wav
#   inflating: ne_np_female/wavs/nep_0546_0054660966.wav
#   inflating: ne_np_female/wavs/nep_0546_0077678862.wav
#   inflating: ne_np_female/wavs/nep_0546_0081522120.wav
#   inflating: ne_np_female/wavs/nep_0546_0087760275.wav
#   inflating: ne_np_female/wavs/nep_0546_0106808568.wav
#   inflating: ne_np_female/wavs/nep_0546_0111162501.wav
#   inflating: ne_np_female/wavs/nep_0546_0111676622.wav
#   inflating: ne_np_female/wavs/nep_0546_0152397263.wav
#   inflating: ne_np_female/wavs/nep_0546_0203684983.wav
#   inflating: ne_np_female/wavs/nep_0546_0212162804.wav
#   inflating: ne_np_female/wavs/nep_0546_0247234914.wav
#   inflating: ne_np_female/wavs/nep_0546_0247685392.wav
#   inflating: ne_np_female/wavs/nep_0546_0280639280.wav
#   inflating: ne_np_female/wavs/nep_0546_0314559048.wav
#   inflating: ne_np_female/wavs/nep_0546_0324069539.wav
#   inflating: ne_np_female/wavs/nep_0546_0328643693.wav
#   inflating: ne_np_female/wavs/nep_0546_0356947146.wav
#   inflating: ne_np_female/wavs/nep_0546_0360261388.wav
#   inflating: ne_np_female/wavs/nep_0546_0371825078.wav
#   inflating: ne_np_female/wavs/nep_0546_0388611826.wav
#   inflating: ne_np_female/wavs/nep_0546_0417178507.wav
#   inflating: ne_np_female/wavs/nep_0546_0420145571.wav
#   inflating: ne_np_female/wavs/nep_0546_0432877132.wav
#   inflating: ne_np_female/wavs/nep_0546_0490617198.wav
#   inflating: ne_np_female/wavs/nep_0546_0504646534.wav
#   inflating: ne_np_female/wavs/nep_0546_0657727170.wav
#   inflating: ne_np_female/wavs/nep_0546_0659548622.wav
#   inflating: ne_np_female/wavs/nep_0546_0664459816.wav
#   inflating: ne_np_female/wavs/nep_0546_0677472615.wav
#   inflating: ne_np_female/wavs/nep_0546_0685084826.wav
#   inflating: ne_np_female/wavs/nep_0546_0712459277.wav
#   inflating: ne_np_female/wavs/nep_0546_0738896302.wav
#   inflating: ne_np_female/wavs/nep_0546_0743764877.wav
#   inflating: ne_np_female/wavs/nep_0546_0744543522.wav
#   inflating: ne_np_female/wavs/nep_0546_0760148551.wav
#   inflating: ne_np_female/wavs/nep_0546_0806003703.wav
#   inflating: ne_np_female/wavs/nep_0546_0876609377.wav
#   inflating: ne_np_female/wavs/nep_0546_0894887834.wav
#   inflating: ne_np_female/wavs/nep_0546_0973996646.wav
#   inflating: ne_np_female/wavs/nep_0546_0987384824.wav
#   inflating: ne_np_female/wavs/nep_0546_0988245523.wav
#   inflating: ne_np_female/wavs/nep_0546_1009807268.wav
#   inflating: ne_np_female/wavs/nep_0546_1036808728.wav
#   inflating: ne_np_female/wavs/nep_0546_1046020727.wav
#   inflating: ne_np_female/wavs/nep_0546_1050863540.wav
#   inflating: ne_np_female/wavs/nep_0546_1075589513.wav
#   inflating: ne_np_female/wavs/nep_0546_1091421919.wav
#   inflating: ne_np_female/wavs/nep_0546_1095090924.wav
#   inflating: ne_np_female/wavs/nep_0546_1101290916.wav
#   inflating: ne_np_female/wavs/nep_0546_1153028889.wav
#   inflating: ne_np_female/wavs/nep_0546_1216756049.wav
#   inflating: ne_np_female/wavs/nep_0546_1266766076.wav
#   inflating: ne_np_female/wavs/nep_0546_1284228568.wav
#   inflating: ne_np_female/wavs/nep_0546_1329853697.wav
#   inflating: ne_np_female/wavs/nep_0546_1364936863.wav
#   inflating: ne_np_female/wavs/nep_0546_1370941050.wav
#   inflating: ne_np_female/wavs/nep_0546_1373549461.wav
#   inflating: ne_np_female/wavs/nep_0546_1409208559.wav
#   inflating: ne_np_female/wavs/nep_0546_1411086812.wav
#   inflating: ne_np_female/wavs/nep_0546_1488676727.wav
#   inflating: ne_np_female/wavs/nep_0546_1506025460.wav
#   inflating: ne_np_female/wavs/nep_0546_1535070415.wav
#   inflating: ne_np_female/wavs/nep_0546_1548994302.wav
#   inflating: ne_np_female/wavs/nep_0546_1555952548.wav
#   inflating: ne_np_female/wavs/nep_0546_1567992918.wav
#   inflating: ne_np_female/wavs/nep_0546_1570010746.wav
#   inflating: ne_np_female/wavs/nep_0546_1581951551.wav
#   inflating: ne_np_female/wavs/nep_0546_1623165518.wav
#   inflating: ne_np_female/wavs/nep_0546_1623725320.wav
#   inflating: ne_np_female/wavs/nep_0546_1627945346.wav
#   inflating: ne_np_female/wavs/nep_0546_1636939995.wav
#   inflating: ne_np_female/wavs/nep_0546_1648288763.wav
#   inflating: ne_np_female/wavs/nep_0546_1657730053.wav
#   inflating: ne_np_female/wavs/nep_0546_1704280925.wav
#   inflating: ne_np_female/wavs/nep_0546_1709529716.wav
#   inflating: ne_np_female/wavs/nep_0546_1751539393.wav
#   inflating: ne_np_female/wavs/nep_0546_1757689247.wav
#   inflating: ne_np_female/wavs/nep_0546_1820151981.wav
#   inflating: ne_np_female/wavs/nep_0546_1828967194.wav
#   inflating: ne_np_female/wavs/nep_0546_1839688913.wav
#   inflating: ne_np_female/wavs/nep_0546_1839946667.wav
#   inflating: ne_np_female/wavs/nep_0546_1841446999.wav
#   inflating: ne_np_female/wavs/nep_0546_1847819546.wav
#   inflating: ne_np_female/wavs/nep_0546_1874346314.wav
#   inflating: ne_np_female/wavs/nep_0546_1875717509.wav
#   inflating: ne_np_female/wavs/nep_0546_1888328246.wav
#   inflating: ne_np_female/wavs/nep_0546_1913589364.wav
#   inflating: ne_np_female/wavs/nep_0546_1917017692.wav
#   inflating: ne_np_female/wavs/nep_0546_1932438217.wav
#   inflating: ne_np_female/wavs/nep_0546_1950992198.wav
#   inflating: ne_np_female/wavs/nep_0546_1969789211.wav
#   inflating: ne_np_female/wavs/nep_0546_1990809193.wav
#   inflating: ne_np_female/wavs/nep_0546_1999862359.wav
#   inflating: ne_np_female/wavs/nep_0546_2028204747.wav
#   inflating: ne_np_female/wavs/nep_0546_2031120995.wav
#   inflating: ne_np_female/wavs/nep_0546_2082351340.wav
#   inflating: ne_np_female/wavs/nep_0546_2106804279.wav
#   inflating: ne_np_female/wavs/nep_0546_2150970344.wav
#   inflating: ne_np_female/wavs/nep_0546_2190381285.wav
#   inflating: ne_np_female/wavs/nep_0546_2228311637.wav
#   inflating: ne_np_female/wavs/nep_0546_2254855120.wav
#   inflating: ne_np_female/wavs/nep_0546_2261491734.wav
#   inflating: ne_np_female/wavs/nep_0546_2264069418.wav
#   inflating: ne_np_female/wavs/nep_0546_2282619132.wav
#   inflating: ne_np_female/wavs/nep_0546_2289266069.wav
#   inflating: ne_np_female/wavs/nep_0546_2300280975.wav
#   inflating: ne_np_female/wavs/nep_0546_2306998866.wav
#   inflating: ne_np_female/wavs/nep_0546_2327279343.wav
#   inflating: ne_np_female/wavs/nep_0546_2423665507.wav
#   inflating: ne_np_female/wavs/nep_0546_2444457349.wav
#   inflating: ne_np_female/wavs/nep_0546_2500635318.wav
#   inflating: ne_np_female/wavs/nep_0546_2555171110.wav
#   inflating: ne_np_female/wavs/nep_0546_2566323184.wav
#   inflating: ne_np_female/wavs/nep_0546_2569424979.wav
#   inflating: ne_np_female/wavs/nep_0546_2580741211.wav
#   inflating: ne_np_female/wavs/nep_0546_2586374559.wav
#   inflating: ne_np_female/wavs/nep_0546_2592619420.wav
#   inflating: ne_np_female/wavs/nep_0546_2598767507.wav
#   inflating: ne_np_female/wavs/nep_0546_2627445287.wav
#   inflating: ne_np_female/wavs/nep_0546_2641669367.wav
#   inflating: ne_np_female/wavs/nep_0546_2648001614.wav
#   inflating: ne_np_female/wavs/nep_0546_2648125610.wav
#   inflating: ne_np_female/wavs/nep_0546_2669050485.wav
#   inflating: ne_np_female/wavs/nep_0546_2708621810.wav
#   inflating: ne_np_female/wavs/nep_0546_2730850248.wav
#   inflating: ne_np_female/wavs/nep_0546_2743516060.wav
#   inflating: ne_np_female/wavs/nep_0546_2756840944.wav
#   inflating: ne_np_female/wavs/nep_0546_2770740893.wav
#   inflating: ne_np_female/wavs/nep_0546_2783338810.wav
#   inflating: ne_np_female/wavs/nep_0546_2785060463.wav
#   inflating: ne_np_female/wavs/nep_0546_2800364285.wav
#   inflating: ne_np_female/wavs/nep_0546_2801412251.wav
#   inflating: ne_np_female/wavs/nep_0546_2843404972.wav
#   inflating: ne_np_female/wavs/nep_0546_2854954282.wav
#   inflating: ne_np_female/wavs/nep_0546_2868510042.wav
#   inflating: ne_np_female/wavs/nep_0546_2878948778.wav
#   inflating: ne_np_female/wavs/nep_0546_2880447148.wav
#   inflating: ne_np_female/wavs/nep_0546_2890130880.wav
#   inflating: ne_np_female/wavs/nep_0546_2901086638.wav
#   inflating: ne_np_female/wavs/nep_0546_2917381710.wav
#   inflating: ne_np_female/wavs/nep_0546_2918033281.wav
#   inflating: ne_np_female/wavs/nep_0546_2923886327.wav
#   inflating: ne_np_female/wavs/nep_0546_2929266220.wav
#   inflating: ne_np_female/wavs/nep_0546_2953992562.wav
#   inflating: ne_np_female/wavs/nep_0546_2958873141.wav
#   inflating: ne_np_female/wavs/nep_0546_3003054814.wav
#   inflating: ne_np_female/wavs/nep_0546_3007836143.wav
#   inflating: ne_np_female/wavs/nep_0546_3020378588.wav
#   inflating: ne_np_female/wavs/nep_0546_3042205946.wav
#   inflating: ne_np_female/wavs/nep_0546_3076577201.wav
#   inflating: ne_np_female/wavs/nep_0546_3134436030.wav
#   inflating: ne_np_female/wavs/nep_0546_3193418396.wav
#   inflating: ne_np_female/wavs/nep_0546_3201480617.wav
#   inflating: ne_np_female/wavs/nep_0546_3212922328.wav
#   inflating: ne_np_female/wavs/nep_0546_3220286793.wav
#   inflating: ne_np_female/wavs/nep_0546_3232354843.wav
#   inflating: ne_np_female/wavs/nep_0546_3267854744.wav
#   inflating: ne_np_female/wavs/nep_0546_3318714782.wav
#   inflating: ne_np_female/wavs/nep_0546_3339057687.wav
#   inflating: ne_np_female/wavs/nep_0546_3349081644.wav
#   inflating: ne_np_female/wavs/nep_0546_3357727111.wav
#   inflating: ne_np_female/wavs/nep_0546_3360525235.wav
#   inflating: ne_np_female/wavs/nep_0546_3379641776.wav
#   inflating: ne_np_female/wavs/nep_0546_3397318151.wav
#   inflating: ne_np_female/wavs/nep_0546_3415443618.wav
#   inflating: ne_np_female/wavs/nep_0546_3432370397.wav
#   inflating: ne_np_female/wavs/nep_0546_3433661851.wav
#   inflating: ne_np_female/wavs/nep_0546_3442005520.wav
#   inflating: ne_np_female/wavs/nep_0546_3468463359.wav
#   inflating: ne_np_female/wavs/nep_0546_3493862458.wav
#   inflating: ne_np_female/wavs/nep_0546_3498602749.wav
#   inflating: ne_np_female/wavs/nep_0546_3502546382.wav
#   inflating: ne_np_female/wavs/nep_0546_3543318757.wav
#   inflating: ne_np_female/wavs/nep_0546_3543759936.wav
#   inflating: ne_np_female/wavs/nep_0546_3594640296.wav
#   inflating: ne_np_female/wavs/nep_0546_3606699939.wav
#   inflating: ne_np_female/wavs/nep_0546_3625614428.wav
#   inflating: ne_np_female/wavs/nep_0546_3655731348.wav
#   inflating: ne_np_female/wavs/nep_0546_3659519943.wav
#   inflating: ne_np_female/wavs/nep_0546_3665916054.wav
#   inflating: ne_np_female/wavs/nep_0546_3669566875.wav
#   inflating: ne_np_female/wavs/nep_0546_3686219859.wav
#   inflating: ne_np_female/wavs/nep_0546_3693406213.wav
#   inflating: ne_np_female/wavs/nep_0546_3719657199.wav
#   inflating: ne_np_female/wavs/nep_0546_3735008673.wav
#   inflating: ne_np_female/wavs/nep_0546_3737710455.wav
#   inflating: ne_np_female/wavs/nep_0546_3743234271.wav
#   inflating: ne_np_female/wavs/nep_0546_3751777393.wav
#   inflating: ne_np_female/wavs/nep_0546_3782097543.wav
#   inflating: ne_np_female/wavs/nep_0546_3785618587.wav
#   inflating: ne_np_female/wavs/nep_0546_3803170301.wav
#   inflating: ne_np_female/wavs/nep_0546_3805346971.wav
#   inflating: ne_np_female/wavs/nep_0546_3844213957.wav
#   inflating: ne_np_female/wavs/nep_0546_3857176321.wav
#   inflating: ne_np_female/wavs/nep_0546_3869979792.wav
#   inflating: ne_np_female/wavs/nep_0546_3899362644.wav
#   inflating: ne_np_female/wavs/nep_0546_3903777350.wav
#   inflating: ne_np_female/wavs/nep_0546_3911026041.wav
#   inflating: ne_np_female/wavs/nep_0546_3979164145.wav
#   inflating: ne_np_female/wavs/nep_0546_3988642046.wav
#   inflating: ne_np_female/wavs/nep_0546_3995718916.wav
#   inflating: ne_np_female/wavs/nep_0546_4013351462.wav
#   inflating: ne_np_female/wavs/nep_0546_4035246296.wav
#   inflating: ne_np_female/wavs/nep_0546_4061797802.wav
#   inflating: ne_np_female/wavs/nep_0546_4074187558.wav
#   inflating: ne_np_female/wavs/nep_0546_4100790116.wav
#   inflating: ne_np_female/wavs/nep_0546_4143561318.wav
#   inflating: ne_np_female/wavs/nep_0546_4192847763.wav
#   inflating: ne_np_female/wavs/nep_0546_4208078228.wav
#   inflating: ne_np_female/wavs/nep_0546_4234687737.wav
#   inflating: ne_np_female/wavs/nep_0546_4235434290.wav
#   inflating: ne_np_female/wavs/nep_0546_4272781089.wav
#   inflating: ne_np_female/wavs/nep_0546_4324932527.wav
#   inflating: ne_np_female/wavs/nep_0546_4403604647.wav
#   inflating: ne_np_female/wavs/nep_0546_4405770244.wav
#   inflating: ne_np_female/wavs/nep_0546_4411250717.wav
#   inflating: ne_np_female/wavs/nep_0546_4418224893.wav
#   inflating: ne_np_female/wavs/nep_0546_4429317177.wav
#   inflating: ne_np_female/wavs/nep_0546_4451907228.wav
#   inflating: ne_np_female/wavs/nep_0546_4462375379.wav
#   inflating: ne_np_female/wavs/nep_0546_4503712516.wav
#   inflating: ne_np_female/wavs/nep_0546_4571121178.wav
#   inflating: ne_np_female/wavs/nep_0546_4580530501.wav
#   inflating: ne_np_female/wavs/nep_0546_4626254053.wav
#   inflating: ne_np_female/wavs/nep_0546_4654161400.wav
#   inflating: ne_np_female/wavs/nep_0546_4668652322.wav
#   inflating: ne_np_female/wavs/nep_0546_4673329605.wav
#   inflating: ne_np_female/wavs/nep_0546_4708367699.wav
#   inflating: ne_np_female/wavs/nep_0546_4710635421.wav
#   inflating: ne_np_female/wavs/nep_0546_4733772203.wav
#   inflating: ne_np_female/wavs/nep_0546_4734354598.wav
#   inflating: ne_np_female/wavs/nep_0546_4759164239.wav
#   inflating: ne_np_female/wavs/nep_0546_4767150400.wav
#   inflating: ne_np_female/wavs/nep_0546_4767440530.wav
#   inflating: ne_np_female/wavs/nep_0546_4792017606.wav
#   inflating: ne_np_female/wavs/nep_0546_4792342171.wav
#   inflating: ne_np_female/wavs/nep_0546_4797569736.wav
#   inflating: ne_np_female/wavs/nep_0546_4819044101.wav
#   inflating: ne_np_female/wavs/nep_0546_4853610763.wav
#   inflating: ne_np_female/wavs/nep_0546_4868265038.wav
#   inflating: ne_np_female/wavs/nep_0546_4874583637.wav
#   inflating: ne_np_female/wavs/nep_0546_4896619679.wav
#   inflating: ne_np_female/wavs/nep_0546_4928555822.wav
#   inflating: ne_np_female/wavs/nep_0546_4940527952.wav
#   inflating: ne_np_female/wavs/nep_0546_4941885441.wav
#   inflating: ne_np_female/wavs/nep_0546_4969979086.wav
#   inflating: ne_np_female/wavs/nep_0546_4979711920.wav
#   inflating: ne_np_female/wavs/nep_0546_5023753880.wav
#   inflating: ne_np_female/wavs/nep_0546_5059471688.wav
#   inflating: ne_np_female/wavs/nep_0546_5082066987.wav
#   inflating: ne_np_female/wavs/nep_0546_5082936888.wav
#   inflating: ne_np_female/wavs/nep_0546_5108450978.wav
#   inflating: ne_np_female/wavs/nep_0546_5121682352.wav
#   inflating: ne_np_female/wavs/nep_0546_5145517817.wav
#   inflating: ne_np_female/wavs/nep_0546_5150629786.wav
#   inflating: ne_np_female/wavs/nep_0546_5154065910.wav
#   inflating: ne_np_female/wavs/nep_0546_5155722329.wav
#   inflating: ne_np_female/wavs/nep_0546_5176171202.wav
#   inflating: ne_np_female/wavs/nep_0546_5184310421.wav
#   inflating: ne_np_female/wavs/nep_0546_5225771126.wav
#   inflating: ne_np_female/wavs/nep_0546_5230584092.wav
#   inflating: ne_np_female/wavs/nep_0546_5273088105.wav
#   inflating: ne_np_female/wavs/nep_0546_5287880117.wav
#   inflating: ne_np_female/wavs/nep_0546_5292495263.wav
#   inflating: ne_np_female/wavs/nep_0546_5294903398.wav
#   inflating: ne_np_female/wavs/nep_0546_5309728526.wav
#   inflating: ne_np_female/wavs/nep_0546_5320106695.wav
#   inflating: ne_np_female/wavs/nep_0546_5345340396.wav
#   inflating: ne_np_female/wavs/nep_0546_5362686516.wav
#   inflating: ne_np_female/wavs/nep_0546_5439122478.wav
#   inflating: ne_np_female/wavs/nep_0546_5451941367.wav
#   inflating: ne_np_female/wavs/nep_0546_5493767844.wav
#   inflating: ne_np_female/wavs/nep_0546_5517187052.wav
#   inflating: ne_np_female/wavs/nep_0546_5521883428.wav
#   inflating: ne_np_female/wavs/nep_0546_5523246251.wav
#   inflating: ne_np_female/wavs/nep_0546_5528622774.wav
#   inflating: ne_np_female/wavs/nep_0546_5530396269.wav
#   inflating: ne_np_female/wavs/nep_0546_5540265879.wav
#   inflating: ne_np_female/wavs/nep_0546_5551244103.wav
#   inflating: ne_np_female/wavs/nep_0546_5559563135.wav
#   inflating: ne_np_female/wavs/nep_0546_5563904117.wav
#   inflating: ne_np_female/wavs/nep_0546_5564857879.wav
#   inflating: ne_np_female/wavs/nep_0546_5591338514.wav
#   inflating: ne_np_female/wavs/nep_0546_5596997258.wav
#   inflating: ne_np_female/wavs/nep_0546_5623578564.wav
#   inflating: ne_np_female/wavs/nep_0546_5625463325.wav
#   inflating: ne_np_female/wavs/nep_0546_5637749186.wav
#   inflating: ne_np_female/wavs/nep_0546_5640068622.wav
#   inflating: ne_np_female/wavs/nep_0546_5641364661.wav
#   inflating: ne_np_female/wavs/nep_0546_5649057553.wav
#   inflating: ne_np_female/wavs/nep_0546_5685379320.wav
#   inflating: ne_np_female/wavs/nep_0546_5693635406.wav
#   inflating: ne_np_female/wavs/nep_0546_5697832733.wav
#   inflating: ne_np_female/wavs/nep_0546_5712694328.wav
#   inflating: ne_np_female/wavs/nep_0546_5748448669.wav
#   inflating: ne_np_female/wavs/nep_0546_5773020952.wav
#   inflating: ne_np_female/wavs/nep_0546_5775264068.wav
#   inflating: ne_np_female/wavs/nep_0546_5792891596.wav
#   inflating: ne_np_female/wavs/nep_0546_5800210345.wav
#   inflating: ne_np_female/wavs/nep_0546_5881846858.wav
#   inflating: ne_np_female/wavs/nep_0546_5887506398.wav
#   inflating: ne_np_female/wavs/nep_0546_5967412214.wav
#   inflating: ne_np_female/wavs/nep_0546_6024469911.wav
#   inflating: ne_np_female/wavs/nep_0546_6024498400.wav
#   inflating: ne_np_female/wavs/nep_0546_6099121597.wav
#   inflating: ne_np_female/wavs/nep_0546_6117297526.wav
#   inflating: ne_np_female/wavs/nep_0546_6133740081.wav
#   inflating: ne_np_female/wavs/nep_0546_6160964956.wav
#   inflating: ne_np_female/wavs/nep_0546_6178756476.wav
#   inflating: ne_np_female/wavs/nep_0546_6181977750.wav
#   inflating: ne_np_female/wavs/nep_0546_6224843014.wav
#   inflating: ne_np_female/wavs/nep_0546_6242395806.wav
#   inflating: ne_np_female/wavs/nep_0546_6261649465.wav
#   inflating: ne_np_female/wavs/nep_0546_6268679559.wav
#   inflating: ne_np_female/wavs/nep_0546_6278470870.wav
#   inflating: ne_np_female/wavs/nep_0546_6280377443.wav
#   inflating: ne_np_female/wavs/nep_0546_6297249192.wav
#   inflating: ne_np_female/wavs/nep_0546_6303294475.wav
#   inflating: ne_np_female/wavs/nep_0546_6322353836.wav
#   inflating: ne_np_female/wavs/nep_0546_6375493076.wav
#   inflating: ne_np_female/wavs/nep_0546_6379008467.wav
#   inflating: ne_np_female/wavs/nep_0546_6477856191.wav
#   inflating: ne_np_female/wavs/nep_0546_6487604424.wav
#   inflating: ne_np_female/wavs/nep_0546_6561926136.wav
#   inflating: ne_np_female/wavs/nep_0546_6565054275.wav
#   inflating: ne_np_female/wavs/nep_0546_6567686476.wav
#   inflating: ne_np_female/wavs/nep_0546_6587298618.wav
#   inflating: ne_np_female/wavs/nep_0546_6608602305.wav
#   inflating: ne_np_female/wavs/nep_0546_6634248093.wav
#   inflating: ne_np_female/wavs/nep_0546_6699931770.wav
#   inflating: ne_np_female/wavs/nep_0546_6701968493.wav
#   inflating: ne_np_female/wavs/nep_0546_6714476998.wav
#   inflating: ne_np_female/wavs/nep_0546_6724371003.wav
#   inflating: ne_np_female/wavs/nep_0546_6730177303.wav
#   inflating: ne_np_female/wavs/nep_0546_6748563935.wav
#   inflating: ne_np_female/wavs/nep_0546_6753563278.wav
#   inflating: ne_np_female/wavs/nep_0546_6790520596.wav
#   inflating: ne_np_female/wavs/nep_0546_6822246701.wav
#   inflating: ne_np_female/wavs/nep_0546_6827653923.wav
#   inflating: ne_np_female/wavs/nep_0546_6835729336.wav
#   inflating: ne_np_female/wavs/nep_0546_6852778943.wav
#   inflating: ne_np_female/wavs/nep_0546_6853079866.wav
#   inflating: ne_np_female/wavs/nep_0546_6886348878.wav
#   inflating: ne_np_female/wavs/nep_0546_6895873651.wav
#   inflating: ne_np_female/wavs/nep_0546_6902458143.wav
#   inflating: ne_np_female/wavs/nep_0546_6924932351.wav
#   inflating: ne_np_female/wavs/nep_0546_6941764775.wav
#   inflating: ne_np_female/wavs/nep_0546_6945085419.wav
#   inflating: ne_np_female/wavs/nep_0546_6959931606.wav
#   inflating: ne_np_female/wavs/nep_0546_6998432618.wav
#   inflating: ne_np_female/wavs/nep_0546_7014054383.wav
#   inflating: ne_np_female/wavs/nep_0546_7016402255.wav
#   inflating: ne_np_female/wavs/nep_0546_7054581764.wav
#   inflating: ne_np_female/wavs/nep_0546_7059399731.wav
#   inflating: ne_np_female/wavs/nep_0546_7066975831.wav
#   inflating: ne_np_female/wavs/nep_0546_7082599536.wav
#   inflating: ne_np_female/wavs/nep_0546_7092737345.wav
#   inflating: ne_np_female/wavs/nep_0546_7094533040.wav
#   inflating: ne_np_female/wavs/nep_0546_7133800018.wav
#   inflating: ne_np_female/wavs/nep_0546_7146910945.wav
#   inflating: ne_np_female/wavs/nep_0546_7150982977.wav
#   inflating: ne_np_female/wavs/nep_0546_7195186643.wav
#   inflating: ne_np_female/wavs/nep_0546_7198399203.wav
#   inflating: ne_np_female/wavs/nep_0546_7212931328.wav
#   inflating: ne_np_female/wavs/nep_0546_7238336677.wav
#   inflating: ne_np_female/wavs/nep_0546_7241261186.wav
#   inflating: ne_np_female/wavs/nep_0546_7289298941.wav
#   inflating: ne_np_female/wavs/nep_0546_7302174967.wav
#   inflating: ne_np_female/wavs/nep_0546_7314848881.wav
#   inflating: ne_np_female/wavs/nep_0546_7327433114.wav
#   inflating: ne_np_female/wavs/nep_0546_7353852861.wav
#   inflating: ne_np_female/wavs/nep_0546_7370160468.wav
#   inflating: ne_np_female/wavs/nep_0546_7420214959.wav
#   inflating: ne_np_female/wavs/nep_0546_7421635821.wav
#   inflating: ne_np_female/wavs/nep_0546_7422515817.wav
#   inflating: ne_np_female/wavs/nep_0546_7454541011.wav
#   inflating: ne_np_female/wavs/nep_0546_7455127638.wav
#   inflating: ne_np_female/wavs/nep_0546_7455362678.wav
#   inflating: ne_np_female/wavs/nep_0546_7493351074.wav
#   inflating: ne_np_female/wavs/nep_0546_7502845342.wav
#   inflating: ne_np_female/wavs/nep_0546_7511966218.wav
#   inflating: ne_np_female/wavs/nep_0546_7516045693.wav
#   inflating: ne_np_female/wavs/nep_0546_7521852173.wav
#   inflating: ne_np_female/wavs/nep_0546_7528731180.wav
#   inflating: ne_np_female/wavs/nep_0546_7563454464.wav
#   inflating: ne_np_female/wavs/nep_0546_7570897621.wav
#   inflating: ne_np_female/wavs/nep_0546_7578870544.wav
#   inflating: ne_np_female/wavs/nep_0546_7629032009.wav
#   inflating: ne_np_female/wavs/nep_0546_7676046381.wav
#   inflating: ne_np_female/wavs/nep_0546_7689862348.wav
#   inflating: ne_np_female/wavs/nep_0546_7696662134.wav
#   inflating: ne_np_female/wavs/nep_0546_7733176302.wav
#   inflating: ne_np_female/wavs/nep_0546_7753581863.wav
#   inflating: ne_np_female/wavs/nep_0546_7774375667.wav
#   inflating: ne_np_female/wavs/nep_0546_7806448108.wav
#   inflating: ne_np_female/wavs/nep_0546_7817976489.wav
#   inflating: ne_np_female/wavs/nep_0546_7830341512.wav
#   inflating: ne_np_female/wavs/nep_0546_7837584211.wav
#   inflating: ne_np_female/wavs/nep_0546_7857067919.wav
#   inflating: ne_np_female/wavs/nep_0546_7857473824.wav
#   inflating: ne_np_female/wavs/nep_0546_7865243262.wav
#   inflating: ne_np_female/wavs/nep_0546_7872130285.wav
#   inflating: ne_np_female/wavs/nep_0546_7916985660.wav
#   inflating: ne_np_female/wavs/nep_0546_7951389195.wav
#   inflating: ne_np_female/wavs/nep_0546_7965126677.wav
#   inflating: ne_np_female/wavs/nep_0546_7970327760.wav
#   inflating: ne_np_female/wavs/nep_0546_8029002129.wav
#   inflating: ne_np_female/wavs/nep_0546_8049723356.wav
#   inflating: ne_np_female/wavs/nep_0546_8072356175.wav
#   inflating: ne_np_female/wavs/nep_0546_8102470649.wav
#   inflating: ne_np_female/wavs/nep_0546_8122250189.wav
#   inflating: ne_np_female/wavs/nep_0546_8137014687.wav
#   inflating: ne_np_female/wavs/nep_0546_8153093399.wav
#   inflating: ne_np_female/wavs/nep_0546_8174329507.wav
#   inflating: ne_np_female/wavs/nep_0546_8209964856.wav
#   inflating: ne_np_female/wavs/nep_0546_8216444997.wav
#   inflating: ne_np_female/wavs/nep_0546_8225278732.wav
#   inflating: ne_np_female/wavs/nep_0546_8230952984.wav
#   inflating: ne_np_female/wavs/nep_0546_8252565869.wav
#   inflating: ne_np_female/wavs/nep_0546_8263716617.wav
#   inflating: ne_np_female/wavs/nep_0546_8269284289.wav
#   inflating: ne_np_female/wavs/nep_0546_8279731068.wav
#   inflating: ne_np_female/wavs/nep_0546_8288093433.wav
#   inflating: ne_np_female/wavs/nep_0546_8308270552.wav
#   inflating: ne_np_female/wavs/nep_0546_8314979469.wav
#   inflating: ne_np_female/wavs/nep_0546_8337996134.wav
#   inflating: ne_np_female/wavs/nep_0546_8384971968.wav
#   inflating: ne_np_female/wavs/nep_0546_8411565863.wav
#   inflating: ne_np_female/wavs/nep_0546_8423611413.wav
#   inflating: ne_np_female/wavs/nep_0546_8455289154.wav
#   inflating: ne_np_female/wavs/nep_0546_8457748492.wav
#   inflating: ne_np_female/wavs/nep_0546_8472528244.wav
#   inflating: ne_np_female/wavs/nep_0546_8473061866.wav
#   inflating: ne_np_female/wavs/nep_0546_8473471222.wav
#   inflating: ne_np_female/wavs/nep_0546_8481103245.wav
#   inflating: ne_np_female/wavs/nep_0546_8482838687.wav
#   inflating: ne_np_female/wavs/nep_0546_8512196296.wav
#   inflating: ne_np_female/wavs/nep_0546_8514789003.wav
#   inflating: ne_np_female/wavs/nep_0546_8524342476.wav
#   inflating: ne_np_female/wavs/nep_0546_8526588911.wav
#   inflating: ne_np_female/wavs/nep_0546_8540565259.wav
#   inflating: ne_np_female/wavs/nep_0546_8564533324.wav
#   inflating: ne_np_female/wavs/nep_0546_8664466780.wav
#   inflating: ne_np_female/wavs/nep_0546_8677425651.wav
#   inflating: ne_np_female/wavs/nep_0546_8679094848.wav
#   inflating: ne_np_female/wavs/nep_0546_8708178608.wav
#   inflating: ne_np_female/wavs/nep_0546_8722667846.wav
#   inflating: ne_np_female/wavs/nep_0546_8729437951.wav
#   inflating: ne_np_female/wavs/nep_0546_8745630097.wav
#   inflating: ne_np_female/wavs/nep_0546_8764132304.wav
#   inflating: ne_np_female/wavs/nep_0546_8764721307.wav
#   inflating: ne_np_female/wavs/nep_0546_8768125323.wav
#   inflating: ne_np_female/wavs/nep_0546_8776000401.wav
#   inflating: ne_np_female/wavs/nep_0546_8791936845.wav
#   inflating: ne_np_female/wavs/nep_0546_8843084784.wav
#   inflating: ne_np_female/wavs/nep_0546_8846826662.wav
#   inflating: ne_np_female/wavs/nep_0546_8860380762.wav
#   inflating: ne_np_female/wavs/nep_0546_8872553757.wav
#   inflating: ne_np_female/wavs/nep_0546_8882222908.wav
#   inflating: ne_np_female/wavs/nep_0546_8896555810.wav
#   inflating: ne_np_female/wavs/nep_0546_8930487507.wav
#   inflating: ne_np_female/wavs/nep_0546_8937731751.wav
#   inflating: ne_np_female/wavs/nep_0546_8955529673.wav
#   inflating: ne_np_female/wavs/nep_0546_8999349284.wav
#   inflating: ne_np_female/wavs/nep_0546_9009740875.wav
#   inflating: ne_np_female/wavs/nep_0546_9023350983.wav
#   inflating: ne_np_female/wavs/nep_0546_9046666695.wav
#   inflating: ne_np_female/wavs/nep_0546_9054535100.wav
#   inflating: ne_np_female/wavs/nep_0546_9062136918.wav
#   inflating: ne_np_female/wavs/nep_0546_9093963485.wav
#   inflating: ne_np_female/wavs/nep_0546_9131901321.wav
#   inflating: ne_np_female/wavs/nep_0546_9158934174.wav
#   inflating: ne_np_female/wavs/nep_0546_9183385297.wav
#   inflating: ne_np_female/wavs/nep_0546_9188640765.wav
#   inflating: ne_np_female/wavs/nep_0546_9233285234.wav
#   inflating: ne_np_female/wavs/nep_0546_9272279274.wav
#   inflating: ne_np_female/wavs/nep_0546_9334740893.wav
#   inflating: ne_np_female/wavs/nep_0546_9339309717.wav
#   inflating: ne_np_female/wavs/nep_0546_9392107080.wav
#   inflating: ne_np_female/wavs/nep_0546_9426840016.wav
#   inflating: ne_np_female/wavs/nep_0546_9447623973.wav
#   inflating: ne_np_female/wavs/nep_0546_9450977405.wav
#   inflating: ne_np_female/wavs/nep_0546_9500168444.wav
#   inflating: ne_np_female/wavs/nep_0546_9521503901.wav
#   inflating: ne_np_female/wavs/nep_0546_9568328624.wav
#   inflating: ne_np_female/wavs/nep_0546_9587230848.wav
#   inflating: ne_np_female/wavs/nep_0546_9588696681.wav
#   inflating: ne_np_female/wavs/nep_0546_9595432537.wav
#   inflating: ne_np_female/wavs/nep_0546_9624031563.wav
#   inflating: ne_np_female/wavs/nep_0546_9655636527.wav
#   inflating: ne_np_female/wavs/nep_0546_9673141857.wav
#   inflating: ne_np_female/wavs/nep_0546_9675837067.wav
#   inflating: ne_np_female/wavs/nep_0546_9709728566.wav
#   inflating: ne_np_female/wavs/nep_0546_9730362107.wav
#   inflating: ne_np_female/wavs/nep_0546_9732483157.wav
#   inflating: ne_np_female/wavs/nep_0546_9798842871.wav
#   inflating: ne_np_female/wavs/nep_0546_9855387476.wav
#   inflating: ne_np_female/wavs/nep_0546_9860405955.wav
#   inflating: ne_np_female/wavs/nep_0546_9879937579.wav
#   inflating: ne_np_female/wavs/nep_0546_9882317584.wav
#   inflating: ne_np_female/wavs/nep_0546_9890598208.wav
#   inflating: ne_np_female/wavs/nep_0546_9929277968.wav
#   inflating: ne_np_female/wavs/nep_0546_9954418010.wav
#   inflating: ne_np_female/wavs/nep_0546_9970131737.wav
#   inflating: ne_np_female/wavs/nep_0649_1055199537.wav
#   inflating: ne_np_female/wavs/nep_0649_1179487906.wav
#   inflating: ne_np_female/wavs/nep_0649_1734113982.wav
#   inflating: ne_np_female/wavs/nep_0649_3100264581.wav
#   inflating: ne_np_female/wavs/nep_0649_8842855723.wav
#   inflating: ne_np_female/wavs/nep_0883_0152052664.wav
#   inflating: ne_np_female/wavs/nep_0883_0523982617.wav
#   inflating: ne_np_female/wavs/nep_0883_0681743016.wav
#   inflating: ne_np_female/wavs/nep_0883_0743584260.wav
#   inflating: ne_np_female/wavs/nep_0883_1901876438.wav
#   inflating: ne_np_female/wavs/nep_0883_2369430056.wav
#   inflating: ne_np_female/wavs/nep_0883_3134182114.wav
#   inflating: ne_np_female/wavs/nep_0883_3153528178.wav
#   inflating: ne_np_female/wavs/nep_0883_3323148122.wav
#   inflating: ne_np_female/wavs/nep_0883_3724821053.wav
#   inflating: ne_np_female/wavs/nep_0883_4623121104.wav
#   inflating: ne_np_female/wavs/nep_0883_4875482575.wav
#   inflating: ne_np_female/wavs/nep_0883_5151957471.wav
#   inflating: ne_np_female/wavs/nep_0883_5250370686.wav
#   inflating: ne_np_female/wavs/nep_0883_6130774235.wav
#   inflating: ne_np_female/wavs/nep_0883_6440912992.wav
#   inflating: ne_np_female/wavs/nep_0883_6567311100.wav
#   inflating: ne_np_female/wavs/nep_0883_6745833485.wav
#   inflating: ne_np_female/wavs/nep_0883_8357619055.wav
#   inflating: ne_np_female/wavs/nep_0883_8460335842.wav
#   inflating: ne_np_female/wavs/nep_0883_8469107559.wav
#   inflating: ne_np_female/wavs/nep_0883_8723568174.wav
#   inflating: ne_np_female/wavs/nep_0883_9164164279.wav
#   inflating: ne_np_female/wavs/nep_0883_9678478624.wav
#   inflating: ne_np_female/wavs/nep_2027_0207928793.wav
#   inflating: ne_np_female/wavs/nep_2027_1887654545.wav
#   inflating: ne_np_female/wavs/nep_2027_1968598216.wav
#   inflating: ne_np_female/wavs/nep_2027_2135210073.wav
#   inflating: ne_np_female/wavs/nep_2027_4177543423.wav
#   inflating: ne_np_female/wavs/nep_2027_4199215152.wav
#   inflating: ne_np_female/wavs/nep_2027_4667640580.wav
#   inflating: ne_np_female/wavs/nep_2027_4724560602.wav
#   inflating: ne_np_female/wavs/nep_2027_4847233647.wav
#   inflating: ne_np_female/wavs/nep_2027_5576535754.wav
#   inflating: ne_np_female/wavs/nep_2027_5665575707.wav
#   inflating: ne_np_female/wavs/nep_2027_5969290132.wav
#   inflating: ne_np_female/wavs/nep_2027_6058780194.wav
#   inflating: ne_np_female/wavs/nep_2027_6330960353.wav
#   inflating: ne_np_female/wavs/nep_2027_7061155296.wav
#   inflating: ne_np_female/wavs/nep_2027_7274060085.wav
#   inflating: ne_np_female/wavs/nep_2027_8609281430.wav
#   inflating: ne_np_female/wavs/nep_2027_8813767402.wav
#   inflating: ne_np_female/wavs/nep_2027_8976817293.wav
#   inflating: ne_np_female/wavs/nep_2027_9839171653.wav
#   inflating: ne_np_female/wavs/nep_2099_0065310479.wav
#   inflating: ne_np_female/wavs/nep_2099_0119467480.wav
#   inflating: ne_np_female/wavs/nep_2099_0135911099.wav
#   inflating: ne_np_female/wavs/nep_2099_0145260888.wav
#   inflating: ne_np_female/wavs/nep_2099_0150100916.wav
#   inflating: ne_np_female/wavs/nep_2099_0153703750.wav
#   inflating: ne_np_female/wavs/nep_2099_0225459997.wav
#   inflating: ne_np_female/wavs/nep_2099_0233938126.wav
#   inflating: ne_np_female/wavs/nep_2099_0249069684.wav
#   inflating: ne_np_female/wavs/nep_2099_0376291458.wav
#   inflating: ne_np_female/wavs/nep_2099_0456476554.wav
#   inflating: ne_np_female/wavs/nep_2099_0489803071.wav
#   inflating: ne_np_female/wavs/nep_2099_0516669352.wav
#   inflating: ne_np_female/wavs/nep_2099_0558451960.wav
#   inflating: ne_np_female/wavs/nep_2099_0631115901.wav
#   inflating: ne_np_female/wavs/nep_2099_0650526524.wav
#   inflating: ne_np_female/wavs/nep_2099_0661714172.wav
#   inflating: ne_np_female/wavs/nep_2099_0784724381.wav
#   inflating: ne_np_female/wavs/nep_2099_0932150072.wav
#   inflating: ne_np_female/wavs/nep_2099_0972783303.wav
#   inflating: ne_np_female/wavs/nep_2099_0974456682.wav
#   inflating: ne_np_female/wavs/nep_2099_1045072190.wav
#   inflating: ne_np_female/wavs/nep_2099_1049912857.wav
#   inflating: ne_np_female/wavs/nep_2099_1113953471.wav
#   inflating: ne_np_female/wavs/nep_2099_1118947558.wav
#   inflating: ne_np_female/wavs/nep_2099_1127258591.wav
#   inflating: ne_np_female/wavs/nep_2099_1166564592.wav
#   inflating: ne_np_female/wavs/nep_2099_1168672510.wav
#   inflating: ne_np_female/wavs/nep_2099_1210926555.wav
#   inflating: ne_np_female/wavs/nep_2099_1239490722.wav
#   inflating: ne_np_female/wavs/nep_2099_1252103550.wav
#   inflating: ne_np_female/wavs/nep_2099_1308110078.wav
#   inflating: ne_np_female/wavs/nep_2099_1325400187.wav
#   inflating: ne_np_female/wavs/nep_2099_1493577464.wav
#   inflating: ne_np_female/wavs/nep_2099_1595751409.wav
#   inflating: ne_np_female/wavs/nep_2099_1620891327.wav
#   inflating: ne_np_female/wavs/nep_2099_1647836016.wav
#   inflating: ne_np_female/wavs/nep_2099_1652297885.wav
#   inflating: ne_np_female/wavs/nep_2099_1781886317.wav
#   inflating: ne_np_female/wavs/nep_2099_1866707562.wav
#   inflating: ne_np_female/wavs/nep_2099_1930580490.wav
#   inflating: ne_np_female/wavs/nep_2099_2087198048.wav
#   inflating: ne_np_female/wavs/nep_2099_2092695301.wav
#   inflating: ne_np_female/wavs/nep_2099_2117262310.wav
#   inflating: ne_np_female/wavs/nep_2099_2148816873.wav
#   inflating: ne_np_female/wavs/nep_2099_2156203541.wav
#   inflating: ne_np_female/wavs/nep_2099_2177646820.wav
#   inflating: ne_np_female/wavs/nep_2099_2236639076.wav
#   inflating: ne_np_female/wavs/nep_2099_2246042046.wav
#   inflating: ne_np_female/wavs/nep_2099_2261012064.wav
#   inflating: ne_np_female/wavs/nep_2099_2272015924.wav
#   inflating: ne_np_female/wavs/nep_2099_2296423149.wav
#   inflating: ne_np_female/wavs/nep_2099_2308716689.wav
#   inflating: ne_np_female/wavs/nep_2099_2312183443.wav
#   inflating: ne_np_female/wavs/nep_2099_2372342860.wav
#   inflating: ne_np_female/wavs/nep_2099_2380888505.wav
#   inflating: ne_np_female/wavs/nep_2099_2396757575.wav
#   inflating: ne_np_female/wavs/nep_2099_2444485210.wav
#   inflating: ne_np_female/wavs/nep_2099_2480341314.wav
#   inflating: ne_np_female/wavs/nep_2099_2545982989.wav
#   inflating: ne_np_female/wavs/nep_2099_2575893683.wav
#   inflating: ne_np_female/wavs/nep_2099_2583853926.wav
#   inflating: ne_np_female/wavs/nep_2099_2602572693.wav
#   inflating: ne_np_female/wavs/nep_2099_2636020806.wav
#   inflating: ne_np_female/wavs/nep_2099_2639367134.wav
#   inflating: ne_np_female/wavs/nep_2099_2651306388.wav
#   inflating: ne_np_female/wavs/nep_2099_2664037030.wav
#   inflating: ne_np_female/wavs/nep_2099_2672412961.wav
#   inflating: ne_np_female/wavs/nep_2099_2761512626.wav
#   inflating: ne_np_female/wavs/nep_2099_2765447007.wav
#   inflating: ne_np_female/wavs/nep_2099_2788612143.wav
#   inflating: ne_np_female/wavs/nep_2099_2836882307.wav
#   inflating: ne_np_female/wavs/nep_2099_2848092180.wav
#   inflating: ne_np_female/wavs/nep_2099_2898115278.wav
#   inflating: ne_np_female/wavs/nep_2099_2910899168.wav
#   inflating: ne_np_female/wavs/nep_2099_2951995413.wav
#   inflating: ne_np_female/wavs/nep_2099_2983462393.wav
#   inflating: ne_np_female/wavs/nep_2099_3210893690.wav
#   inflating: ne_np_female/wavs/nep_2099_3232335200.wav
#   inflating: ne_np_female/wavs/nep_2099_3236525110.wav
#   inflating: ne_np_female/wavs/nep_2099_3265813239.wav
#   inflating: ne_np_female/wavs/nep_2099_3287257157.wav
#   inflating: ne_np_female/wavs/nep_2099_3360592058.wav
#   inflating: ne_np_female/wavs/nep_2099_3384352377.wav
#   inflating: ne_np_female/wavs/nep_2099_3400996335.wav
#   inflating: ne_np_female/wavs/nep_2099_3420424836.wav
#   inflating: ne_np_female/wavs/nep_2099_3504794324.wav
#   inflating: ne_np_female/wavs/nep_2099_3508801376.wav
#   inflating: ne_np_female/wavs/nep_2099_3520404984.wav
#   inflating: ne_np_female/wavs/nep_2099_3532073204.wav
#   inflating: ne_np_female/wavs/nep_2099_3636838174.wav
#   inflating: ne_np_female/wavs/nep_2099_3660091245.wav
#   inflating: ne_np_female/wavs/nep_2099_3674649929.wav
#   inflating: ne_np_female/wavs/nep_2099_3683393070.wav
#   inflating: ne_np_female/wavs/nep_2099_3691524514.wav
#   inflating: ne_np_female/wavs/nep_2099_3837561282.wav
#   inflating: ne_np_female/wavs/nep_2099_3840539384.wav
#   inflating: ne_np_female/wavs/nep_2099_3862635526.wav
#   inflating: ne_np_female/wavs/nep_2099_3928220943.wav
#   inflating: ne_np_female/wavs/nep_2099_3979939574.wav
#   inflating: ne_np_female/wavs/nep_2099_4033610943.wav
#   inflating: ne_np_female/wavs/nep_2099_4050693112.wav
#   inflating: ne_np_female/wavs/nep_2099_4067442303.wav
#   inflating: ne_np_female/wavs/nep_2099_4100396715.wav
#   inflating: ne_np_female/wavs/nep_2099_4169695290.wav
#   inflating: ne_np_female/wavs/nep_2099_4176068194.wav
#   inflating: ne_np_female/wavs/nep_2099_4208594844.wav
#   inflating: ne_np_female/wavs/nep_2099_4273865064.wav
#   inflating: ne_np_female/wavs/nep_2099_4281336848.wav
#   inflating: ne_np_female/wavs/nep_2099_4379273998.wav
#   inflating: ne_np_female/wavs/nep_2099_4436163003.wav
#   inflating: ne_np_female/wavs/nep_2099_4449358732.wav
#   inflating: ne_np_female/wavs/nep_2099_4459809718.wav
#   inflating: ne_np_female/wavs/nep_2099_4461704085.wav
#   inflating: ne_np_female/wavs/nep_2099_4492131142.wav
#   inflating: ne_np_female/wavs/nep_2099_4501444493.wav
#   inflating: ne_np_female/wavs/nep_2099_4518604406.wav
#   inflating: ne_np_female/wavs/nep_2099_4519299999.wav
#   inflating: ne_np_female/wavs/nep_2099_4550495055.wav
#   inflating: ne_np_female/wavs/nep_2099_4554960550.wav
#   inflating: ne_np_female/wavs/nep_2099_4604098970.wav
#   inflating: ne_np_female/wavs/nep_2099_4631152487.wav
#   inflating: ne_np_female/wavs/nep_2099_4707771331.wav
#   inflating: ne_np_female/wavs/nep_2099_4744680160.wav
#   inflating: ne_np_female/wavs/nep_2099_4770237520.wav
#   inflating: ne_np_female/wavs/nep_2099_4770680947.wav
#   inflating: ne_np_female/wavs/nep_2099_4815781687.wav
#   inflating: ne_np_female/wavs/nep_2099_4853806205.wav
#   inflating: ne_np_female/wavs/nep_2099_4909848859.wav
#   inflating: ne_np_female/wavs/nep_2099_4913924179.wav
#   inflating: ne_np_female/wavs/nep_2099_4941967874.wav
#   inflating: ne_np_female/wavs/nep_2099_4979236297.wav
#   inflating: ne_np_female/wavs/nep_2099_5032830850.wav
#   inflating: ne_np_female/wavs/nep_2099_5048690176.wav
#   inflating: ne_np_female/wavs/nep_2099_5054938752.wav
#   inflating: ne_np_female/wavs/nep_2099_5118226450.wav
#   inflating: ne_np_female/wavs/nep_2099_5218658859.wav
#   inflating: ne_np_female/wavs/nep_2099_5234496621.wav
#   inflating: ne_np_female/wavs/nep_2099_5252626197.wav
#   inflating: ne_np_female/wavs/nep_2099_5267195265.wav
#   inflating: ne_np_female/wavs/nep_2099_5304715258.wav
#   inflating: ne_np_female/wavs/nep_2099_5307317292.wav
#   inflating: ne_np_female/wavs/nep_2099_5327754802.wav
#   inflating: ne_np_female/wavs/nep_2099_5350016637.wav
#   inflating: ne_np_female/wavs/nep_2099_5401272194.wav
#   inflating: ne_np_female/wavs/nep_2099_5502275720.wav
#   inflating: ne_np_female/wavs/nep_2099_5521500706.wav
#   inflating: ne_np_female/wavs/nep_2099_5556441385.wav
#   inflating: ne_np_female/wavs/nep_2099_5576821657.wav
#   inflating: ne_np_female/wavs/nep_2099_5618542901.wav
#   inflating: ne_np_female/wavs/nep_2099_5641131819.wav
#   inflating: ne_np_female/wavs/nep_2099_5645653931.wav
#   inflating: ne_np_female/wavs/nep_2099_5648258185.wav
#   inflating: ne_np_female/wavs/nep_2099_5660771258.wav
#   inflating: ne_np_female/wavs/nep_2099_5687427261.wav
#   inflating: ne_np_female/wavs/nep_2099_5741033366.wav
#   inflating: ne_np_female/wavs/nep_2099_5756420394.wav
#   inflating: ne_np_female/wavs/nep_2099_5760175818.wav
#   inflating: ne_np_female/wavs/nep_2099_5812748784.wav
#   inflating: ne_np_female/wavs/nep_2099_5823542172.wav
#   inflating: ne_np_female/wavs/nep_2099_5839248117.wav
#   inflating: ne_np_female/wavs/nep_2099_5868366489.wav
#   inflating: ne_np_female/wavs/nep_2099_5919356064.wav
#   inflating: ne_np_female/wavs/nep_2099_5922025842.wav
#   inflating: ne_np_female/wavs/nep_2099_5925264926.wav
#   inflating: ne_np_female/wavs/nep_2099_6039823279.wav
#   inflating: ne_np_female/wavs/nep_2099_6048396103.wav
#   inflating: ne_np_female/wavs/nep_2099_6055635685.wav
#   inflating: ne_np_female/wavs/nep_2099_6069536092.wav
#   inflating: ne_np_female/wavs/nep_2099_6109436534.wav
#   inflating: ne_np_female/wavs/nep_2099_6177486482.wav
#   inflating: ne_np_female/wavs/nep_2099_6182182497.wav
#   inflating: ne_np_female/wavs/nep_2099_6220214087.wav
#   inflating: ne_np_female/wavs/nep_2099_6283825030.wav
#   inflating: ne_np_female/wavs/nep_2099_6300428933.wav
#   inflating: ne_np_female/wavs/nep_2099_6364360672.wav
#   inflating: ne_np_female/wavs/nep_2099_6377479275.wav
#   inflating: ne_np_female/wavs/nep_2099_6379965939.wav
#   inflating: ne_np_female/wavs/nep_2099_6441499351.wav
#   inflating: ne_np_female/wavs/nep_2099_6496884013.wav
#   inflating: ne_np_female/wavs/nep_2099_6539885256.wav
#   inflating: ne_np_female/wavs/nep_2099_6573413045.wav
#   inflating: ne_np_female/wavs/nep_2099_6592070542.wav
#   inflating: ne_np_female/wavs/nep_2099_6684522365.wav
#   inflating: ne_np_female/wavs/nep_2099_6718283522.wav
#   inflating: ne_np_female/wavs/nep_2099_6752211697.wav
#   inflating: ne_np_female/wavs/nep_2099_6783914335.wav
#   inflating: ne_np_female/wavs/nep_2099_6804594335.wav
#   inflating: ne_np_female/wavs/nep_2099_6828893048.wav
#   inflating: ne_np_female/wavs/nep_2099_6880385108.wav
#   inflating: ne_np_female/wavs/nep_2099_6925166966.wav
#   inflating: ne_np_female/wavs/nep_2099_6985724525.wav
#   inflating: ne_np_female/wavs/nep_2099_6989474730.wav
#   inflating: ne_np_female/wavs/nep_2099_7067930712.wav
#   inflating: ne_np_female/wavs/nep_2099_7146853781.wav
# ...
#   inflating: ne_np_female/wavs/nep_6834_4927536600.wav
#   inflating: ne_np_female/wavs/nep_6834_4963803865.wav
#   inflating: ne_np_female/wavs/nep_6834_4981767777.wav
#   inflating: ne_np_female/wavs/nep_6834_4986165748.wav
#   inflating: ne_np_female/wavs/nep_6834_5007479984.wav
#   inflating: ne_np_female/wavs/nep_6834_5070348763.wav
#   inflating: ne_np_female/wavs/nep_6834_5122650091.wav
#   inflating: ne_np_female/wavs/nep_6834_5173085348.wav
#   inflating: ne_np_female/wavs/nep_6834_5257840596.wav
#   inflating: ne_np_female/wavs/nep_6834_5260978904.wav
#   inflating: ne_np_female/wavs/nep_6834_5295537087.wav
#   inflating: ne_np_female/wavs/nep_6834_5400599628.wav
#   inflating: ne_np_female/wavs/nep_6834_5431604112.wav
#   inflating: ne_np_female/wavs/nep_6834_5460988013.wav
#   inflating: ne_np_female/wavs/nep_6834_5592477130.wav
#   inflating: ne_np_female/wavs/nep_6834_5746530753.wav
#   inflating: ne_np_female/wavs/nep_6834_5798576935.wav
#   inflating: ne_np_female/wavs/nep_6834_5802345009.wav
#   inflating: ne_np_female/wavs/nep_6834_5877473759.wav
#   inflating: ne_np_female/wavs/nep_6834_5916619272.wav
#   inflating: ne_np_female/wavs/nep_6834_5966581481.wav
#   inflating: ne_np_female/wavs/nep_6834_5997059918.wav
#   inflating: ne_np_female/wavs/nep_6834_6045810218.wav
#   inflating: ne_np_female/wavs/nep_6834_6151409964.wav
#   inflating: ne_np_female/wavs/nep_6834_6191873103.wav
#   inflating: ne_np_female/wavs/nep_6834_6227221696.wav
#   inflating: ne_np_female/wavs/nep_6834_6231233885.wav
#   inflating: ne_np_female/wavs/nep_6834_6280964849.wav
#   inflating: ne_np_female/wavs/nep_6834_6318313501.wav
#   inflating: ne_np_female/wavs/nep_6834_6362179385.wav
#   inflating: ne_np_female/wavs/nep_6834_6392881485.wav
#   inflating: ne_np_female/wavs/nep_6834_6449523850.wav
#   inflating: ne_np_female/wavs/nep_6834_6500238641.wav
#   inflating: ne_np_female/wavs/nep_6834_6500910053.wav
#   inflating: ne_np_female/wavs/nep_6834_6501222973.wav
#   inflating: ne_np_female/wavs/nep_6834_6530919193.wav
#   inflating: ne_np_female/wavs/nep_6834_6727338945.wav
#   inflating: ne_np_female/wavs/nep_6834_6748541699.wav
#   inflating: ne_np_female/wavs/nep_6834_6786807069.wav
#   inflating: ne_np_female/wavs/nep_6834_6910353378.wav
#   inflating: ne_np_female/wavs/nep_6834_6997773130.wav
#   inflating: ne_np_female/wavs/nep_6834_7006102475.wav
#   inflating: ne_np_female/wavs/nep_6834_7022722399.wav
#   inflating: ne_np_female/wavs/nep_6834_7045652727.wav
#   inflating: ne_np_female/wavs/nep_6834_7219780083.wav
#   inflating: ne_np_female/wavs/nep_6834_7235986256.wav
#   inflating: ne_np_female/wavs/nep_6834_7318170766.wav
#   inflating: ne_np_female/wavs/nep_6834_7338170386.wav
#   inflating: ne_np_female/wavs/nep_6834_7347847874.wav
#   inflating: ne_np_female/wavs/nep_6834_7367961655.wav
#   inflating: ne_np_female/wavs/nep_6834_7400338955.wav
#   inflating: ne_np_female/wavs/nep_6834_7496761736.wav
#   inflating: ne_np_female/wavs/nep_6834_7534114675.wav
#   inflating: ne_np_female/wavs/nep_6834_7575295537.wav
#   inflating: ne_np_female/wavs/nep_6834_7581185692.wav
#   inflating: ne_np_female/wavs/nep_6834_7597189861.wav
#   inflating: ne_np_female/wavs/nep_6834_7621423521.wav
#   inflating: ne_np_female/wavs/nep_6834_7680945837.wav
#   inflating: ne_np_female/wavs/nep_6834_7738562180.wav
#   inflating: ne_np_female/wavs/nep_6834_7766238939.wav
#   inflating: ne_np_female/wavs/nep_6834_7810371653.wav
#   inflating: ne_np_female/wavs/nep_6834_7819509842.wav
#   inflating: ne_np_female/wavs/nep_6834_7828553259.wav
#   inflating: ne_np_female/wavs/nep_6834_7829580309.wav
#   inflating: ne_np_female/wavs/nep_6834_7865588733.wav
#   inflating: ne_np_female/wavs/nep_6834_7871266412.wav
#   inflating: ne_np_female/wavs/nep_6834_7899693955.wav
#   inflating: ne_np_female/wavs/nep_6834_7946628431.wav
#   inflating: ne_np_female/wavs/nep_6834_7999704556.wav
#   inflating: ne_np_female/wavs/nep_6834_8024274937.wav
#   inflating: ne_np_female/wavs/nep_6834_8130311336.wav
#   inflating: ne_np_female/wavs/nep_6834_8134424465.wav
#   inflating: ne_np_female/wavs/nep_6834_8174154863.wav
#   inflating: ne_np_female/wavs/nep_6834_8192975347.wav
#   inflating: ne_np_female/wavs/nep_6834_8304577409.wav
#   inflating: ne_np_female/wavs/nep_6834_8313324263.wav
#   inflating: ne_np_female/wavs/nep_6834_8455496039.wav
#   inflating: ne_np_female/wavs/nep_6834_8623317500.wav
#   inflating: ne_np_female/wavs/nep_6834_8628853591.wav
#   inflating: ne_np_female/wavs/nep_6834_8677691953.wav
#   inflating: ne_np_female/wavs/nep_6834_8728617166.wav
#   inflating: ne_np_female/wavs/nep_6834_8782018734.wav
#   inflating: ne_np_female/wavs/nep_6834_8836482229.wav
#   inflating: ne_np_female/wavs/nep_6834_8941342606.wav
#   inflating: ne_np_female/wavs/nep_6834_8962137317.wav
#   inflating: ne_np_female/wavs/nep_6834_9008342916.wav
#   inflating: ne_np_female/wavs/nep_6834_9092559990.wav
#   inflating: ne_np_female/wavs/nep_6834_9113225488.wav
#   inflating: ne_np_female/wavs/nep_6834_9155833217.wav
#   inflating: ne_np_female/wavs/nep_6834_9198746343.wav
#   inflating: ne_np_female/wavs/nep_6834_9278979144.wav
#   inflating: ne_np_female/wavs/nep_6834_9312649856.wav
#   inflating: ne_np_female/wavs/nep_6834_9351558392.wav
#   inflating: ne_np_female/wavs/nep_6834_9372773397.wav
#   inflating: ne_np_female/wavs/nep_6834_9385085142.wav
#   inflating: ne_np_female/wavs/nep_6834_9555445187.wav
#   inflating: ne_np_female/wavs/nep_6834_9558302314.wav
#   inflating: ne_np_female/wavs/nep_6834_9683958153.wav
#   inflating: ne_np_female/wavs/nep_6834_9709151348.wav
#   inflating: ne_np_female/wavs/nep_6834_9740563659.wav
#   inflating: ne_np_female/wavs/nep_6834_9820060770.wav
#   inflating: ne_np_female/wavs/nep_6834_9867321262.wav
#   inflating: ne_np_female/wavs/nep_7957_0009783902.wav
#   inflating: ne_np_female/wavs/nep_7957_0079907626.wav
#   inflating: ne_np_female/wavs/nep_7957_0082530407.wav
#   inflating: ne_np_female/wavs/nep_7957_0087734441.wav
#   inflating: ne_np_female/wavs/nep_7957_0140388673.wav
#   inflating: ne_np_female/wavs/nep_7957_0150211614.wav
#   inflating: ne_np_female/wavs/nep_7957_0177954418.wav
#   inflating: ne_np_female/wavs/nep_7957_0250324643.wav
#   inflating: ne_np_female/wavs/nep_7957_0328143850.wav
#   inflating: ne_np_female/wavs/nep_7957_0385367299.wav
#   inflating: ne_np_female/wavs/nep_7957_0459069016.wav
#   inflating: ne_np_female/wavs/nep_7957_0465528479.wav
#   inflating: ne_np_female/wavs/nep_7957_0539427969.wav
#   inflating: ne_np_female/wavs/nep_7957_0701885846.wav
#   inflating: ne_np_female/wavs/nep_7957_0754329079.wav
#   inflating: ne_np_female/wavs/nep_7957_0767454215.wav
#   inflating: ne_np_female/wavs/nep_7957_0918744926.wav
#   inflating: ne_np_female/wavs/nep_7957_1107857989.wav
#   inflating: ne_np_female/wavs/nep_7957_1264932788.wav
#   inflating: ne_np_female/wavs/nep_7957_1305772940.wav
#   inflating: ne_np_female/wavs/nep_7957_1388418121.wav
#   inflating: ne_np_female/wavs/nep_7957_1561164877.wav
#   inflating: ne_np_female/wavs/nep_7957_1562490176.wav
#   inflating: ne_np_female/wavs/nep_7957_1605678105.wav
#   inflating: ne_np_female/wavs/nep_7957_1717899039.wav
#   inflating: ne_np_female/wavs/nep_7957_1817204134.wav
#   inflating: ne_np_female/wavs/nep_7957_1879972607.wav
#   inflating: ne_np_female/wavs/nep_7957_1988178635.wav
#   inflating: ne_np_female/wavs/nep_7957_2004204104.wav
#   inflating: ne_np_female/wavs/nep_7957_2162495145.wav
#   inflating: ne_np_female/wavs/nep_7957_2261972825.wav
#   inflating: ne_np_female/wavs/nep_7957_2306441679.wav
#   inflating: ne_np_female/wavs/nep_7957_2420759252.wav
#   inflating: ne_np_female/wavs/nep_7957_2619070331.wav
#   inflating: ne_np_female/wavs/nep_7957_2831159128.wav
#   inflating: ne_np_female/wavs/nep_7957_2912354038.wav
#   inflating: ne_np_female/wavs/nep_7957_2945185218.wav
#   inflating: ne_np_female/wavs/nep_7957_2946235127.wav
#   inflating: ne_np_female/wavs/nep_7957_3053783668.wav
#   inflating: ne_np_female/wavs/nep_7957_3056873419.wav
#   inflating: ne_np_female/wavs/nep_7957_3122821499.wav
#   inflating: ne_np_female/wavs/nep_7957_3383714049.wav
#   inflating: ne_np_female/wavs/nep_7957_3423244460.wav
#   inflating: ne_np_female/wavs/nep_7957_3647141889.wav
#   inflating: ne_np_female/wavs/nep_7957_3764105076.wav
#   inflating: ne_np_female/wavs/nep_7957_4073378842.wav
#   inflating: ne_np_female/wavs/nep_7957_4119953298.wav
#   inflating: ne_np_female/wavs/nep_7957_4183289036.wav
#   inflating: ne_np_female/wavs/nep_7957_4268626399.wav
#   inflating: ne_np_female/wavs/nep_7957_4271932038.wav
#   inflating: ne_np_female/wavs/nep_7957_4341937167.wav
#   inflating: ne_np_female/wavs/nep_7957_4586775162.wav
#   inflating: ne_np_female/wavs/nep_7957_4596578175.wav
#   inflating: ne_np_female/wavs/nep_7957_4717090689.wav
#   inflating: ne_np_female/wavs/nep_7957_4735995613.wav
#   inflating: ne_np_female/wavs/nep_7957_4810765538.wav
#   inflating: ne_np_female/wavs/nep_7957_4817046571.wav
#   inflating: ne_np_female/wavs/nep_7957_4936747249.wav
#   inflating: ne_np_female/wavs/nep_7957_5084430899.wav
#   inflating: ne_np_female/wavs/nep_7957_5396441684.wav
#   inflating: ne_np_female/wavs/nep_7957_5435738711.wav
#   inflating: ne_np_female/wavs/nep_7957_5536664294.wav
#   inflating: ne_np_female/wavs/nep_7957_5610002623.wav
#   inflating: ne_np_female/wavs/nep_7957_5636337706.wav
#   inflating: ne_np_female/wavs/nep_7957_5683536819.wav
#   inflating: ne_np_female/wavs/nep_7957_5688499953.wav
#   inflating: ne_np_female/wavs/nep_7957_5692054824.wav
#   inflating: ne_np_female/wavs/nep_7957_5716140709.wav
#   inflating: ne_np_female/wavs/nep_7957_5786715186.wav
#   inflating: ne_np_female/wavs/nep_7957_6155198316.wav
#   inflating: ne_np_female/wavs/nep_7957_6298591264.wav
#   inflating: ne_np_female/wavs/nep_7957_6330432420.wav
#   inflating: ne_np_female/wavs/nep_7957_6689854482.wav
#   inflating: ne_np_female/wavs/nep_7957_6706814045.wav
#   inflating: ne_np_female/wavs/nep_7957_6834505402.wav
#   inflating: ne_np_female/wavs/nep_7957_7043499849.wav
#   inflating: ne_np_female/wavs/nep_7957_7061781956.wav
#   inflating: ne_np_female/wavs/nep_7957_7150839031.wav
#   inflating: ne_np_female/wavs/nep_7957_7174466874.wav
#   inflating: ne_np_female/wavs/nep_7957_7179302770.wav
#   inflating: ne_np_female/wavs/nep_7957_7218719384.wav
#   inflating: ne_np_female/wavs/nep_7957_7277032953.wav
#   inflating: ne_np_female/wavs/nep_7957_7390775219.wav
#   inflating: ne_np_female/wavs/nep_7957_7498485870.wav
#   inflating: ne_np_female/wavs/nep_7957_7595935465.wav
#   inflating: ne_np_female/wavs/nep_7957_7650570354.wav
#   inflating: ne_np_female/wavs/nep_7957_8068460898.wav
#   inflating: ne_np_female/wavs/nep_7957_8176877225.wav
#   inflating: ne_np_female/wavs/nep_7957_8208452579.wav
#   inflating: ne_np_female/wavs/nep_7957_8568488459.wav
#   inflating: ne_np_female/wavs/nep_7957_8610550659.wav
#   inflating: ne_np_female/wavs/nep_7957_8622545561.wav
#   inflating: ne_np_female/wavs/nep_7957_8648955519.wav
#   inflating: ne_np_female/wavs/nep_7957_8690887370.wav
#   inflating: ne_np_female/wavs/nep_7957_8821387069.wav
#   inflating: ne_np_female/wavs/nep_7957_8852910206.wav
#   inflating: ne_np_female/wavs/nep_7957_8962516805.wav
#   inflating: ne_np_female/wavs/nep_7957_8964412285.wav
#   inflating: ne_np_female/wavs/nep_7957_8968461916.wav
#   inflating: ne_np_female/wavs/nep_7957_9047604439.wav
#   inflating: ne_np_female/wavs/nep_7957_9062454092.wav
#   inflating: ne_np_female/wavs/nep_7957_9078420842.wav
#   inflating: ne_np_female/wavs/nep_7957_9170956763.wav
#   inflating: ne_np_female/wavs/nep_7957_9402794157.wav
#   inflating: ne_np_female/wavs/nep_7957_9501826337.wav
#   inflating: ne_np_female/wavs/nep_7957_9519606809.wav
#   inflating: ne_np_female/wavs/nep_7957_9553525282.wav
#   inflating: ne_np_female/wavs/nep_7957_9590537696.wav
#   inflating: ne_np_female/wavs/nep_7957_9607614486.wav
#   inflating: ne_np_female/wavs/nep_7957_9680379589.wav
#   inflating: ne_np_female/wavs/nep_7957_9826018123.wav
#   inflating: ne_np_female/wavs/nep_7957_9879087796.wav
#   inflating: ne_np_female/wavs/nep_7957_9918407216.wav
#   inflating: ne_np_female/wavs/nep_7957_9978009630.wav
#   inflating: ne_np_female/wavs/nep_9407_0158792615.wav
#   inflating: ne_np_female/wavs/nep_9407_0193589415.wav
#   inflating: ne_np_female/wavs/nep_9407_0400722495.wav
#   inflating: ne_np_female/wavs/nep_9407_0496486930.wav
#   inflating: ne_np_female/wavs/nep_9407_0613415585.wav
#   inflating: ne_np_female/wavs/nep_9407_0799871024.wav
#   inflating: ne_np_female/wavs/nep_9407_0996409696.wav
#   inflating: ne_np_female/wavs/nep_9407_1014345868.wav
#   inflating: ne_np_female/wavs/nep_9407_1025784594.wav
#   inflating: ne_np_female/wavs/nep_9407_1174772886.wav
#   inflating: ne_np_female/wavs/nep_9407_1190775953.wav
#   inflating: ne_np_female/wavs/nep_9407_1238310521.wav
#   inflating: ne_np_female/wavs/nep_9407_1315910654.wav
#   inflating: ne_np_female/wavs/nep_9407_1364591454.wav
#   inflating: ne_np_female/wavs/nep_9407_1387465127.wav
#   inflating: ne_np_female/wavs/nep_9407_1645226568.wav
#   inflating: ne_np_female/wavs/nep_9407_2141121852.wav
#   inflating: ne_np_female/wavs/nep_9407_2263580908.wav
#   inflating: ne_np_female/wavs/nep_9407_2333970111.wav
#   inflating: ne_np_female/wavs/nep_9407_2488033066.wav
#   inflating: ne_np_female/wavs/nep_9407_2812946804.wav
#   inflating: ne_np_female/wavs/nep_9407_3266682112.wav
#   inflating: ne_np_female/wavs/nep_9407_3483517941.wav
#   inflating: ne_np_female/wavs/nep_9407_3627853892.wav
#   inflating: ne_np_female/wavs/nep_9407_3709787182.wav
#   inflating: ne_np_female/wavs/nep_9407_3741270281.wav
#   inflating: ne_np_female/wavs/nep_9407_3822201289.wav
#   inflating: ne_np_female/wavs/nep_9407_3978206055.wav
#   inflating: ne_np_female/wavs/nep_9407_4315096359.wav
#   inflating: ne_np_female/wavs/nep_9407_4456725875.wav
#   inflating: ne_np_female/wavs/nep_9407_4546759808.wav
#   inflating: ne_np_female/wavs/nep_9407_4708385865.wav
#   inflating: ne_np_female/wavs/nep_9407_5120596605.wav
#   inflating: ne_np_female/wavs/nep_9407_5122519134.wav
#   inflating: ne_np_female/wavs/nep_9407_5725574039.wav
#   inflating: ne_np_female/wavs/nep_9407_5753543973.wav
#   inflating: ne_np_female/wavs/nep_9407_5753765750.wav
#   inflating: ne_np_female/wavs/nep_9407_5754189878.wav
#   inflating: ne_np_female/wavs/nep_9407_6166370797.wav
#   inflating: ne_np_female/wavs/nep_9407_6191215837.wav
#   inflating: ne_np_female/wavs/nep_9407_6193607404.wav
#   inflating: ne_np_female/wavs/nep_9407_6540916448.wav
#   inflating: ne_np_female/wavs/nep_9407_6625520421.wav
#   inflating: ne_np_female/wavs/nep_9407_6761600954.wav
#   inflating: ne_np_female/wavs/nep_9407_6860838920.wav
#   inflating: ne_np_female/wavs/nep_9407_7175482211.wav
#   inflating: ne_np_female/wavs/nep_9407_7452562092.wav
#   inflating: ne_np_female/wavs/nep_9407_7594762595.wav
#   inflating: ne_np_female/wavs/nep_9407_7758195523.wav
#   inflating: ne_np_female/wavs/nep_9407_7860795301.wav
#   inflating: ne_np_female/wavs/nep_9407_7958778449.wav
#   inflating: ne_np_female/wavs/nep_9407_7973941193.wav
#   inflating: ne_np_female/wavs/nep_9407_8029469037.wav
#   inflating: ne_np_female/wavs/nep_9407_8609403285.wav
#   inflating: ne_np_female/wavs/nep_9407_8654587697.wav
#   inflating: ne_np_female/wavs/nep_9407_8703001189.wav
#   inflating: ne_np_female/wavs/nep_9407_9206137835.wav
#   inflating: ne_np_female/wavs/nep_9407_9290636989.wav
#   inflating: ne_np_female/wavs/nep_9407_9295760097.wav
#   inflating: ne_np_female/wavs/nep_9407_9451979543.wav
#   inflating: ne_np_female/wavs/nep_9407_9558473002.wav
#   inflating: ne_np_female/wavs/nep_9407_9632964143.wav
#   inflating: ne_np_female/wavs/nep_9407_9646005575.wav
#   inflating: ne_np_female/wavs/nep_9407_9974252924.wav
# line_index.tsv	wavs

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from datasets import load_dataset

colnames=['path','sentence'] 
df  = pd.read_csv('/content/ne_np_female/line_index.tsv',sep='\t',header=None,names = colnames)
df['path'] = '/content/ne_np_female/wavs/'+df['path'] +'.wav'

train, test = train_test_split(df, test_size=0.1)

train.to_csv('/content/ne_np_female/line_index_train.csv')
test.to_csv('/content/ne_np_female/line_index_test.csv')
#common_voice_train = load_dataset('csv', data_files='/content/ne_np_female/line_index_train.csv',split= 'train')
#common_voice_test = load_dataset('csv', data_files='/content/ne_np_female/line_index_test.csv',split = 'train')

# %%
import torch
import torchaudio
from datasets import load_dataset, load_metric
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
import re

test_dataset = load_dataset('csv', data_files='/content/ne_np_female/line_index_test.csv',split = 'train')
wer = load_metric("wer")

processor = Wav2Vec2Processor.from_pretrained("gagan3012/wav2vec2-xlsr-nepali")
model = Wav2Vec2ForCTC.from_pretrained("gagan3012/wav2vec2-xlsr-nepali") 
model.to("cuda")

chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\“]'  # TODO: adapt this list to include all special characters you removed from the data
resampler = torchaudio.transforms.Resample(48_000, 16_000)

# Preprocessing the datasets.
# We need to read the aduio files as arrays
def speech_file_to_array_fn(batch):
	batch["sentence"] = re.sub(chars_to_ignore_regex, '', batch["sentence"]).lower()
	speech_array, sampling_rate = torchaudio.load(batch["path"])
	batch["speech"] = resampler(speech_array).squeeze().numpy()
	return batch

test_dataset = test_dataset.map(speech_file_to_array_fn)

# Preprocessing the datasets.
# We need to read the aduio files as arrays
def evaluate(batch):
	inputs = processor(batch["speech"], sampling_rate=16_000, return_tensors="pt", padding=True)

	with torch.no_grad():
		logits = model(inputs.input_values.to("cuda"), attention_mask=inputs.attention_mask.to("cuda")).logits

	pred_ids = torch.argmax(logits, dim=-1)
	batch["pred_strings"] = processor.batch_decode(pred_ids)
	return batch

result = test_dataset.map(evaluate, batched=True, batch_size=8)

print("WER: {:2f}".format(100 * wer.compute(predictions=result["pred_strings"], references=result["sentence"])))
# Out:
# Using custom data configuration default-33e60b51d29931aa
# Downloading and preparing dataset csv/default (download: Unknown size, generated: Unknown size, post-processed: Unknown size, total: Unknown size) to /root/.cache/huggingface/datasets/csv/default-33e60b51d29931aa/0.0.0/2a88c45fed596f9421a2e7f74ab1a3cd012ef75210a5dc1950e8d60ca8d9c66c...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-33e60b51d29931aa/0.0.0/2a88c45fed596f9421a2e7f74ab1a3cd012ef75210a5dc1950e8d60ca8d9c66c. Subsequent calls will reuse this data.
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# HBox(children=(FloatProgress(value=0.0, max=207.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=26.0), HTML(value='')))
# WER: 5.970952

# %% [markdown]
# Alright! The transcription can definitely be recognized from our prediction, but it is far from being perfect. Training the model a bit longer, spending more time on the data preprocessing, and especially using a language model for decoding would certainly improve the model's overall performance.
#
# For a demonstration model on a low-resource language, the results are acceptable, however 🤗.
